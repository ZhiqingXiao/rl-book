# %% [markdown]
# # Use Off-Policy VPG with Baseline to Play CartPole-v0
#
# PyTorch version

# %%
# %matplotlib inline

import sys
import logging
import itertools

import numpy as np
np.random.seed(0)
import pandas as pd
import gym
import matplotlib.pyplot as plt
import torch
torch.manual_seed(0)
import torch.nn as nn
import torch.optim as optim
import torch.distributions as distributions

logging.basicConfig(level=logging.INFO,
        format='%(asctime)s [%(levelname)s] %(message)s',
        stream=sys.stdout, datefmt='%H:%M:%S')

# %%
env = gym.make('CartPole-v0', new_step_api=True)
for key in vars(env):
    logging.info('%s: %s', key, vars(env)[key])
for key in vars(env.spec):
    logging.info('%s: %s', key, vars(env.spec)[key])
# Out:
# 00:02:21 [INFO] env: <CartPoleEnv<CartPole-v0>>
# 00:02:21 [INFO] action_space: Discrete(2)
# 00:02:21 [INFO] observation_space: Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)
# 00:02:21 [INFO] reward_range: (-inf, inf)
# 00:02:21 [INFO] metadata: {'render.modes': ['human', 'rgb_array'], 'video.frames_per_second': 50}
# 00:02:21 [INFO] _max_episode_steps: 200
# 00:02:21 [INFO] _elapsed_steps: None
# 00:02:21 [INFO] id: CartPole-v0
# 00:02:21 [INFO] entry_point: gym.envs.classic_control:CartPoleEnv
# 00:02:21 [INFO] reward_threshold: 195.0
# 00:02:21 [INFO] nondeterministic: False
# 00:02:21 [INFO] max_episode_steps: 200
# 00:02:21 [INFO] _kwargs: {}
# 00:02:21 [INFO] _env_name: CartPole

# %%
class OffPolicyVPGwBaselineAgent:
    def __init__(self, env,):
        self.action_n = env.action_space.n
        self.gamma = 0.99

        self.policy_net = self.build_net(
                input_size=env.observation_space.shape[0],
                hidden_sizes=[],
                output_size=self.action_n, output_activator=nn.Softmax(1))
        self.policy_optimizer = optim.Adam(self.policy_net.parameters(), lr=0.06)
        self.baseline_net = self.build_net(
                input_size=env.observation_space.shape[0],
                hidden_sizes=[])
        self.baseline_optimizer = optim.Adam(self.policy_net.parameters(), lr=0.1)
        self.baseline_loss = nn.MSELoss()

    def build_net(self, input_size, hidden_sizes, output_size=1,
            output_activator=None, use_bias=False):
        layers = []
        for input_size, output_size in zip(
                [input_size,] + hidden_sizes, hidden_sizes + [output_size,]):
            layers.append(nn.Linear(input_size, output_size, bias=use_bias))
            layers.append(nn.ReLU())
        layers = layers[:-1]
        if output_activator:
            layers.append(output_activator)
        model = nn.Sequential(*layers)
        return model

    def reset(self, mode=None):
        self.mode = mode
        if self.mode == 'train':
            self.trajectory = []

    def step(self, observation, reward, termination):
        if self.mode == 'train':
            action = np.random.choice(self.action_n)  # use random policy
            self.trajectory += [observation, reward, termination, action]
        else:
            state_tensor = torch.as_tensor(observation,
                    dtype=torch.float).unsqueeze(0)
            prob_tensor = self.policy_net(state_tensor)
            action_tensor = distributions.Categorical(prob_tensor).sample()
            action = action_tensor.numpy()[0]
        return action

    def close(self):
        if self.mode == 'train':
            self.learn()

    def learn(self):
        state_tensor = torch.as_tensor(self.trajectory[0::4], dtype=torch.float)
        reward_tensor = torch.as_tensor(self.trajectory[1::4], dtype=torch.float)
        action_tensor = torch.as_tensor(self.trajectory[3::4], dtype=torch.long)
        arange_tensor = torch.arange(state_tensor.shape[0], dtype=torch.float)

        # update baseline
        discount_tensor = self.gamma ** arange_tensor
        discounted_reward_tensor = discount_tensor * reward_tensor
        discounted_return_tensor = discounted_reward_tensor.flip(
                0).cumsum(0).flip(0)
        return_tensor = discounted_return_tensor / discount_tensor
        pred_tensor = self.baseline_net(state_tensor)
        psi_tensor = (discounted_return_tensor -
                discount_tensor * pred_tensor).detach()
        baseline_loss_tensor = self.baseline_loss(pred_tensor,
                return_tensor.unsqueeze(1))
        self.baseline_optimizer.zero_grad()
        baseline_loss_tensor.backward()
        self.baseline_optimizer.step()

        # update policy
        all_pi_tensor = self.policy_net(state_tensor)
        pi_tensor = torch.gather(all_pi_tensor, 1,
                action_tensor.unsqueeze(1)).squeeze(1)
        behavior_prob = 1. / self.action_n
        policy_loss_tensor = -(psi_tensor / behavior_prob * pi_tensor).mean()
        self.policy_optimizer.zero_grad()
        policy_loss_tensor.backward()
        self.policy_optimizer.step()


agent = OffPolicyVPGwBaselineAgent(env)

# %%
def play_episode(env, agent, seed=None, mode=None, render=False):
    observation = env.reset(seed=seed)
    reward, termination, truncation = 0., False, False
    agent.reset(mode=mode)
    episode_reward, elapsed_steps = 0., 0
    while True:
        action = agent.step(observation, reward, termination)
        if render:
            env.render()
        if termination or truncation:
            break
        observation, reward, termination, truncation, _ = env.step(action)
        episode_reward += reward
        elapsed_steps += 1
    agent.close()
    return episode_reward, elapsed_steps


logging.info('==== train ====')
episode_rewards = []
for episode in itertools.count():
    play_episode(env, agent, seed=episode,
            mode='train')
    episode_reward, elapsed_steps = play_episode(env, agent)
    episode_rewards.append(episode_reward)
    logging.info('train episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
    if np.mean(episode_rewards[-20:]) > 199:
        break
plt.plot(episode_rewards)


logging.info('==== test ====')
episode_rewards = []
for episode in range(100):
    episode_reward, elapsed_steps = play_episode(env, agent)
    episode_rewards.append(episode_reward)
    logging.info('test episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
logging.info('average episode reward = %.2f ± %.2f',
        np.mean(episode_rewards), np.std(episode_rewards))
# Out:
# 00:02:21 [INFO] ==== train ====
# 00:02:21 [INFO] train episode 0: reward = 39.00, steps = 39
# 00:02:21 [INFO] train episode 1: reward = 56.00, steps = 56
# 00:02:21 [INFO] train episode 2: reward = 61.00, steps = 61
# 00:02:21 [INFO] train episode 3: reward = 72.00, steps = 72
# 00:02:21 [INFO] train episode 4: reward = 45.00, steps = 45
# 00:02:21 [INFO] train episode 5: reward = 39.00, steps = 39
# 00:02:21 [INFO] train episode 6: reward = 28.00, steps = 28
# 00:02:21 [INFO] train episode 7: reward = 129.00, steps = 129
# 00:02:21 [INFO] train episode 8: reward = 17.00, steps = 17
# 00:02:21 [INFO] train episode 9: reward = 24.00, steps = 24
# 00:02:21 [INFO] train episode 10: reward = 51.00, steps = 51
# 00:02:21 [INFO] train episode 11: reward = 16.00, steps = 16
# 00:02:21 [INFO] train episode 12: reward = 15.00, steps = 15
# 00:02:22 [INFO] train episode 13: reward = 32.00, steps = 32
# 00:02:22 [INFO] train episode 14: reward = 79.00, steps = 79
# 00:02:22 [INFO] train episode 15: reward = 44.00, steps = 44
# 00:02:22 [INFO] train episode 16: reward = 18.00, steps = 18
# 00:02:22 [INFO] train episode 17: reward = 17.00, steps = 17
# 00:02:22 [INFO] train episode 18: reward = 19.00, steps = 19
# 00:02:22 [INFO] train episode 19: reward = 49.00, steps = 49
# 00:02:22 [INFO] train episode 20: reward = 47.00, steps = 47
# 00:02:22 [INFO] train episode 21: reward = 68.00, steps = 68
# 00:02:22 [INFO] train episode 22: reward = 48.00, steps = 48
# 00:02:22 [INFO] train episode 23: reward = 91.00, steps = 91
# 00:02:22 [INFO] train episode 24: reward = 9.00, steps = 9
# 00:02:22 [INFO] train episode 25: reward = 47.00, steps = 47
# 00:02:22 [INFO] train episode 26: reward = 59.00, steps = 59
# 00:02:22 [INFO] train episode 27: reward = 104.00, steps = 104
# 00:02:22 [INFO] train episode 28: reward = 83.00, steps = 83
# 00:02:22 [INFO] train episode 29: reward = 25.00, steps = 25
# 00:02:22 [INFO] train episode 30: reward = 36.00, steps = 36
# 00:02:22 [INFO] train episode 31: reward = 91.00, steps = 91
# 00:02:22 [INFO] train episode 32: reward = 46.00, steps = 46
# 00:02:22 [INFO] train episode 33: reward = 20.00, steps = 20
# 00:02:22 [INFO] train episode 34: reward = 20.00, steps = 20
# 00:02:22 [INFO] train episode 35: reward = 54.00, steps = 54
# 00:02:22 [INFO] train episode 36: reward = 101.00, steps = 101
# 00:02:22 [INFO] train episode 37: reward = 39.00, steps = 39
# 00:02:22 [INFO] train episode 38: reward = 16.00, steps = 16
# 00:02:22 [INFO] train episode 39: reward = 29.00, steps = 29
# 00:02:22 [INFO] train episode 40: reward = 61.00, steps = 61
# 00:02:22 [INFO] train episode 41: reward = 64.00, steps = 64
# 00:02:22 [INFO] train episode 42: reward = 124.00, steps = 124
# 00:02:22 [INFO] train episode 43: reward = 82.00, steps = 82
# 00:02:22 [INFO] train episode 44: reward = 81.00, steps = 81
# 00:02:22 [INFO] train episode 45: reward = 115.00, steps = 115
# 00:02:22 [INFO] train episode 46: reward = 49.00, steps = 49
# 00:02:22 [INFO] train episode 47: reward = 55.00, steps = 55
# 00:02:22 [INFO] train episode 48: reward = 47.00, steps = 47
# 00:02:22 [INFO] train episode 49: reward = 49.00, steps = 49
# 00:02:22 [INFO] train episode 50: reward = 51.00, steps = 51
# 00:02:22 [INFO] train episode 51: reward = 103.00, steps = 103
# 00:02:22 [INFO] train episode 52: reward = 93.00, steps = 93
# 00:02:22 [INFO] train episode 53: reward = 114.00, steps = 114
# 00:02:22 [INFO] train episode 54: reward = 36.00, steps = 36
# 00:02:22 [INFO] train episode 55: reward = 115.00, steps = 115
# 00:02:22 [INFO] train episode 56: reward = 35.00, steps = 35
# 00:02:22 [INFO] train episode 57: reward = 54.00, steps = 54
# 00:02:22 [INFO] train episode 58: reward = 48.00, steps = 48
# 00:02:22 [INFO] train episode 59: reward = 120.00, steps = 120
# 00:02:23 [INFO] train episode 60: reward = 35.00, steps = 35
# 00:02:23 [INFO] train episode 61: reward = 74.00, steps = 74
# 00:02:23 [INFO] train episode 62: reward = 23.00, steps = 23
# 00:02:23 [INFO] train episode 63: reward = 74.00, steps = 74
# 00:02:23 [INFO] train episode 64: reward = 57.00, steps = 57
# 00:02:23 [INFO] train episode 65: reward = 84.00, steps = 84
# 00:02:23 [INFO] train episode 66: reward = 47.00, steps = 47
# 00:02:23 [INFO] train episode 67: reward = 23.00, steps = 23
# 00:02:23 [INFO] train episode 68: reward = 89.00, steps = 89
# 00:02:23 [INFO] train episode 69: reward = 89.00, steps = 89
# 00:02:23 [INFO] train episode 70: reward = 34.00, steps = 34
# 00:02:23 [INFO] train episode 71: reward = 85.00, steps = 85
# 00:02:23 [INFO] train episode 72: reward = 34.00, steps = 34
# 00:02:23 [INFO] train episode 73: reward = 74.00, steps = 74
# 00:02:23 [INFO] train episode 74: reward = 48.00, steps = 48
# 00:02:23 [INFO] train episode 75: reward = 41.00, steps = 41
# 00:02:23 [INFO] train episode 76: reward = 48.00, steps = 48
# 00:02:23 [INFO] train episode 77: reward = 62.00, steps = 62
# 00:02:23 [INFO] train episode 78: reward = 37.00, steps = 37
# 00:02:23 [INFO] train episode 79: reward = 54.00, steps = 54
# 00:02:23 [INFO] train episode 80: reward = 76.00, steps = 76
# 00:02:23 [INFO] train episode 81: reward = 68.00, steps = 68
# 00:02:23 [INFO] train episode 82: reward = 94.00, steps = 94
# 00:02:23 [INFO] train episode 83: reward = 61.00, steps = 61
# 00:02:23 [INFO] train episode 84: reward = 69.00, steps = 69
# 00:02:23 [INFO] train episode 85: reward = 41.00, steps = 41
# 00:02:23 [INFO] train episode 86: reward = 26.00, steps = 26
# 00:02:23 [INFO] train episode 87: reward = 63.00, steps = 63
# 00:02:23 [INFO] train episode 88: reward = 42.00, steps = 42
# 00:02:23 [INFO] train episode 89: reward = 25.00, steps = 25
# 00:02:23 [INFO] train episode 90: reward = 45.00, steps = 45
# 00:02:23 [INFO] train episode 91: reward = 82.00, steps = 82
# 00:02:23 [INFO] train episode 92: reward = 67.00, steps = 67
# 00:02:23 [INFO] train episode 93: reward = 59.00, steps = 59
# 00:02:23 [INFO] train episode 94: reward = 62.00, steps = 62
# 00:02:23 [INFO] train episode 95: reward = 49.00, steps = 49
# 00:02:23 [INFO] train episode 96: reward = 55.00, steps = 55
# 00:02:23 [INFO] train episode 97: reward = 145.00, steps = 145
# 00:02:23 [INFO] train episode 98: reward = 45.00, steps = 45
# 00:02:23 [INFO] train episode 99: reward = 57.00, steps = 57
# 00:02:23 [INFO] train episode 100: reward = 35.00, steps = 35
# 00:02:23 [INFO] train episode 101: reward = 140.00, steps = 140
# 00:02:23 [INFO] train episode 102: reward = 55.00, steps = 55
# 00:02:23 [INFO] train episode 103: reward = 57.00, steps = 57
# 00:02:23 [INFO] train episode 104: reward = 33.00, steps = 33
# 00:02:23 [INFO] train episode 105: reward = 72.00, steps = 72
# 00:02:23 [INFO] train episode 106: reward = 86.00, steps = 86
# 00:02:24 [INFO] train episode 107: reward = 61.00, steps = 61
# 00:02:24 [INFO] train episode 108: reward = 89.00, steps = 89
# 00:02:24 [INFO] train episode 109: reward = 55.00, steps = 55
# 00:02:24 [INFO] train episode 110: reward = 65.00, steps = 65
# 00:02:24 [INFO] train episode 111: reward = 37.00, steps = 37
# 00:02:24 [INFO] train episode 112: reward = 62.00, steps = 62
# 00:02:24 [INFO] train episode 113: reward = 57.00, steps = 57
# 00:02:24 [INFO] train episode 114: reward = 50.00, steps = 50
# 00:02:24 [INFO] train episode 115: reward = 62.00, steps = 62
# 00:02:24 [INFO] train episode 116: reward = 83.00, steps = 83
# 00:02:24 [INFO] train episode 117: reward = 79.00, steps = 79
# 00:02:24 [INFO] train episode 118: reward = 41.00, steps = 41
# 00:02:24 [INFO] train episode 119: reward = 48.00, steps = 48
# 00:02:24 [INFO] train episode 120: reward = 55.00, steps = 55
# 00:02:24 [INFO] train episode 121: reward = 63.00, steps = 63
# 00:02:24 [INFO] train episode 122: reward = 53.00, steps = 53
# 00:02:24 [INFO] train episode 123: reward = 83.00, steps = 83
# 00:02:24 [INFO] train episode 124: reward = 108.00, steps = 108
# 00:02:24 [INFO] train episode 125: reward = 39.00, steps = 39
# 00:02:24 [INFO] train episode 126: reward = 59.00, steps = 59
# 00:02:24 [INFO] train episode 127: reward = 48.00, steps = 48
# 00:02:24 [INFO] train episode 128: reward = 80.00, steps = 80
# 00:02:24 [INFO] train episode 129: reward = 84.00, steps = 84
# 00:02:24 [INFO] train episode 130: reward = 85.00, steps = 85
# 00:02:24 [INFO] train episode 131: reward = 78.00, steps = 78
# 00:02:24 [INFO] train episode 132: reward = 59.00, steps = 59
# 00:02:24 [INFO] train episode 133: reward = 56.00, steps = 56
# 00:02:24 [INFO] train episode 134: reward = 65.00, steps = 65
# 00:02:24 [INFO] train episode 135: reward = 36.00, steps = 36
# 00:02:24 [INFO] train episode 136: reward = 51.00, steps = 51
# 00:02:24 [INFO] train episode 137: reward = 34.00, steps = 34
# 00:02:24 [INFO] train episode 138: reward = 67.00, steps = 67
# 00:02:24 [INFO] train episode 139: reward = 59.00, steps = 59
# 00:02:24 [INFO] train episode 140: reward = 43.00, steps = 43
# 00:02:24 [INFO] train episode 141: reward = 101.00, steps = 101
# 00:02:24 [INFO] train episode 142: reward = 74.00, steps = 74
# 00:02:24 [INFO] train episode 143: reward = 69.00, steps = 69
# 00:02:24 [INFO] train episode 144: reward = 48.00, steps = 48
# 00:02:24 [INFO] train episode 145: reward = 55.00, steps = 55
# 00:02:24 [INFO] train episode 146: reward = 63.00, steps = 63
# 00:02:24 [INFO] train episode 147: reward = 60.00, steps = 60
# 00:02:24 [INFO] train episode 148: reward = 108.00, steps = 108
# 00:02:24 [INFO] train episode 149: reward = 56.00, steps = 56
# 00:02:24 [INFO] train episode 150: reward = 51.00, steps = 51
# 00:02:24 [INFO] train episode 151: reward = 70.00, steps = 70
# 00:02:25 [INFO] train episode 152: reward = 52.00, steps = 52
# 00:02:25 [INFO] train episode 153: reward = 33.00, steps = 33
# 00:02:25 [INFO] train episode 154: reward = 48.00, steps = 48
# 00:02:25 [INFO] train episode 155: reward = 145.00, steps = 145
# 00:02:25 [INFO] train episode 156: reward = 75.00, steps = 75
# 00:02:25 [INFO] train episode 157: reward = 48.00, steps = 48
# 00:02:25 [INFO] train episode 158: reward = 43.00, steps = 43
# 00:02:25 [INFO] train episode 159: reward = 54.00, steps = 54
# 00:02:25 [INFO] train episode 160: reward = 119.00, steps = 119
# 00:02:25 [INFO] train episode 161: reward = 69.00, steps = 69
# 00:02:25 [INFO] train episode 162: reward = 97.00, steps = 97
# 00:02:25 [INFO] train episode 163: reward = 63.00, steps = 63
# 00:02:25 [INFO] train episode 164: reward = 64.00, steps = 64
# 00:02:25 [INFO] train episode 165: reward = 63.00, steps = 63
# 00:02:25 [INFO] train episode 166: reward = 44.00, steps = 44
# 00:02:25 [INFO] train episode 167: reward = 61.00, steps = 61
# 00:02:25 [INFO] train episode 168: reward = 74.00, steps = 74
# 00:02:25 [INFO] train episode 169: reward = 68.00, steps = 68
# 00:02:25 [INFO] train episode 170: reward = 43.00, steps = 43
# 00:02:25 [INFO] train episode 171: reward = 51.00, steps = 51
# 00:02:25 [INFO] train episode 172: reward = 51.00, steps = 51
# 00:02:25 [INFO] train episode 173: reward = 33.00, steps = 33
# 00:02:25 [INFO] train episode 174: reward = 31.00, steps = 31
# 00:02:25 [INFO] train episode 175: reward = 49.00, steps = 49
# 00:02:25 [INFO] train episode 176: reward = 85.00, steps = 85
# 00:02:25 [INFO] train episode 177: reward = 57.00, steps = 57
# 00:02:25 [INFO] train episode 178: reward = 54.00, steps = 54
# 00:02:25 [INFO] train episode 179: reward = 90.00, steps = 90
# 00:02:25 [INFO] train episode 180: reward = 44.00, steps = 44
# 00:02:25 [INFO] train episode 181: reward = 68.00, steps = 68
# 00:02:25 [INFO] train episode 182: reward = 103.00, steps = 103
# 00:02:25 [INFO] train episode 183: reward = 78.00, steps = 78
# 00:02:25 [INFO] train episode 184: reward = 71.00, steps = 71
# 00:02:25 [INFO] train episode 185: reward = 43.00, steps = 43
# 00:02:25 [INFO] train episode 186: reward = 102.00, steps = 102
# 00:02:25 [INFO] train episode 187: reward = 57.00, steps = 57
# 00:02:25 [INFO] train episode 188: reward = 98.00, steps = 98
# 00:02:25 [INFO] train episode 189: reward = 68.00, steps = 68
# 00:02:25 [INFO] train episode 190: reward = 62.00, steps = 62
# 00:02:25 [INFO] train episode 191: reward = 39.00, steps = 39
# 00:02:25 [INFO] train episode 192: reward = 64.00, steps = 64
# 00:02:25 [INFO] train episode 193: reward = 130.00, steps = 130
# 00:02:25 [INFO] train episode 194: reward = 108.00, steps = 108
# 00:02:25 [INFO] train episode 195: reward = 59.00, steps = 59
# 00:02:26 [INFO] train episode 196: reward = 50.00, steps = 50
# 00:02:26 [INFO] train episode 197: reward = 58.00, steps = 58
# 00:02:26 [INFO] train episode 198: reward = 59.00, steps = 59
# 00:02:26 [INFO] train episode 199: reward = 60.00, steps = 60
# 00:02:26 [INFO] train episode 200: reward = 58.00, steps = 58
# 00:02:26 [INFO] train episode 201: reward = 22.00, steps = 22
# 00:02:26 [INFO] train episode 202: reward = 49.00, steps = 49
# 00:02:26 [INFO] train episode 203: reward = 73.00, steps = 73
# 00:02:26 [INFO] train episode 204: reward = 63.00, steps = 63
# 00:02:26 [INFO] train episode 205: reward = 65.00, steps = 65
# 00:02:26 [INFO] train episode 206: reward = 22.00, steps = 22
# 00:02:26 [INFO] train episode 207: reward = 71.00, steps = 71
# 00:02:26 [INFO] train episode 208: reward = 72.00, steps = 72
# 00:02:26 [INFO] train episode 209: reward = 61.00, steps = 61
# 00:02:26 [INFO] train episode 210: reward = 44.00, steps = 44
# 00:02:26 [INFO] train episode 211: reward = 47.00, steps = 47
# 00:02:26 [INFO] train episode 212: reward = 57.00, steps = 57
# 00:02:26 [INFO] train episode 213: reward = 109.00, steps = 109
# 00:02:26 [INFO] train episode 214: reward = 61.00, steps = 61
# 00:02:26 [INFO] train episode 215: reward = 170.00, steps = 170
# 00:02:26 [INFO] train episode 216: reward = 51.00, steps = 51
# 00:02:26 [INFO] train episode 217: reward = 71.00, steps = 71
# 00:02:26 [INFO] train episode 218: reward = 57.00, steps = 57
# 00:02:26 [INFO] train episode 219: reward = 56.00, steps = 56
# 00:02:26 [INFO] train episode 220: reward = 38.00, steps = 38
# 00:02:26 [INFO] train episode 221: reward = 39.00, steps = 39
# 00:02:26 [INFO] train episode 222: reward = 163.00, steps = 163
# 00:02:26 [INFO] train episode 223: reward = 61.00, steps = 61
# 00:02:26 [INFO] train episode 224: reward = 15.00, steps = 15
# 00:02:26 [INFO] train episode 225: reward = 33.00, steps = 33
# 00:02:26 [INFO] train episode 226: reward = 34.00, steps = 34
# 00:02:26 [INFO] train episode 227: reward = 89.00, steps = 89
# 00:02:26 [INFO] train episode 228: reward = 49.00, steps = 49
# 00:02:26 [INFO] train episode 229: reward = 37.00, steps = 37
# 00:02:26 [INFO] train episode 230: reward = 64.00, steps = 64
# 00:02:26 [INFO] train episode 231: reward = 55.00, steps = 55
# 00:02:26 [INFO] train episode 232: reward = 66.00, steps = 66
# 00:02:26 [INFO] train episode 233: reward = 36.00, steps = 36
# 00:02:26 [INFO] train episode 234: reward = 64.00, steps = 64
# 00:02:26 [INFO] train episode 235: reward = 59.00, steps = 59
# 00:02:26 [INFO] train episode 236: reward = 72.00, steps = 72
# 00:02:26 [INFO] train episode 237: reward = 53.00, steps = 53
# 00:02:26 [INFO] train episode 238: reward = 72.00, steps = 72
# 00:02:26 [INFO] train episode 239: reward = 49.00, steps = 49
# 00:02:26 [INFO] train episode 240: reward = 41.00, steps = 41
# 00:02:26 [INFO] train episode 241: reward = 119.00, steps = 119
# 00:02:26 [INFO] train episode 242: reward = 69.00, steps = 69
# 00:02:27 [INFO] train episode 243: reward = 78.00, steps = 78
# 00:02:27 [INFO] train episode 244: reward = 69.00, steps = 69
# 00:02:27 [INFO] train episode 245: reward = 91.00, steps = 91
# 00:02:27 [INFO] train episode 246: reward = 42.00, steps = 42
# 00:02:27 [INFO] train episode 247: reward = 104.00, steps = 104
# 00:02:27 [INFO] train episode 248: reward = 37.00, steps = 37
# 00:02:27 [INFO] train episode 249: reward = 86.00, steps = 86
# 00:02:27 [INFO] train episode 250: reward = 66.00, steps = 66
# 00:02:27 [INFO] train episode 251: reward = 97.00, steps = 97
# 00:02:27 [INFO] train episode 252: reward = 41.00, steps = 41
# 00:02:27 [INFO] train episode 253: reward = 70.00, steps = 70
# 00:02:27 [INFO] train episode 254: reward = 64.00, steps = 64
# 00:02:27 [INFO] train episode 255: reward = 76.00, steps = 76
# 00:02:27 [INFO] train episode 256: reward = 43.00, steps = 43
# 00:02:27 [INFO] train episode 257: reward = 49.00, steps = 49
# 00:02:27 [INFO] train episode 258: reward = 64.00, steps = 64
# 00:02:27 [INFO] train episode 259: reward = 29.00, steps = 29
# 00:02:27 [INFO] train episode 260: reward = 75.00, steps = 75
# 00:02:27 [INFO] train episode 261: reward = 62.00, steps = 62
# 00:02:27 [INFO] train episode 262: reward = 53.00, steps = 53
# 00:02:27 [INFO] train episode 263: reward = 56.00, steps = 56
# 00:02:27 [INFO] train episode 264: reward = 74.00, steps = 74
# 00:02:27 [INFO] train episode 265: reward = 75.00, steps = 75
# 00:02:27 [INFO] train episode 266: reward = 54.00, steps = 54
# 00:02:27 [INFO] train episode 267: reward = 44.00, steps = 44
# 00:02:27 [INFO] train episode 268: reward = 62.00, steps = 62
# 00:02:27 [INFO] train episode 269: reward = 32.00, steps = 32
# 00:02:27 [INFO] train episode 270: reward = 175.00, steps = 175
# 00:02:27 [INFO] train episode 271: reward = 53.00, steps = 53
# 00:02:27 [INFO] train episode 272: reward = 43.00, steps = 43
# 00:02:27 [INFO] train episode 273: reward = 44.00, steps = 44
# 00:02:27 [INFO] train episode 274: reward = 52.00, steps = 52
# 00:02:27 [INFO] train episode 275: reward = 53.00, steps = 53
# 00:02:27 [INFO] train episode 276: reward = 77.00, steps = 77
# 00:02:27 [INFO] train episode 277: reward = 94.00, steps = 94
# 00:02:27 [INFO] train episode 278: reward = 86.00, steps = 86
# 00:02:27 [INFO] train episode 279: reward = 94.00, steps = 94
# 00:02:27 [INFO] train episode 280: reward = 129.00, steps = 129
# 00:02:27 [INFO] train episode 281: reward = 99.00, steps = 99
# 00:02:27 [INFO] train episode 282: reward = 37.00, steps = 37
# 00:02:27 [INFO] train episode 283: reward = 50.00, steps = 50
# 00:02:27 [INFO] train episode 284: reward = 50.00, steps = 50
# 00:02:27 [INFO] train episode 285: reward = 139.00, steps = 139
# 00:02:27 [INFO] train episode 286: reward = 52.00, steps = 52
# 00:02:28 [INFO] train episode 287: reward = 51.00, steps = 51
# 00:02:28 [INFO] train episode 288: reward = 68.00, steps = 68
# 00:02:28 [INFO] train episode 289: reward = 46.00, steps = 46
# 00:02:28 [INFO] train episode 290: reward = 77.00, steps = 77
# 00:02:28 [INFO] train episode 291: reward = 65.00, steps = 65
# 00:02:28 [INFO] train episode 292: reward = 45.00, steps = 45
# 00:02:28 [INFO] train episode 293: reward = 91.00, steps = 91
# 00:02:28 [INFO] train episode 294: reward = 48.00, steps = 48
# 00:02:28 [INFO] train episode 295: reward = 78.00, steps = 78
# 00:02:28 [INFO] train episode 296: reward = 56.00, steps = 56
# 00:02:28 [INFO] train episode 297: reward = 80.00, steps = 80
# 00:02:28 [INFO] train episode 298: reward = 67.00, steps = 67
# 00:02:28 [INFO] train episode 299: reward = 92.00, steps = 92
# 00:02:28 [INFO] train episode 300: reward = 61.00, steps = 61
# 00:02:28 [INFO] train episode 301: reward = 54.00, steps = 54
# 00:02:28 [INFO] train episode 302: reward = 62.00, steps = 62
# 00:02:28 [INFO] train episode 303: reward = 64.00, steps = 64
# 00:02:28 [INFO] train episode 304: reward = 55.00, steps = 55
# 00:02:28 [INFO] train episode 305: reward = 64.00, steps = 64
# 00:02:28 [INFO] train episode 306: reward = 63.00, steps = 63
# 00:02:28 [INFO] train episode 307: reward = 66.00, steps = 66
# 00:02:28 [INFO] train episode 308: reward = 44.00, steps = 44
# 00:02:28 [INFO] train episode 309: reward = 66.00, steps = 66
# 00:02:28 [INFO] train episode 310: reward = 59.00, steps = 59
# 00:02:28 [INFO] train episode 311: reward = 31.00, steps = 31
# 00:02:28 [INFO] train episode 312: reward = 54.00, steps = 54
# 00:02:28 [INFO] train episode 313: reward = 71.00, steps = 71
# 00:02:28 [INFO] train episode 314: reward = 53.00, steps = 53
# 00:02:28 [INFO] train episode 315: reward = 48.00, steps = 48
# 00:02:28 [INFO] train episode 316: reward = 78.00, steps = 78
# 00:02:28 [INFO] train episode 317: reward = 53.00, steps = 53
# 00:02:28 [INFO] train episode 318: reward = 47.00, steps = 47
# 00:02:28 [INFO] train episode 319: reward = 62.00, steps = 62
# 00:02:28 [INFO] train episode 320: reward = 44.00, steps = 44
# 00:02:28 [INFO] train episode 321: reward = 40.00, steps = 40
# 00:02:28 [INFO] train episode 322: reward = 23.00, steps = 23
# 00:02:28 [INFO] train episode 323: reward = 61.00, steps = 61
# 00:02:28 [INFO] train episode 324: reward = 40.00, steps = 40
# 00:02:28 [INFO] train episode 325: reward = 65.00, steps = 65
# 00:02:28 [INFO] train episode 326: reward = 46.00, steps = 46
# 00:02:28 [INFO] train episode 327: reward = 63.00, steps = 63
# 00:02:28 [INFO] train episode 328: reward = 56.00, steps = 56
# 00:02:28 [INFO] train episode 329: reward = 74.00, steps = 74
# 00:02:28 [INFO] train episode 330: reward = 47.00, steps = 47
# 00:02:28 [INFO] train episode 331: reward = 77.00, steps = 77
# 00:02:28 [INFO] train episode 332: reward = 61.00, steps = 61
# 00:02:28 [INFO] train episode 333: reward = 65.00, steps = 65
# 00:02:28 [INFO] train episode 334: reward = 81.00, steps = 81
# 00:02:29 [INFO] train episode 335: reward = 53.00, steps = 53
# 00:02:29 [INFO] train episode 336: reward = 43.00, steps = 43
# 00:02:29 [INFO] train episode 337: reward = 80.00, steps = 80
# 00:02:29 [INFO] train episode 338: reward = 48.00, steps = 48
# 00:02:29 [INFO] train episode 339: reward = 53.00, steps = 53
# 00:02:29 [INFO] train episode 340: reward = 74.00, steps = 74
# 00:02:29 [INFO] train episode 341: reward = 82.00, steps = 82
# 00:02:29 [INFO] train episode 342: reward = 93.00, steps = 93
# 00:02:29 [INFO] train episode 343: reward = 57.00, steps = 57
# 00:02:29 [INFO] train episode 344: reward = 62.00, steps = 62
# 00:02:29 [INFO] train episode 345: reward = 62.00, steps = 62
# 00:02:29 [INFO] train episode 346: reward = 59.00, steps = 59
# 00:02:29 [INFO] train episode 347: reward = 80.00, steps = 80
# 00:02:29 [INFO] train episode 348: reward = 71.00, steps = 71
# 00:02:29 [INFO] train episode 349: reward = 90.00, steps = 90
# 00:02:29 [INFO] train episode 350: reward = 54.00, steps = 54
# 00:02:29 [INFO] train episode 351: reward = 60.00, steps = 60
# 00:02:29 [INFO] train episode 352: reward = 45.00, steps = 45
# 00:02:29 [INFO] train episode 353: reward = 126.00, steps = 126
# 00:02:29 [INFO] train episode 354: reward = 66.00, steps = 66
# 00:02:29 [INFO] train episode 355: reward = 53.00, steps = 53
# 00:02:29 [INFO] train episode 356: reward = 67.00, steps = 67
# 00:02:29 [INFO] train episode 357: reward = 42.00, steps = 42
# 00:02:29 [INFO] train episode 358: reward = 119.00, steps = 119
# 00:02:29 [INFO] train episode 359: reward = 52.00, steps = 52
# 00:02:29 [INFO] train episode 360: reward = 45.00, steps = 45
# 00:02:29 [INFO] train episode 361: reward = 46.00, steps = 46
# 00:02:29 [INFO] train episode 362: reward = 52.00, steps = 52
# 00:02:29 [INFO] train episode 363: reward = 41.00, steps = 41
# 00:02:29 [INFO] train episode 364: reward = 58.00, steps = 58
# 00:02:29 [INFO] train episode 365: reward = 79.00, steps = 79
# 00:02:29 [INFO] train episode 366: reward = 66.00, steps = 66
# 00:02:29 [INFO] train episode 367: reward = 53.00, steps = 53
# 00:02:29 [INFO] train episode 368: reward = 61.00, steps = 61
# 00:02:29 [INFO] train episode 369: reward = 36.00, steps = 36
# 00:02:29 [INFO] train episode 370: reward = 71.00, steps = 71
# 00:02:29 [INFO] train episode 371: reward = 45.00, steps = 45
# 00:02:29 [INFO] train episode 372: reward = 33.00, steps = 33
# 00:02:29 [INFO] train episode 373: reward = 90.00, steps = 90
# 00:02:29 [INFO] train episode 374: reward = 51.00, steps = 51
# 00:02:29 [INFO] train episode 375: reward = 55.00, steps = 55
# 00:02:29 [INFO] train episode 376: reward = 112.00, steps = 112
# 00:02:29 [INFO] train episode 377: reward = 104.00, steps = 104
# 00:02:29 [INFO] train episode 378: reward = 63.00, steps = 63
# 00:02:29 [INFO] train episode 379: reward = 90.00, steps = 90
# 00:02:30 [INFO] train episode 380: reward = 30.00, steps = 30
# 00:02:30 [INFO] train episode 381: reward = 68.00, steps = 68
# 00:02:30 [INFO] train episode 382: reward = 47.00, steps = 47
# 00:02:30 [INFO] train episode 383: reward = 71.00, steps = 71
# 00:02:30 [INFO] train episode 384: reward = 59.00, steps = 59
# 00:02:30 [INFO] train episode 385: reward = 121.00, steps = 121
# 00:02:30 [INFO] train episode 386: reward = 45.00, steps = 45
# 00:02:30 [INFO] train episode 387: reward = 57.00, steps = 57
# 00:02:30 [INFO] train episode 388: reward = 88.00, steps = 88
# 00:02:30 [INFO] train episode 389: reward = 84.00, steps = 84
# 00:02:30 [INFO] train episode 390: reward = 29.00, steps = 29
# 00:02:30 [INFO] train episode 391: reward = 77.00, steps = 77
# 00:02:30 [INFO] train episode 392: reward = 45.00, steps = 45
# 00:02:30 [INFO] train episode 393: reward = 46.00, steps = 46
# 00:02:30 [INFO] train episode 394: reward = 101.00, steps = 101
# 00:02:30 [INFO] train episode 395: reward = 37.00, steps = 37
# 00:02:30 [INFO] train episode 396: reward = 80.00, steps = 80
# 00:02:30 [INFO] train episode 397: reward = 94.00, steps = 94
# 00:02:30 [INFO] train episode 398: reward = 80.00, steps = 80
# 00:02:30 [INFO] train episode 399: reward = 63.00, steps = 63
# 00:02:30 [INFO] train episode 400: reward = 33.00, steps = 33
# 00:02:30 [INFO] train episode 401: reward = 85.00, steps = 85
# 00:02:30 [INFO] train episode 402: reward = 47.00, steps = 47
# 00:02:30 [INFO] train episode 403: reward = 47.00, steps = 47
# 00:02:30 [INFO] train episode 404: reward = 113.00, steps = 113
# 00:02:30 [INFO] train episode 405: reward = 52.00, steps = 52
# 00:02:30 [INFO] train episode 406: reward = 50.00, steps = 50
# 00:02:30 [INFO] train episode 407: reward = 42.00, steps = 42
# 00:02:30 [INFO] train episode 408: reward = 49.00, steps = 49
# 00:02:30 [INFO] train episode 409: reward = 67.00, steps = 67
# 00:02:30 [INFO] train episode 410: reward = 99.00, steps = 99
# 00:02:30 [INFO] train episode 411: reward = 73.00, steps = 73
# 00:02:30 [INFO] train episode 412: reward = 59.00, steps = 59
# 00:02:30 [INFO] train episode 413: reward = 26.00, steps = 26
# 00:02:30 [INFO] train episode 414: reward = 47.00, steps = 47
# 00:02:30 [INFO] train episode 415: reward = 86.00, steps = 86
# 00:02:30 [INFO] train episode 416: reward = 97.00, steps = 97
# 00:02:30 [INFO] train episode 417: reward = 59.00, steps = 59
# 00:02:30 [INFO] train episode 418: reward = 53.00, steps = 53
# 00:02:30 [INFO] train episode 419: reward = 71.00, steps = 71
# 00:02:30 [INFO] train episode 420: reward = 53.00, steps = 53
# 00:02:30 [INFO] train episode 421: reward = 79.00, steps = 79
# 00:02:30 [INFO] train episode 422: reward = 39.00, steps = 39
# 00:02:30 [INFO] train episode 423: reward = 150.00, steps = 150
# 00:02:30 [INFO] train episode 424: reward = 50.00, steps = 50
# 00:02:31 [INFO] train episode 425: reward = 64.00, steps = 64
# 00:02:31 [INFO] train episode 426: reward = 58.00, steps = 58
# 00:02:31 [INFO] train episode 427: reward = 61.00, steps = 61
# 00:02:31 [INFO] train episode 428: reward = 90.00, steps = 90
# 00:02:31 [INFO] train episode 429: reward = 50.00, steps = 50
# 00:02:31 [INFO] train episode 430: reward = 117.00, steps = 117
# 00:02:31 [INFO] train episode 431: reward = 82.00, steps = 82
# 00:02:31 [INFO] train episode 432: reward = 85.00, steps = 85
# 00:02:31 [INFO] train episode 433: reward = 60.00, steps = 60
# 00:02:31 [INFO] train episode 434: reward = 111.00, steps = 111
# 00:02:31 [INFO] train episode 435: reward = 44.00, steps = 44
# 00:02:31 [INFO] train episode 436: reward = 81.00, steps = 81
# 00:02:31 [INFO] train episode 437: reward = 63.00, steps = 63
# 00:02:31 [INFO] train episode 438: reward = 56.00, steps = 56
# 00:02:31 [INFO] train episode 439: reward = 115.00, steps = 115
# 00:02:31 [INFO] train episode 440: reward = 78.00, steps = 78
# 00:02:31 [INFO] train episode 441: reward = 57.00, steps = 57
# 00:02:31 [INFO] train episode 442: reward = 93.00, steps = 93
# 00:02:31 [INFO] train episode 443: reward = 104.00, steps = 104
# 00:02:31 [INFO] train episode 444: reward = 70.00, steps = 70
# 00:02:31 [INFO] train episode 445: reward = 44.00, steps = 44
# 00:02:31 [INFO] train episode 446: reward = 59.00, steps = 59
# 00:02:31 [INFO] train episode 447: reward = 87.00, steps = 87
# 00:02:31 [INFO] train episode 448: reward = 43.00, steps = 43
# 00:02:31 [INFO] train episode 449: reward = 55.00, steps = 55
# 00:02:31 [INFO] train episode 450: reward = 60.00, steps = 60
# 00:02:31 [INFO] train episode 451: reward = 49.00, steps = 49
# 00:02:31 [INFO] train episode 452: reward = 84.00, steps = 84
# 00:02:31 [INFO] train episode 453: reward = 47.00, steps = 47
# 00:02:31 [INFO] train episode 454: reward = 70.00, steps = 70
# 00:02:31 [INFO] train episode 455: reward = 63.00, steps = 63
# 00:02:31 [INFO] train episode 456: reward = 78.00, steps = 78
# 00:02:31 [INFO] train episode 457: reward = 85.00, steps = 85
# 00:02:31 [INFO] train episode 458: reward = 65.00, steps = 65
# 00:02:31 [INFO] train episode 459: reward = 88.00, steps = 88
# 00:02:31 [INFO] train episode 460: reward = 87.00, steps = 87
# 00:02:31 [INFO] train episode 461: reward = 67.00, steps = 67
# 00:02:31 [INFO] train episode 462: reward = 61.00, steps = 61
# 00:02:31 [INFO] train episode 463: reward = 69.00, steps = 69
# 00:02:31 [INFO] train episode 464: reward = 52.00, steps = 52
# 00:02:31 [INFO] train episode 465: reward = 69.00, steps = 69
# 00:02:31 [INFO] train episode 466: reward = 62.00, steps = 62
# 00:02:32 [INFO] train episode 467: reward = 71.00, steps = 71
# 00:02:32 [INFO] train episode 468: reward = 75.00, steps = 75
# 00:02:32 [INFO] train episode 469: reward = 141.00, steps = 141
# 00:02:32 [INFO] train episode 470: reward = 57.00, steps = 57
# 00:02:32 [INFO] train episode 471: reward = 48.00, steps = 48
# 00:02:32 [INFO] train episode 472: reward = 123.00, steps = 123
# 00:02:32 [INFO] train episode 473: reward = 83.00, steps = 83
# 00:02:32 [INFO] train episode 474: reward = 96.00, steps = 96
# 00:02:32 [INFO] train episode 475: reward = 43.00, steps = 43
# 00:02:32 [INFO] train episode 476: reward = 51.00, steps = 51
# 00:02:32 [INFO] train episode 477: reward = 73.00, steps = 73
# 00:02:32 [INFO] train episode 478: reward = 67.00, steps = 67
# 00:02:32 [INFO] train episode 479: reward = 63.00, steps = 63
# 00:02:32 [INFO] train episode 480: reward = 56.00, steps = 56
# 00:02:32 [INFO] train episode 481: reward = 84.00, steps = 84
# 00:02:32 [INFO] train episode 482: reward = 57.00, steps = 57
# 00:02:32 [INFO] train episode 483: reward = 45.00, steps = 45
# 00:02:32 [INFO] train episode 484: reward = 103.00, steps = 103
# 00:02:32 [INFO] train episode 485: reward = 59.00, steps = 59
# 00:02:32 [INFO] train episode 486: reward = 100.00, steps = 100
# 00:02:32 [INFO] train episode 487: reward = 50.00, steps = 50
# 00:02:32 [INFO] train episode 488: reward = 70.00, steps = 70
# 00:02:32 [INFO] train episode 489: reward = 62.00, steps = 62
# 00:02:32 [INFO] train episode 490: reward = 59.00, steps = 59
# 00:02:32 [INFO] train episode 491: reward = 71.00, steps = 71
# 00:02:32 [INFO] train episode 492: reward = 49.00, steps = 49
# 00:02:32 [INFO] train episode 493: reward = 70.00, steps = 70
# 00:02:32 [INFO] train episode 494: reward = 78.00, steps = 78
# 00:02:32 [INFO] train episode 495: reward = 81.00, steps = 81
# 00:02:32 [INFO] train episode 496: reward = 52.00, steps = 52
# 00:02:32 [INFO] train episode 497: reward = 44.00, steps = 44
# 00:02:32 [INFO] train episode 498: reward = 78.00, steps = 78
# 00:02:32 [INFO] train episode 499: reward = 51.00, steps = 51
# 00:02:32 [INFO] train episode 500: reward = 60.00, steps = 60
# 00:02:32 [INFO] train episode 501: reward = 52.00, steps = 52
# 00:02:32 [INFO] train episode 502: reward = 69.00, steps = 69
# 00:02:32 [INFO] train episode 503: reward = 74.00, steps = 74
# 00:02:32 [INFO] train episode 504: reward = 44.00, steps = 44
# 00:02:32 [INFO] train episode 505: reward = 81.00, steps = 81
# 00:02:32 [INFO] train episode 506: reward = 78.00, steps = 78
# 00:02:32 [INFO] train episode 507: reward = 38.00, steps = 38
# 00:02:32 [INFO] train episode 508: reward = 56.00, steps = 56
# 00:02:32 [INFO] train episode 509: reward = 58.00, steps = 58
# 00:02:33 [INFO] train episode 510: reward = 46.00, steps = 46
# 00:02:33 [INFO] train episode 511: reward = 88.00, steps = 88
# 00:02:33 [INFO] train episode 512: reward = 81.00, steps = 81
# 00:02:33 [INFO] train episode 513: reward = 68.00, steps = 68
# 00:02:33 [INFO] train episode 514: reward = 87.00, steps = 87
# 00:02:33 [INFO] train episode 515: reward = 79.00, steps = 79
# 00:02:33 [INFO] train episode 516: reward = 48.00, steps = 48
# 00:02:33 [INFO] train episode 517: reward = 73.00, steps = 73
# 00:02:33 [INFO] train episode 518: reward = 138.00, steps = 138
# 00:02:33 [INFO] train episode 519: reward = 63.00, steps = 63
# 00:02:33 [INFO] train episode 520: reward = 64.00, steps = 64
# 00:02:33 [INFO] train episode 521: reward = 56.00, steps = 56
# 00:02:33 [INFO] train episode 522: reward = 52.00, steps = 52
# 00:02:33 [INFO] train episode 523: reward = 102.00, steps = 102
# 00:02:33 [INFO] train episode 524: reward = 64.00, steps = 64
# 00:02:33 [INFO] train episode 525: reward = 51.00, steps = 51
# 00:02:33 [INFO] train episode 526: reward = 47.00, steps = 47
# 00:02:33 [INFO] train episode 527: reward = 83.00, steps = 83
# 00:02:33 [INFO] train episode 528: reward = 75.00, steps = 75
# 00:02:33 [INFO] train episode 529: reward = 84.00, steps = 84
# 00:02:33 [INFO] train episode 530: reward = 66.00, steps = 66
# 00:02:33 [INFO] train episode 531: reward = 77.00, steps = 77
# 00:02:33 [INFO] train episode 532: reward = 52.00, steps = 52
# 00:02:33 [INFO] train episode 533: reward = 51.00, steps = 51
# 00:02:33 [INFO] train episode 534: reward = 73.00, steps = 73
# 00:02:33 [INFO] train episode 535: reward = 77.00, steps = 77
# 00:02:33 [INFO] train episode 536: reward = 81.00, steps = 81
# 00:02:33 [INFO] train episode 537: reward = 42.00, steps = 42
# 00:02:33 [INFO] train episode 538: reward = 126.00, steps = 126
# 00:02:33 [INFO] train episode 539: reward = 47.00, steps = 47
# 00:02:33 [INFO] train episode 540: reward = 44.00, steps = 44
# 00:02:33 [INFO] train episode 541: reward = 92.00, steps = 92
# 00:02:33 [INFO] train episode 542: reward = 75.00, steps = 75
# 00:02:33 [INFO] train episode 543: reward = 72.00, steps = 72
# 00:02:33 [INFO] train episode 544: reward = 54.00, steps = 54
# 00:02:33 [INFO] train episode 545: reward = 75.00, steps = 75
# 00:02:33 [INFO] train episode 546: reward = 80.00, steps = 80
# 00:02:33 [INFO] train episode 547: reward = 60.00, steps = 60
# 00:02:33 [INFO] train episode 548: reward = 75.00, steps = 75
# 00:02:33 [INFO] train episode 549: reward = 52.00, steps = 52
# 00:02:34 [INFO] train episode 550: reward = 197.00, steps = 197
# 00:02:34 [INFO] train episode 551: reward = 64.00, steps = 64
# 00:02:34 [INFO] train episode 552: reward = 93.00, steps = 93
# 00:02:34 [INFO] train episode 553: reward = 59.00, steps = 59
# 00:02:34 [INFO] train episode 554: reward = 80.00, steps = 80
# 00:02:34 [INFO] train episode 555: reward = 47.00, steps = 47
# 00:02:34 [INFO] train episode 556: reward = 76.00, steps = 76
# 00:02:34 [INFO] train episode 557: reward = 77.00, steps = 77
# 00:02:34 [INFO] train episode 558: reward = 108.00, steps = 108
# 00:02:34 [INFO] train episode 559: reward = 57.00, steps = 57
# 00:02:34 [INFO] train episode 560: reward = 136.00, steps = 136
# 00:02:34 [INFO] train episode 561: reward = 85.00, steps = 85
# 00:02:34 [INFO] train episode 562: reward = 77.00, steps = 77
# 00:02:34 [INFO] train episode 563: reward = 70.00, steps = 70
# 00:02:34 [INFO] train episode 564: reward = 44.00, steps = 44
# 00:02:34 [INFO] train episode 565: reward = 59.00, steps = 59
# 00:02:34 [INFO] train episode 566: reward = 65.00, steps = 65
# 00:02:34 [INFO] train episode 567: reward = 116.00, steps = 116
# 00:02:34 [INFO] train episode 568: reward = 104.00, steps = 104
# 00:02:34 [INFO] train episode 569: reward = 60.00, steps = 60
# 00:02:34 [INFO] train episode 570: reward = 73.00, steps = 73
# 00:02:34 [INFO] train episode 571: reward = 50.00, steps = 50
# 00:02:34 [INFO] train episode 572: reward = 48.00, steps = 48
# 00:02:34 [INFO] train episode 573: reward = 59.00, steps = 59
# 00:02:34 [INFO] train episode 574: reward = 110.00, steps = 110
# 00:02:34 [INFO] train episode 575: reward = 76.00, steps = 76
# 00:02:34 [INFO] train episode 576: reward = 42.00, steps = 42
# 00:02:34 [INFO] train episode 577: reward = 52.00, steps = 52
# 00:02:34 [INFO] train episode 578: reward = 98.00, steps = 98
# 00:02:34 [INFO] train episode 579: reward = 62.00, steps = 62
# 00:02:34 [INFO] train episode 580: reward = 188.00, steps = 188
# 00:02:34 [INFO] train episode 581: reward = 55.00, steps = 55
# 00:02:34 [INFO] train episode 582: reward = 66.00, steps = 66
# 00:02:34 [INFO] train episode 583: reward = 70.00, steps = 70
# 00:02:34 [INFO] train episode 584: reward = 68.00, steps = 68
# 00:02:34 [INFO] train episode 585: reward = 55.00, steps = 55
# 00:02:34 [INFO] train episode 586: reward = 83.00, steps = 83
# 00:02:34 [INFO] train episode 587: reward = 74.00, steps = 74
# 00:02:34 [INFO] train episode 588: reward = 76.00, steps = 76
# 00:02:35 [INFO] train episode 589: reward = 61.00, steps = 61
# 00:02:35 [INFO] train episode 590: reward = 80.00, steps = 80
# 00:02:35 [INFO] train episode 591: reward = 85.00, steps = 85
# 00:02:35 [INFO] train episode 592: reward = 89.00, steps = 89
# 00:02:35 [INFO] train episode 593: reward = 69.00, steps = 69
# 00:02:35 [INFO] train episode 594: reward = 62.00, steps = 62
# 00:02:35 [INFO] train episode 595: reward = 53.00, steps = 53
# 00:02:35 [INFO] train episode 596: reward = 61.00, steps = 61
# 00:02:35 [INFO] train episode 597: reward = 60.00, steps = 60
# 00:02:35 [INFO] train episode 598: reward = 94.00, steps = 94
# 00:02:35 [INFO] train episode 599: reward = 84.00, steps = 84
# 00:02:35 [INFO] train episode 600: reward = 73.00, steps = 73
# 00:02:35 [INFO] train episode 601: reward = 66.00, steps = 66
# 00:02:35 [INFO] train episode 602: reward = 127.00, steps = 127
# 00:02:35 [INFO] train episode 603: reward = 52.00, steps = 52
# 00:02:35 [INFO] train episode 604: reward = 60.00, steps = 60
# 00:02:35 [INFO] train episode 605: reward = 84.00, steps = 84
# 00:02:35 [INFO] train episode 606: reward = 75.00, steps = 75
# 00:02:35 [INFO] train episode 607: reward = 79.00, steps = 79
# 00:02:35 [INFO] train episode 608: reward = 80.00, steps = 80
# 00:02:35 [INFO] train episode 609: reward = 62.00, steps = 62
# 00:02:35 [INFO] train episode 610: reward = 70.00, steps = 70
# 00:02:35 [INFO] train episode 611: reward = 78.00, steps = 78
# 00:02:35 [INFO] train episode 612: reward = 90.00, steps = 90
# 00:02:35 [INFO] train episode 613: reward = 62.00, steps = 62
# 00:02:35 [INFO] train episode 614: reward = 74.00, steps = 74
# 00:02:35 [INFO] train episode 615: reward = 59.00, steps = 59
# 00:02:35 [INFO] train episode 616: reward = 94.00, steps = 94
# 00:02:35 [INFO] train episode 617: reward = 50.00, steps = 50
# 00:02:35 [INFO] train episode 618: reward = 46.00, steps = 46
# 00:02:35 [INFO] train episode 619: reward = 58.00, steps = 58
# 00:02:35 [INFO] train episode 620: reward = 84.00, steps = 84
# 00:02:35 [INFO] train episode 621: reward = 93.00, steps = 93
# 00:02:35 [INFO] train episode 622: reward = 62.00, steps = 62
# 00:02:35 [INFO] train episode 623: reward = 63.00, steps = 63
# 00:02:35 [INFO] train episode 624: reward = 107.00, steps = 107
# 00:02:35 [INFO] train episode 625: reward = 38.00, steps = 38
# 00:02:35 [INFO] train episode 626: reward = 56.00, steps = 56
# 00:02:35 [INFO] train episode 627: reward = 90.00, steps = 90
# 00:02:35 [INFO] train episode 628: reward = 39.00, steps = 39
# 00:02:35 [INFO] train episode 629: reward = 143.00, steps = 143
# 00:02:35 [INFO] train episode 630: reward = 62.00, steps = 62
# 00:02:36 [INFO] train episode 631: reward = 61.00, steps = 61
# 00:02:36 [INFO] train episode 632: reward = 131.00, steps = 131
# 00:02:36 [INFO] train episode 633: reward = 71.00, steps = 71
# 00:02:36 [INFO] train episode 634: reward = 60.00, steps = 60
# 00:02:36 [INFO] train episode 635: reward = 65.00, steps = 65
# 00:02:36 [INFO] train episode 636: reward = 72.00, steps = 72
# 00:02:36 [INFO] train episode 637: reward = 69.00, steps = 69
# 00:02:36 [INFO] train episode 638: reward = 69.00, steps = 69
# 00:02:36 [INFO] train episode 639: reward = 50.00, steps = 50
# 00:02:36 [INFO] train episode 640: reward = 48.00, steps = 48
# 00:02:36 [INFO] train episode 641: reward = 64.00, steps = 64
# 00:02:36 [INFO] train episode 642: reward = 156.00, steps = 156
# 00:02:36 [INFO] train episode 643: reward = 85.00, steps = 85
# 00:02:36 [INFO] train episode 644: reward = 95.00, steps = 95
# 00:02:36 [INFO] train episode 645: reward = 64.00, steps = 64
# 00:02:36 [INFO] train episode 646: reward = 111.00, steps = 111
# 00:02:36 [INFO] train episode 647: reward = 66.00, steps = 66
# 00:02:36 [INFO] train episode 648: reward = 96.00, steps = 96
# 00:02:36 [INFO] train episode 649: reward = 61.00, steps = 61
# 00:02:36 [INFO] train episode 650: reward = 83.00, steps = 83
# 00:02:36 [INFO] train episode 651: reward = 66.00, steps = 66
# 00:02:36 [INFO] train episode 652: reward = 60.00, steps = 60
# 00:02:36 [INFO] train episode 653: reward = 67.00, steps = 67
# 00:02:36 [INFO] train episode 654: reward = 85.00, steps = 85
# 00:02:36 [INFO] train episode 655: reward = 105.00, steps = 105
# 00:02:36 [INFO] train episode 656: reward = 78.00, steps = 78
# 00:02:36 [INFO] train episode 657: reward = 79.00, steps = 79
# 00:02:36 [INFO] train episode 658: reward = 74.00, steps = 74
# 00:02:36 [INFO] train episode 659: reward = 50.00, steps = 50
# 00:02:36 [INFO] train episode 660: reward = 59.00, steps = 59
# 00:02:36 [INFO] train episode 661: reward = 107.00, steps = 107
# 00:02:36 [INFO] train episode 662: reward = 92.00, steps = 92
# 00:02:36 [INFO] train episode 663: reward = 97.00, steps = 97
# 00:02:36 [INFO] train episode 664: reward = 50.00, steps = 50
# 00:02:36 [INFO] train episode 665: reward = 54.00, steps = 54
# 00:02:36 [INFO] train episode 666: reward = 123.00, steps = 123
# 00:02:36 [INFO] train episode 667: reward = 71.00, steps = 71
# 00:02:36 [INFO] train episode 668: reward = 63.00, steps = 63
# 00:02:37 [INFO] train episode 669: reward = 129.00, steps = 129
# 00:02:37 [INFO] train episode 670: reward = 57.00, steps = 57
# 00:02:37 [INFO] train episode 671: reward = 58.00, steps = 58
# 00:02:37 [INFO] train episode 672: reward = 175.00, steps = 175
# 00:02:37 [INFO] train episode 673: reward = 98.00, steps = 98
# 00:02:37 [INFO] train episode 674: reward = 64.00, steps = 64
# 00:02:37 [INFO] train episode 675: reward = 73.00, steps = 73
# 00:02:37 [INFO] train episode 676: reward = 46.00, steps = 46
# 00:02:37 [INFO] train episode 677: reward = 64.00, steps = 64
# 00:02:37 [INFO] train episode 678: reward = 72.00, steps = 72
# 00:02:37 [INFO] train episode 679: reward = 79.00, steps = 79
# 00:02:37 [INFO] train episode 680: reward = 80.00, steps = 80
# 00:02:37 [INFO] train episode 681: reward = 48.00, steps = 48
# 00:02:37 [INFO] train episode 682: reward = 58.00, steps = 58
# 00:02:37 [INFO] train episode 683: reward = 61.00, steps = 61
# 00:02:37 [INFO] train episode 684: reward = 81.00, steps = 81
# 00:02:37 [INFO] train episode 685: reward = 72.00, steps = 72
# 00:02:37 [INFO] train episode 686: reward = 81.00, steps = 81
# 00:02:37 [INFO] train episode 687: reward = 102.00, steps = 102
# 00:02:37 [INFO] train episode 688: reward = 80.00, steps = 80
# 00:02:37 [INFO] train episode 689: reward = 82.00, steps = 82
# 00:02:37 [INFO] train episode 690: reward = 82.00, steps = 82
# 00:02:37 [INFO] train episode 691: reward = 65.00, steps = 65
# 00:02:37 [INFO] train episode 692: reward = 78.00, steps = 78
# 00:02:37 [INFO] train episode 693: reward = 58.00, steps = 58
# 00:02:37 [INFO] train episode 694: reward = 75.00, steps = 75
# 00:02:37 [INFO] train episode 695: reward = 58.00, steps = 58
# 00:02:37 [INFO] train episode 696: reward = 67.00, steps = 67
# 00:02:37 [INFO] train episode 697: reward = 81.00, steps = 81
# 00:02:37 [INFO] train episode 698: reward = 80.00, steps = 80
# 00:02:37 [INFO] train episode 699: reward = 70.00, steps = 70
# 00:02:37 [INFO] train episode 700: reward = 66.00, steps = 66
# 00:02:37 [INFO] train episode 701: reward = 94.00, steps = 94
# 00:02:37 [INFO] train episode 702: reward = 54.00, steps = 54
# 00:02:37 [INFO] train episode 703: reward = 87.00, steps = 87
# 00:02:37 [INFO] train episode 704: reward = 110.00, steps = 110
# 00:02:37 [INFO] train episode 705: reward = 82.00, steps = 82
# 00:02:37 [INFO] train episode 706: reward = 67.00, steps = 67
# 00:02:37 [INFO] train episode 707: reward = 75.00, steps = 75
# 00:02:37 [INFO] train episode 708: reward = 81.00, steps = 81
# 00:02:37 [INFO] train episode 709: reward = 62.00, steps = 62
# 00:02:38 [INFO] train episode 710: reward = 69.00, steps = 69
# 00:02:38 [INFO] train episode 711: reward = 132.00, steps = 132
# 00:02:38 [INFO] train episode 712: reward = 96.00, steps = 96
# 00:02:38 [INFO] train episode 713: reward = 53.00, steps = 53
# 00:02:38 [INFO] train episode 714: reward = 41.00, steps = 41
# 00:02:38 [INFO] train episode 715: reward = 54.00, steps = 54
# 00:02:38 [INFO] train episode 716: reward = 48.00, steps = 48
# 00:02:38 [INFO] train episode 717: reward = 116.00, steps = 116
# 00:02:38 [INFO] train episode 718: reward = 53.00, steps = 53
# 00:02:38 [INFO] train episode 719: reward = 96.00, steps = 96
# 00:02:38 [INFO] train episode 720: reward = 65.00, steps = 65
# 00:02:38 [INFO] train episode 721: reward = 58.00, steps = 58
# 00:02:38 [INFO] train episode 722: reward = 88.00, steps = 88
# 00:02:38 [INFO] train episode 723: reward = 70.00, steps = 70
# 00:02:38 [INFO] train episode 724: reward = 45.00, steps = 45
# 00:02:38 [INFO] train episode 725: reward = 80.00, steps = 80
# 00:02:38 [INFO] train episode 726: reward = 111.00, steps = 111
# 00:02:38 [INFO] train episode 727: reward = 113.00, steps = 113
# 00:02:38 [INFO] train episode 728: reward = 83.00, steps = 83
# 00:02:38 [INFO] train episode 729: reward = 141.00, steps = 141
# 00:02:38 [INFO] train episode 730: reward = 71.00, steps = 71
# 00:02:38 [INFO] train episode 731: reward = 102.00, steps = 102
# 00:02:38 [INFO] train episode 732: reward = 82.00, steps = 82
# 00:02:38 [INFO] train episode 733: reward = 71.00, steps = 71
# 00:02:38 [INFO] train episode 734: reward = 54.00, steps = 54
# 00:02:38 [INFO] train episode 735: reward = 116.00, steps = 116
# 00:02:38 [INFO] train episode 736: reward = 88.00, steps = 88
# 00:02:38 [INFO] train episode 737: reward = 68.00, steps = 68
# 00:02:38 [INFO] train episode 738: reward = 70.00, steps = 70
# 00:02:38 [INFO] train episode 739: reward = 110.00, steps = 110
# 00:02:38 [INFO] train episode 740: reward = 71.00, steps = 71
# 00:02:38 [INFO] train episode 741: reward = 56.00, steps = 56
# 00:02:38 [INFO] train episode 742: reward = 121.00, steps = 121
# 00:02:38 [INFO] train episode 743: reward = 104.00, steps = 104
# 00:02:38 [INFO] train episode 744: reward = 85.00, steps = 85
# 00:02:38 [INFO] train episode 745: reward = 55.00, steps = 55
# 00:02:38 [INFO] train episode 746: reward = 81.00, steps = 81
# 00:02:38 [INFO] train episode 747: reward = 81.00, steps = 81
# 00:02:39 [INFO] train episode 748: reward = 104.00, steps = 104
# 00:02:39 [INFO] train episode 749: reward = 62.00, steps = 62
# 00:02:39 [INFO] train episode 750: reward = 71.00, steps = 71
# 00:02:39 [INFO] train episode 751: reward = 168.00, steps = 168
# 00:02:39 [INFO] train episode 752: reward = 136.00, steps = 136
# 00:02:39 [INFO] train episode 753: reward = 133.00, steps = 133
# 00:02:39 [INFO] train episode 754: reward = 70.00, steps = 70
# 00:02:39 [INFO] train episode 755: reward = 100.00, steps = 100
# 00:02:39 [INFO] train episode 756: reward = 101.00, steps = 101
# 00:02:39 [INFO] train episode 757: reward = 70.00, steps = 70
# 00:02:39 [INFO] train episode 758: reward = 57.00, steps = 57
# 00:02:39 [INFO] train episode 759: reward = 60.00, steps = 60
# 00:02:39 [INFO] train episode 760: reward = 80.00, steps = 80
# 00:02:39 [INFO] train episode 761: reward = 79.00, steps = 79
# 00:02:39 [INFO] train episode 762: reward = 46.00, steps = 46
# 00:02:39 [INFO] train episode 763: reward = 72.00, steps = 72
# 00:02:39 [INFO] train episode 764: reward = 65.00, steps = 65
# 00:02:39 [INFO] train episode 765: reward = 66.00, steps = 66
# 00:02:39 [INFO] train episode 766: reward = 83.00, steps = 83
# 00:02:39 [INFO] train episode 767: reward = 67.00, steps = 67
# 00:02:39 [INFO] train episode 768: reward = 117.00, steps = 117
# 00:02:39 [INFO] train episode 769: reward = 200.00, steps = 200
# 00:02:39 [INFO] train episode 770: reward = 62.00, steps = 62
# 00:02:39 [INFO] train episode 771: reward = 144.00, steps = 144
# ...
# 00:06:55 [INFO] train episode 6217: reward = 200.00, steps = 200
# 00:06:55 [INFO] train episode 6218: reward = 178.00, steps = 178
# 00:06:55 [INFO] train episode 6219: reward = 196.00, steps = 196
# 00:06:55 [INFO] train episode 6220: reward = 191.00, steps = 191
# 00:06:56 [INFO] train episode 6221: reward = 200.00, steps = 200
# 00:06:56 [INFO] train episode 6222: reward = 200.00, steps = 200
# 00:06:56 [INFO] train episode 6223: reward = 200.00, steps = 200
# 00:06:56 [INFO] train episode 6224: reward = 200.00, steps = 200
# 00:06:56 [INFO] train episode 6225: reward = 177.00, steps = 177
# 00:06:56 [INFO] train episode 6226: reward = 200.00, steps = 200
# 00:06:56 [INFO] train episode 6227: reward = 194.00, steps = 194
# 00:06:56 [INFO] train episode 6228: reward = 190.00, steps = 190
# 00:06:56 [INFO] train episode 6229: reward = 200.00, steps = 200
# 00:06:56 [INFO] train episode 6230: reward = 200.00, steps = 200
# 00:06:56 [INFO] train episode 6231: reward = 187.00, steps = 187
# 00:06:56 [INFO] train episode 6232: reward = 199.00, steps = 199
# 00:06:56 [INFO] train episode 6233: reward = 190.00, steps = 190
# 00:06:56 [INFO] train episode 6234: reward = 200.00, steps = 200
# 00:06:56 [INFO] train episode 6235: reward = 192.00, steps = 192
# 00:06:56 [INFO] train episode 6236: reward = 200.00, steps = 200
# 00:06:56 [INFO] train episode 6237: reward = 170.00, steps = 170
# 00:06:56 [INFO] train episode 6238: reward = 200.00, steps = 200
# 00:06:57 [INFO] train episode 6239: reward = 200.00, steps = 200
# 00:06:57 [INFO] train episode 6240: reward = 200.00, steps = 200
# 00:06:57 [INFO] train episode 6241: reward = 200.00, steps = 200
# 00:06:57 [INFO] train episode 6242: reward = 195.00, steps = 195
# 00:06:57 [INFO] train episode 6243: reward = 200.00, steps = 200
# 00:06:57 [INFO] train episode 6244: reward = 156.00, steps = 156
# 00:06:57 [INFO] train episode 6245: reward = 200.00, steps = 200
# 00:06:57 [INFO] train episode 6246: reward = 200.00, steps = 200
# 00:06:57 [INFO] train episode 6247: reward = 153.00, steps = 153
# 00:06:57 [INFO] train episode 6248: reward = 175.00, steps = 175
# 00:06:57 [INFO] train episode 6249: reward = 200.00, steps = 200
# 00:06:57 [INFO] train episode 6250: reward = 185.00, steps = 185
# 00:06:57 [INFO] train episode 6251: reward = 152.00, steps = 152
# 00:06:57 [INFO] train episode 6252: reward = 200.00, steps = 200
# 00:06:57 [INFO] train episode 6253: reward = 194.00, steps = 194
# 00:06:57 [INFO] train episode 6254: reward = 171.00, steps = 171
# 00:06:57 [INFO] train episode 6255: reward = 200.00, steps = 200
# 00:06:58 [INFO] train episode 6256: reward = 181.00, steps = 181
# 00:06:58 [INFO] train episode 6257: reward = 166.00, steps = 166
# 00:06:58 [INFO] train episode 6258: reward = 200.00, steps = 200
# 00:06:58 [INFO] train episode 6259: reward = 191.00, steps = 191
# 00:06:58 [INFO] train episode 6260: reward = 200.00, steps = 200
# 00:06:58 [INFO] train episode 6261: reward = 198.00, steps = 198
# 00:06:58 [INFO] train episode 6262: reward = 184.00, steps = 184
# 00:06:58 [INFO] train episode 6263: reward = 200.00, steps = 200
# 00:06:58 [INFO] train episode 6264: reward = 200.00, steps = 200
# 00:06:58 [INFO] train episode 6265: reward = 154.00, steps = 154
# 00:06:58 [INFO] train episode 6266: reward = 200.00, steps = 200
# 00:06:58 [INFO] train episode 6267: reward = 164.00, steps = 164
# 00:06:58 [INFO] train episode 6268: reward = 200.00, steps = 200
# 00:06:58 [INFO] train episode 6269: reward = 200.00, steps = 200
# 00:06:58 [INFO] train episode 6270: reward = 200.00, steps = 200
# 00:06:58 [INFO] train episode 6271: reward = 200.00, steps = 200
# 00:06:58 [INFO] train episode 6272: reward = 162.00, steps = 162
# 00:06:58 [INFO] train episode 6273: reward = 160.00, steps = 160
# 00:06:59 [INFO] train episode 6274: reward = 200.00, steps = 200
# 00:06:59 [INFO] train episode 6275: reward = 200.00, steps = 200
# 00:06:59 [INFO] train episode 6276: reward = 197.00, steps = 197
# 00:06:59 [INFO] train episode 6277: reward = 196.00, steps = 196
# 00:06:59 [INFO] train episode 6278: reward = 161.00, steps = 161
# 00:06:59 [INFO] train episode 6279: reward = 172.00, steps = 172
# 00:06:59 [INFO] train episode 6280: reward = 138.00, steps = 138
# 00:06:59 [INFO] train episode 6281: reward = 161.00, steps = 161
# 00:06:59 [INFO] train episode 6282: reward = 200.00, steps = 200
# 00:06:59 [INFO] train episode 6283: reward = 155.00, steps = 155
# 00:06:59 [INFO] train episode 6284: reward = 177.00, steps = 177
# 00:06:59 [INFO] train episode 6285: reward = 196.00, steps = 196
# 00:06:59 [INFO] train episode 6286: reward = 200.00, steps = 200
# 00:06:59 [INFO] train episode 6287: reward = 158.00, steps = 158
# 00:06:59 [INFO] train episode 6288: reward = 150.00, steps = 150
# 00:06:59 [INFO] train episode 6289: reward = 200.00, steps = 200
# 00:06:59 [INFO] train episode 6290: reward = 191.00, steps = 191
# 00:06:59 [INFO] train episode 6291: reward = 185.00, steps = 185
# 00:06:59 [INFO] train episode 6292: reward = 193.00, steps = 193
# 00:07:00 [INFO] train episode 6293: reward = 200.00, steps = 200
# 00:07:00 [INFO] train episode 6294: reward = 177.00, steps = 177
# 00:07:00 [INFO] train episode 6295: reward = 200.00, steps = 200
# 00:07:00 [INFO] train episode 6296: reward = 200.00, steps = 200
# 00:07:00 [INFO] train episode 6297: reward = 200.00, steps = 200
# 00:07:00 [INFO] train episode 6298: reward = 200.00, steps = 200
# 00:07:00 [INFO] train episode 6299: reward = 200.00, steps = 200
# 00:07:00 [INFO] train episode 6300: reward = 200.00, steps = 200
# 00:07:00 [INFO] train episode 6301: reward = 169.00, steps = 169
# 00:07:00 [INFO] train episode 6302: reward = 200.00, steps = 200
# 00:07:00 [INFO] train episode 6303: reward = 200.00, steps = 200
# 00:07:00 [INFO] train episode 6304: reward = 200.00, steps = 200
# 00:07:00 [INFO] train episode 6305: reward = 200.00, steps = 200
# 00:07:00 [INFO] train episode 6306: reward = 177.00, steps = 177
# 00:07:00 [INFO] train episode 6307: reward = 200.00, steps = 200
# 00:07:00 [INFO] train episode 6308: reward = 200.00, steps = 200
# 00:07:00 [INFO] train episode 6309: reward = 200.00, steps = 200
# 00:07:01 [INFO] train episode 6310: reward = 190.00, steps = 190
# 00:07:01 [INFO] train episode 6311: reward = 200.00, steps = 200
# 00:07:01 [INFO] train episode 6312: reward = 182.00, steps = 182
# 00:07:01 [INFO] train episode 6313: reward = 200.00, steps = 200
# 00:07:01 [INFO] train episode 6314: reward = 200.00, steps = 200
# 00:07:01 [INFO] train episode 6315: reward = 200.00, steps = 200
# 00:07:01 [INFO] train episode 6316: reward = 200.00, steps = 200
# 00:07:01 [INFO] train episode 6317: reward = 200.00, steps = 200
# 00:07:01 [INFO] train episode 6318: reward = 200.00, steps = 200
# 00:07:01 [INFO] train episode 6319: reward = 200.00, steps = 200
# 00:07:01 [INFO] train episode 6320: reward = 200.00, steps = 200
# 00:07:01 [INFO] train episode 6321: reward = 200.00, steps = 200
# 00:07:01 [INFO] train episode 6322: reward = 200.00, steps = 200
# 00:07:01 [INFO] train episode 6323: reward = 200.00, steps = 200
# 00:07:01 [INFO] train episode 6324: reward = 200.00, steps = 200
# 00:07:01 [INFO] train episode 6325: reward = 200.00, steps = 200
# 00:07:02 [INFO] train episode 6326: reward = 200.00, steps = 200
# 00:07:02 [INFO] train episode 6327: reward = 166.00, steps = 166
# 00:07:02 [INFO] train episode 6328: reward = 200.00, steps = 200
# 00:07:02 [INFO] train episode 6329: reward = 200.00, steps = 200
# 00:07:02 [INFO] train episode 6330: reward = 197.00, steps = 197
# 00:07:02 [INFO] train episode 6331: reward = 191.00, steps = 191
# 00:07:02 [INFO] train episode 6332: reward = 200.00, steps = 200
# 00:07:02 [INFO] train episode 6333: reward = 200.00, steps = 200
# 00:07:02 [INFO] train episode 6334: reward = 200.00, steps = 200
# 00:07:02 [INFO] train episode 6335: reward = 200.00, steps = 200
# 00:07:02 [INFO] train episode 6336: reward = 195.00, steps = 195
# 00:07:02 [INFO] train episode 6337: reward = 172.00, steps = 172
# 00:07:02 [INFO] train episode 6338: reward = 200.00, steps = 200
# 00:07:02 [INFO] train episode 6339: reward = 200.00, steps = 200
# 00:07:02 [INFO] train episode 6340: reward = 200.00, steps = 200
# 00:07:02 [INFO] train episode 6341: reward = 181.00, steps = 181
# 00:07:02 [INFO] train episode 6342: reward = 200.00, steps = 200
# 00:07:02 [INFO] train episode 6343: reward = 161.00, steps = 161
# 00:07:03 [INFO] train episode 6344: reward = 200.00, steps = 200
# 00:07:03 [INFO] train episode 6345: reward = 181.00, steps = 181
# 00:07:03 [INFO] train episode 6346: reward = 200.00, steps = 200
# 00:07:03 [INFO] train episode 6347: reward = 193.00, steps = 193
# 00:07:03 [INFO] train episode 6348: reward = 200.00, steps = 200
# 00:07:03 [INFO] train episode 6349: reward = 200.00, steps = 200
# 00:07:03 [INFO] train episode 6350: reward = 200.00, steps = 200
# 00:07:03 [INFO] train episode 6351: reward = 200.00, steps = 200
# 00:07:03 [INFO] train episode 6352: reward = 200.00, steps = 200
# 00:07:03 [INFO] train episode 6353: reward = 200.00, steps = 200
# 00:07:03 [INFO] train episode 6354: reward = 200.00, steps = 200
# 00:07:03 [INFO] train episode 6355: reward = 200.00, steps = 200
# 00:07:03 [INFO] train episode 6356: reward = 200.00, steps = 200
# 00:07:03 [INFO] train episode 6357: reward = 200.00, steps = 200
# 00:07:03 [INFO] train episode 6358: reward = 200.00, steps = 200
# 00:07:03 [INFO] train episode 6359: reward = 200.00, steps = 200
# 00:07:04 [INFO] train episode 6360: reward = 200.00, steps = 200
# 00:07:04 [INFO] train episode 6361: reward = 200.00, steps = 200
# 00:07:04 [INFO] train episode 6362: reward = 200.00, steps = 200
# 00:07:04 [INFO] train episode 6363: reward = 200.00, steps = 200
# 00:07:04 [INFO] train episode 6364: reward = 200.00, steps = 200
# 00:07:04 [INFO] train episode 6365: reward = 200.00, steps = 200
# 00:07:04 [INFO] ==== test ====
# 00:07:04 [INFO] test episode 0: reward = 200.00, steps = 200
# 00:07:04 [INFO] test episode 1: reward = 184.00, steps = 184
# 00:07:04 [INFO] test episode 2: reward = 200.00, steps = 200
# 00:07:04 [INFO] test episode 3: reward = 200.00, steps = 200
# 00:07:04 [INFO] test episode 4: reward = 200.00, steps = 200
# 00:07:04 [INFO] test episode 5: reward = 194.00, steps = 194
# 00:07:04 [INFO] test episode 6: reward = 200.00, steps = 200
# 00:07:04 [INFO] test episode 7: reward = 200.00, steps = 200
# 00:07:04 [INFO] test episode 8: reward = 200.00, steps = 200
# 00:07:04 [INFO] test episode 9: reward = 200.00, steps = 200
# 00:07:04 [INFO] test episode 10: reward = 168.00, steps = 168
# 00:07:04 [INFO] test episode 11: reward = 200.00, steps = 200
# 00:07:05 [INFO] test episode 12: reward = 182.00, steps = 182
# 00:07:05 [INFO] test episode 13: reward = 200.00, steps = 200
# 00:07:05 [INFO] test episode 14: reward = 200.00, steps = 200
# 00:07:05 [INFO] test episode 15: reward = 200.00, steps = 200
# 00:07:05 [INFO] test episode 16: reward = 200.00, steps = 200
# 00:07:05 [INFO] test episode 17: reward = 196.00, steps = 196
# 00:07:05 [INFO] test episode 18: reward = 200.00, steps = 200
# 00:07:05 [INFO] test episode 19: reward = 176.00, steps = 176
# 00:07:05 [INFO] test episode 20: reward = 188.00, steps = 188
# 00:07:05 [INFO] test episode 21: reward = 188.00, steps = 188
# 00:07:05 [INFO] test episode 22: reward = 200.00, steps = 200
# 00:07:05 [INFO] test episode 23: reward = 200.00, steps = 200
# 00:07:05 [INFO] test episode 24: reward = 200.00, steps = 200
# 00:07:05 [INFO] test episode 25: reward = 200.00, steps = 200
# 00:07:05 [INFO] test episode 26: reward = 200.00, steps = 200
# 00:07:05 [INFO] test episode 27: reward = 200.00, steps = 200
# 00:07:05 [INFO] test episode 28: reward = 185.00, steps = 185
# 00:07:05 [INFO] test episode 29: reward = 200.00, steps = 200
# 00:07:06 [INFO] test episode 30: reward = 200.00, steps = 200
# 00:07:06 [INFO] test episode 31: reward = 200.00, steps = 200
# 00:07:06 [INFO] test episode 32: reward = 200.00, steps = 200
# 00:07:06 [INFO] test episode 33: reward = 200.00, steps = 200
# 00:07:06 [INFO] test episode 34: reward = 200.00, steps = 200
# 00:07:06 [INFO] test episode 35: reward = 200.00, steps = 200
# 00:07:06 [INFO] test episode 36: reward = 200.00, steps = 200
# 00:07:06 [INFO] test episode 37: reward = 188.00, steps = 188
# 00:07:06 [INFO] test episode 38: reward = 200.00, steps = 200
# 00:07:06 [INFO] test episode 39: reward = 200.00, steps = 200
# 00:07:06 [INFO] test episode 40: reward = 200.00, steps = 200
# 00:07:06 [INFO] test episode 41: reward = 200.00, steps = 200
# 00:07:06 [INFO] test episode 42: reward = 200.00, steps = 200
# 00:07:06 [INFO] test episode 43: reward = 164.00, steps = 164
# 00:07:06 [INFO] test episode 44: reward = 200.00, steps = 200
# 00:07:06 [INFO] test episode 45: reward = 200.00, steps = 200
# 00:07:06 [INFO] test episode 46: reward = 184.00, steps = 184
# 00:07:07 [INFO] test episode 47: reward = 200.00, steps = 200
# 00:07:07 [INFO] test episode 48: reward = 200.00, steps = 200
# 00:07:07 [INFO] test episode 49: reward = 200.00, steps = 200
# 00:07:07 [INFO] test episode 50: reward = 193.00, steps = 193
# 00:07:07 [INFO] test episode 51: reward = 200.00, steps = 200
# 00:07:07 [INFO] test episode 52: reward = 200.00, steps = 200
# 00:07:07 [INFO] test episode 53: reward = 200.00, steps = 200
# 00:07:07 [INFO] test episode 54: reward = 198.00, steps = 198
# 00:07:07 [INFO] test episode 55: reward = 199.00, steps = 199
# 00:07:07 [INFO] test episode 56: reward = 200.00, steps = 200
# 00:07:07 [INFO] test episode 57: reward = 200.00, steps = 200
# 00:07:07 [INFO] test episode 58: reward = 200.00, steps = 200
# 00:07:07 [INFO] test episode 59: reward = 187.00, steps = 187
# 00:07:07 [INFO] test episode 60: reward = 200.00, steps = 200
# 00:07:07 [INFO] test episode 61: reward = 184.00, steps = 184
# 00:07:07 [INFO] test episode 62: reward = 200.00, steps = 200
# 00:07:07 [INFO] test episode 63: reward = 200.00, steps = 200
# 00:07:07 [INFO] test episode 64: reward = 200.00, steps = 200
# 00:07:08 [INFO] test episode 65: reward = 188.00, steps = 188
# 00:07:08 [INFO] test episode 66: reward = 169.00, steps = 169
# 00:07:08 [INFO] test episode 67: reward = 200.00, steps = 200
# 00:07:08 [INFO] test episode 68: reward = 200.00, steps = 200
# 00:07:08 [INFO] test episode 69: reward = 200.00, steps = 200
# 00:07:08 [INFO] test episode 70: reward = 177.00, steps = 177
# 00:07:08 [INFO] test episode 71: reward = 200.00, steps = 200
# 00:07:08 [INFO] test episode 72: reward = 200.00, steps = 200
# 00:07:08 [INFO] test episode 73: reward = 200.00, steps = 200
# 00:07:08 [INFO] test episode 74: reward = 200.00, steps = 200
# 00:07:08 [INFO] test episode 75: reward = 200.00, steps = 200
# 00:07:08 [INFO] test episode 76: reward = 200.00, steps = 200
# 00:07:08 [INFO] test episode 77: reward = 200.00, steps = 200
# 00:07:08 [INFO] test episode 78: reward = 200.00, steps = 200
# 00:07:08 [INFO] test episode 79: reward = 200.00, steps = 200
# 00:07:08 [INFO] test episode 80: reward = 200.00, steps = 200
# 00:07:08 [INFO] test episode 81: reward = 200.00, steps = 200
# 00:07:08 [INFO] test episode 82: reward = 200.00, steps = 200
# 00:07:09 [INFO] test episode 83: reward = 200.00, steps = 200
# 00:07:09 [INFO] test episode 84: reward = 189.00, steps = 189
# 00:07:09 [INFO] test episode 85: reward = 200.00, steps = 200
# 00:07:09 [INFO] test episode 86: reward = 200.00, steps = 200
# 00:07:09 [INFO] test episode 87: reward = 200.00, steps = 200
# 00:07:09 [INFO] test episode 88: reward = 200.00, steps = 200
# 00:07:09 [INFO] test episode 89: reward = 200.00, steps = 200
# 00:07:09 [INFO] test episode 90: reward = 200.00, steps = 200
# 00:07:09 [INFO] test episode 91: reward = 200.00, steps = 200
# 00:07:09 [INFO] test episode 92: reward = 200.00, steps = 200
# 00:07:09 [INFO] test episode 93: reward = 200.00, steps = 200
# 00:07:09 [INFO] test episode 94: reward = 184.00, steps = 184
# 00:07:09 [INFO] test episode 95: reward = 200.00, steps = 200
# 00:07:09 [INFO] test episode 96: reward = 197.00, steps = 197
# 00:07:09 [INFO] test episode 97: reward = 200.00, steps = 200
# 00:07:09 [INFO] test episode 98: reward = 200.00, steps = 200
# 00:07:09 [INFO] test episode 99: reward = 200.00, steps = 200
# 00:07:09 [INFO] average episode reward = 196.62 ± 7.61

# %%
env.close()
