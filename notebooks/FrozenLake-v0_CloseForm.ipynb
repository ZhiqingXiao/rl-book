# %% [markdown]
# # Use Close-Form Policy to Play FrozenLake-v0

# %%
import sys
import logging
import imp
import itertools

import numpy as np
np.random.seed(0)
import gym

imp.reload(logging)
logging.basicConfig(level=logging.DEBUG,
        format='%(asctime)s [%(levelname)s] %(message)s',
        stream=sys.stdout, datefmt='%H:%M:%S')

# %%
env = gym.make('FrozenLake-v0')
env.seed(0)
for key in vars(env):
    logging.info('%s: %s', key, vars(env)[key])
for key in vars(env.spec):
    logging.info('%s: %s', key, vars(env.spec)[key])
# Out:
# 00:00:00 [INFO] env: <FrozenLakeEnv<FrozenLake-v0>>
# 00:00:00 [INFO] action_space: Discrete(4)
# 00:00:00 [INFO] observation_space: Discrete(16)
# 00:00:00 [INFO] reward_range: (0, 1)
# 00:00:00 [INFO] metadata: {'render.modes': ['human', 'ansi']}
# 00:00:00 [INFO] _max_episode_steps: 100
# 00:00:00 [INFO] _elapsed_steps: None
# 00:00:00 [INFO] id: FrozenLake-v0
# 00:00:00 [INFO] entry_point: gym.envs.toy_text:FrozenLakeEnv
# 00:00:00 [INFO] reward_threshold: 0.78
# 00:00:00 [INFO] nondeterministic: False
# 00:00:00 [INFO] max_episode_steps: 100
# 00:00:00 [INFO] _kwargs: {'map_name': '4x4'}
# 00:00:00 [INFO] _env_name: FrozenLake

# %%
class CloseFormAgent:
    def __init__(self, env):
        state_n, action_n = env.observation_space.n, env.action_space.n
        v = np.zeros((env.spec.max_episode_steps+1, state_n))
        q = np.zeros((env.spec.max_episode_steps+1, state_n, action_n))
        pi = np.zeros((env.spec.max_episode_steps+1, state_n))
        for t in range(env.spec.max_episode_steps-1, -1, -1):
            for s in range(state_n):
                for a in range(action_n):
                    for p, next_s, r, d in env.P[s][a]:
                        q[t, s, a] += p * (r + (1. - float(d)) * v[t+1, next_s])
                v[t, s] = q[t, s].max()
                pi[t, s] = q[t, s].argmax()
        self.pi = pi

    def reset(self, mode=None):
        self.t = 0

    def step(self, observation, _reward, _done):
        action = self.pi[self.t, observation]
        self.t += 1
        return action

    def close(self):
        pass


agent = CloseFormAgent(env)

# %%
def play_episode(env, agent, max_episode_steps=None, mode=None, render=False):
    observation, reward, done = env.reset(), 0., False
    agent.reset(mode=mode)
    episode_reward, elapsed_steps = 0., 0
    while True:
        action = agent.step(observation, reward, done)
        if render:
            env.render()
        if done:
            break
        observation, reward, done, _ = env.step(action)
        episode_reward += reward
        elapsed_steps += 1
        if max_episode_steps and elapsed_steps >= max_episode_steps:
            break
    agent.close()
    return episode_reward, elapsed_steps


logging.info('==== test ====')
episode_rewards = []
for episode in range(100):
    episode_reward, elapsed_steps = play_episode(env, agent)
    episode_rewards.append(episode_reward)
    logging.debug('test episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
logging.info('average episode reward = %.2f ± %.2f',
        np.mean(episode_rewards), np.std(episode_rewards))
# Out:
# 00:00:00 [INFO] ==== test ====
# 00:00:00 [DEBUG] test episode 0: reward = 1.00, steps = 14
# 00:00:00 [DEBUG] test episode 1: reward = 1.00, steps = 11
# 00:00:00 [DEBUG] test episode 2: reward = 1.00, steps = 31
# 00:00:00 [DEBUG] test episode 3: reward = 0.00, steps = 14
# 00:00:00 [DEBUG] test episode 4: reward = 0.00, steps = 9
# 00:00:00 [DEBUG] test episode 5: reward = 1.00, steps = 93
# 00:00:00 [DEBUG] test episode 6: reward = 1.00, steps = 100
# 00:00:00 [DEBUG] test episode 7: reward = 1.00, steps = 34
# 00:00:00 [DEBUG] test episode 8: reward = 1.00, steps = 86
# 00:00:00 [DEBUG] test episode 9: reward = 1.00, steps = 26
# 00:00:00 [DEBUG] test episode 10: reward = 0.00, steps = 16
# 00:00:00 [DEBUG] test episode 11: reward = 1.00, steps = 57
# 00:00:00 [DEBUG] test episode 12: reward = 0.00, steps = 98
# 00:00:00 [DEBUG] test episode 13: reward = 0.00, steps = 10
# 00:00:00 [DEBUG] test episode 14: reward = 0.00, steps = 100
# 00:00:00 [DEBUG] test episode 15: reward = 1.00, steps = 7
# 00:00:00 [DEBUG] test episode 16: reward = 1.00, steps = 97
# 00:00:00 [DEBUG] test episode 17: reward = 1.00, steps = 26
# 00:00:00 [DEBUG] test episode 18: reward = 1.00, steps = 58
# 00:00:00 [DEBUG] test episode 19: reward = 1.00, steps = 27
# 00:00:00 [DEBUG] test episode 20: reward = 0.00, steps = 49
# 00:00:00 [DEBUG] test episode 21: reward = 0.00, steps = 85
# 00:00:00 [DEBUG] test episode 22: reward = 0.00, steps = 73
# 00:00:00 [DEBUG] test episode 23: reward = 1.00, steps = 25
# 00:00:00 [DEBUG] test episode 24: reward = 1.00, steps = 16
# 00:00:00 [DEBUG] test episode 25: reward = 1.00, steps = 24
# 00:00:00 [DEBUG] test episode 26: reward = 1.00, steps = 41
# 00:00:00 [DEBUG] test episode 27: reward = 1.00, steps = 27
# 00:00:00 [DEBUG] test episode 28: reward = 1.00, steps = 29
# 00:00:00 [DEBUG] test episode 29: reward = 1.00, steps = 36
# 00:00:00 [DEBUG] test episode 30: reward = 1.00, steps = 36
# 00:00:00 [DEBUG] test episode 31: reward = 1.00, steps = 55
# 00:00:00 [DEBUG] test episode 32: reward = 1.00, steps = 27
# 00:00:00 [DEBUG] test episode 33: reward = 1.00, steps = 80
# 00:00:00 [DEBUG] test episode 34: reward = 1.00, steps = 11
# 00:00:00 [DEBUG] test episode 35: reward = 1.00, steps = 48
# 00:00:00 [DEBUG] test episode 36: reward = 0.00, steps = 79
# 00:00:00 [DEBUG] test episode 37: reward = 1.00, steps = 70
# 00:00:00 [DEBUG] test episode 38: reward = 0.00, steps = 100
# 00:00:00 [DEBUG] test episode 39: reward = 1.00, steps = 48
# 00:00:00 [DEBUG] test episode 40: reward = 1.00, steps = 11
# 00:00:00 [DEBUG] test episode 41: reward = 1.00, steps = 29
# 00:00:00 [DEBUG] test episode 42: reward = 1.00, steps = 84
# 00:00:00 [DEBUG] test episode 43: reward = 0.00, steps = 100
# 00:00:00 [DEBUG] test episode 44: reward = 1.00, steps = 27
# 00:00:00 [DEBUG] test episode 45: reward = 1.00, steps = 81
# 00:00:00 [DEBUG] test episode 46: reward = 1.00, steps = 8
# 00:00:00 [DEBUG] test episode 47: reward = 1.00, steps = 81
# 00:00:00 [DEBUG] test episode 48: reward = 1.00, steps = 21
# 00:00:00 [DEBUG] test episode 49: reward = 1.00, steps = 73
# 00:00:00 [DEBUG] test episode 50: reward = 1.00, steps = 46
# 00:00:00 [DEBUG] test episode 51: reward = 1.00, steps = 18
# 00:00:00 [DEBUG] test episode 52: reward = 1.00, steps = 13
# 00:00:00 [DEBUG] test episode 53: reward = 0.00, steps = 26
# 00:00:00 [DEBUG] test episode 54: reward = 1.00, steps = 63
# 00:00:00 [DEBUG] test episode 55: reward = 1.00, steps = 24
# 00:00:00 [DEBUG] test episode 56: reward = 0.00, steps = 100
# 00:00:00 [DEBUG] test episode 57: reward = 1.00, steps = 46
# 00:00:00 [DEBUG] test episode 58: reward = 0.00, steps = 74
# 00:00:00 [DEBUG] test episode 59: reward = 1.00, steps = 28
# 00:00:00 [DEBUG] test episode 60: reward = 1.00, steps = 34
# 00:00:00 [DEBUG] test episode 61: reward = 1.00, steps = 77
# 00:00:00 [DEBUG] test episode 62: reward = 1.00, steps = 72
# 00:00:00 [DEBUG] test episode 63: reward = 1.00, steps = 22
# 00:00:00 [DEBUG] test episode 64: reward = 1.00, steps = 35
# 00:00:00 [DEBUG] test episode 65: reward = 1.00, steps = 62
# 00:00:00 [DEBUG] test episode 66: reward = 0.00, steps = 35
# 00:00:00 [DEBUG] test episode 67: reward = 1.00, steps = 27
# 00:00:00 [DEBUG] test episode 68: reward = 0.00, steps = 22
# 00:00:00 [DEBUG] test episode 69: reward = 1.00, steps = 48
# 00:00:00 [DEBUG] test episode 70: reward = 1.00, steps = 22
# 00:00:00 [DEBUG] test episode 71: reward = 0.00, steps = 100
# 00:00:00 [DEBUG] test episode 72: reward = 0.00, steps = 100
# 00:00:00 [DEBUG] test episode 73: reward = 1.00, steps = 30
# 00:00:00 [DEBUG] test episode 74: reward = 1.00, steps = 34
# 00:00:00 [DEBUG] test episode 75: reward = 1.00, steps = 35
# 00:00:00 [DEBUG] test episode 76: reward = 1.00, steps = 6
# 00:00:00 [DEBUG] test episode 77: reward = 1.00, steps = 25
# 00:00:00 [DEBUG] test episode 78: reward = 0.00, steps = 45
# 00:00:00 [DEBUG] test episode 79: reward = 0.00, steps = 39
# 00:00:00 [DEBUG] test episode 80: reward = 1.00, steps = 55
# 00:00:00 [DEBUG] test episode 81: reward = 0.00, steps = 12
# 00:00:00 [DEBUG] test episode 82: reward = 1.00, steps = 16
# 00:00:00 [DEBUG] test episode 83: reward = 1.00, steps = 37
# 00:00:00 [DEBUG] test episode 84: reward = 1.00, steps = 97
# 00:00:00 [DEBUG] test episode 85: reward = 1.00, steps = 65
# 00:00:00 [DEBUG] test episode 86: reward = 1.00, steps = 48
# 00:00:00 [DEBUG] test episode 87: reward = 0.00, steps = 100
# 00:00:00 [DEBUG] test episode 88: reward = 0.00, steps = 31
# 00:00:00 [DEBUG] test episode 89: reward = 1.00, steps = 71
# 00:00:00 [DEBUG] test episode 90: reward = 1.00, steps = 75
# 00:00:00 [DEBUG] test episode 91: reward = 0.00, steps = 15
# 00:00:00 [DEBUG] test episode 92: reward = 1.00, steps = 52
# 00:00:00 [DEBUG] test episode 93: reward = 1.00, steps = 24
# 00:00:00 [DEBUG] test episode 94: reward = 1.00, steps = 37
# 00:00:00 [DEBUG] test episode 95: reward = 1.00, steps = 17
# 00:00:00 [DEBUG] test episode 96: reward = 1.00, steps = 14
# 00:00:00 [DEBUG] test episode 97: reward = 1.00, steps = 11
# 00:00:00 [DEBUG] test episode 98: reward = 1.00, steps = 29
# 00:00:00 [DEBUG] test episode 99: reward = 1.00, steps = 13
# 00:00:00 [INFO] average episode reward = 0.75 ± 0.43

# %%
env.close()
