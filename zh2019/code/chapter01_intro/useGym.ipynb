# %% [markdown]
# # 扩展库 Gym 的使用

# %%
import numpy as np
np.random.seed(0)
import pandas as pd
import gym

# %% [markdown]
# 列出所有环境

# %%
space_names = ['观测空间', '动作空间', '奖励范围', '最大步数']
df = pd.DataFrame(columns=space_names)

for env_id in gym.envs.registry:
    try:
        env = gym.make(env_id)
        observation_space = env.observation_space
        action_space = env.action_space
        reward_range = env.reward_range
        max_episode_steps = None
        if isinstance(env, gym.wrappers.time_limit.TimeLimit):
            max_episode_steps = env._max_episode_steps
        df.loc[env_id] = [observation_space, action_space, reward_range, max_episode_steps]
    except:
        pass

with pd.option_context('display.max_rows', None):
    display(df)
# Out:
#                                                                                    观测空间  \
# ALE/Adventure-v5                                      Box(0, 255, (250, 160, 3), uint8)
# ALE/Adventure-ram-v5                                         Box(0, 255, (128,), uint8)
# ALE/AirRaid-v5                                        Box(0, 255, (250, 160, 3), uint8)
# ALE/AirRaid-ram-v5                                           Box(0, 255, (128,), uint8)
# ALE/Alien-v5                                          Box(0, 255, (210, 160, 3), uint8)
# ALE/Alien-ram-v5                                             Box(0, 255, (128,), uint8)
# ALE/Amidar-v5                                         Box(0, 255, (210, 160, 3), uint8)
# ALE/Amidar-ram-v5                                            Box(0, 255, (128,), uint8)
# ALE/Assault-v5                                        Box(0, 255, (210, 160, 3), uint8)
# ALE/Assault-ram-v5                                           Box(0, 255, (128,), uint8)
# ALE/Asterix-v5                                        Box(0, 255, (210, 160, 3), uint8)
# ALE/Asterix-ram-v5                                           Box(0, 255, (128,), uint8)
# ALE/Asteroids-v5                                      Box(0, 255, (210, 160, 3), uint8)
# ALE/Asteroids-ram-v5                                         Box(0, 255, (128,), uint8)
# ALE/Atlantis-v5                                       Box(0, 255, (210, 160, 3), uint8)
# ALE/Atlantis-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/Atlantis2-v5                                      Box(0, 255, (210, 160, 3), uint8)
# ALE/Atlantis2-ram-v5                                         Box(0, 255, (128,), uint8)
# ALE/Backgammon-v5                                     Box(0, 255, (210, 160, 3), uint8)
# ALE/Backgammon-ram-v5                                        Box(0, 255, (128,), uint8)
# ALE/BankHeist-v5                                      Box(0, 255, (210, 160, 3), uint8)
# ALE/BankHeist-ram-v5                                         Box(0, 255, (128,), uint8)
# ALE/BasicMath-v5                                      Box(0, 255, (210, 160, 3), uint8)
# ALE/BasicMath-ram-v5                                         Box(0, 255, (128,), uint8)
# ALE/BattleZone-v5                                     Box(0, 255, (210, 160, 3), uint8)
# ALE/BattleZone-ram-v5                                        Box(0, 255, (128,), uint8)
# ALE/BeamRider-v5                                      Box(0, 255, (210, 160, 3), uint8)
# ALE/BeamRider-ram-v5                                         Box(0, 255, (128,), uint8)
# ALE/Berzerk-v5                                        Box(0, 255, (210, 160, 3), uint8)
# ALE/Berzerk-ram-v5                                           Box(0, 255, (128,), uint8)
# ALE/Blackjack-v5                                      Box(0, 255, (210, 160, 3), uint8)
# ALE/Blackjack-ram-v5                                         Box(0, 255, (128,), uint8)
# ALE/Bowling-v5                                        Box(0, 255, (210, 160, 3), uint8)
# ALE/Bowling-ram-v5                                           Box(0, 255, (128,), uint8)
# ALE/Boxing-v5                                         Box(0, 255, (210, 160, 3), uint8)
# ALE/Boxing-ram-v5                                            Box(0, 255, (128,), uint8)
# ALE/Breakout-v5                                       Box(0, 255, (210, 160, 3), uint8)
# ALE/Breakout-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/Carnival-v5                                       Box(0, 255, (214, 160, 3), uint8)
# ALE/Carnival-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/Casino-v5                                         Box(0, 255, (210, 160, 3), uint8)
# ALE/Casino-ram-v5                                            Box(0, 255, (128,), uint8)
# ALE/Centipede-v5                                      Box(0, 255, (210, 160, 3), uint8)
# ALE/Centipede-ram-v5                                         Box(0, 255, (128,), uint8)
# ALE/ChopperCommand-v5                                 Box(0, 255, (210, 160, 3), uint8)
# ALE/ChopperCommand-ram-v5                                    Box(0, 255, (128,), uint8)
# ALE/CrazyClimber-v5                                   Box(0, 255, (210, 160, 3), uint8)
# ALE/CrazyClimber-ram-v5                                      Box(0, 255, (128,), uint8)
# ALE/Crossbow-v5                                       Box(0, 255, (210, 160, 3), uint8)
# ALE/Crossbow-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/Darkchambers-v5                                   Box(0, 255, (210, 160, 3), uint8)
# ALE/Darkchambers-ram-v5                                      Box(0, 255, (128,), uint8)
# ALE/Defender-v5                                       Box(0, 255, (210, 160, 3), uint8)
# ALE/Defender-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/DemonAttack-v5                                    Box(0, 255, (210, 160, 3), uint8)
# ALE/DemonAttack-ram-v5                                       Box(0, 255, (128,), uint8)
# ALE/DonkeyKong-v5                                     Box(0, 255, (210, 160, 3), uint8)
# ALE/DonkeyKong-ram-v5                                        Box(0, 255, (128,), uint8)
# ALE/DoubleDunk-v5                                     Box(0, 255, (210, 160, 3), uint8)
# ALE/DoubleDunk-ram-v5                                        Box(0, 255, (128,), uint8)
# ALE/Earthworld-v5                                     Box(0, 255, (210, 160, 3), uint8)
# ALE/Earthworld-ram-v5                                        Box(0, 255, (128,), uint8)
# ALE/ElevatorAction-v5                                 Box(0, 255, (210, 160, 3), uint8)
# ALE/ElevatorAction-ram-v5                                    Box(0, 255, (128,), uint8)
# ALE/Enduro-v5                                         Box(0, 255, (210, 160, 3), uint8)
# ALE/Enduro-ram-v5                                            Box(0, 255, (128,), uint8)
# ALE/Entombed-v5                                       Box(0, 255, (210, 160, 3), uint8)
# ALE/Entombed-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/Et-v5                                             Box(0, 255, (210, 160, 3), uint8)
# ALE/Et-ram-v5                                                Box(0, 255, (128,), uint8)
# ALE/FishingDerby-v5                                   Box(0, 255, (210, 160, 3), uint8)
# ALE/FishingDerby-ram-v5                                      Box(0, 255, (128,), uint8)
# ALE/FlagCapture-v5                                    Box(0, 255, (210, 160, 3), uint8)
# ALE/FlagCapture-ram-v5                                       Box(0, 255, (128,), uint8)
# ALE/Freeway-v5                                        Box(0, 255, (210, 160, 3), uint8)
# ALE/Freeway-ram-v5                                           Box(0, 255, (128,), uint8)
# ALE/Frogger-v5                                        Box(0, 255, (210, 160, 3), uint8)
# ALE/Frogger-ram-v5                                           Box(0, 255, (128,), uint8)
# ALE/Frostbite-v5                                      Box(0, 255, (210, 160, 3), uint8)
# ALE/Frostbite-ram-v5                                         Box(0, 255, (128,), uint8)
# ALE/Galaxian-v5                                       Box(0, 255, (210, 160, 3), uint8)
# ALE/Galaxian-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/Gopher-v5                                         Box(0, 255, (210, 160, 3), uint8)
# ALE/Gopher-ram-v5                                            Box(0, 255, (128,), uint8)
# ALE/Gravitar-v5                                       Box(0, 255, (210, 160, 3), uint8)
# ALE/Gravitar-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/Hangman-v5                                        Box(0, 255, (210, 160, 3), uint8)
# ALE/Hangman-ram-v5                                           Box(0, 255, (128,), uint8)
# ALE/HauntedHouse-v5                                   Box(0, 255, (210, 160, 3), uint8)
# ALE/HauntedHouse-ram-v5                                      Box(0, 255, (128,), uint8)
# ALE/Hero-v5                                           Box(0, 255, (210, 160, 3), uint8)
# ALE/Hero-ram-v5                                              Box(0, 255, (128,), uint8)
# ALE/HumanCannonball-v5                                Box(0, 255, (210, 160, 3), uint8)
# ALE/HumanCannonball-ram-v5                                   Box(0, 255, (128,), uint8)
# ALE/IceHockey-v5                                      Box(0, 255, (210, 160, 3), uint8)
# ALE/IceHockey-ram-v5                                         Box(0, 255, (128,), uint8)
# ALE/Jamesbond-v5                                      Box(0, 255, (210, 160, 3), uint8)
# ALE/Jamesbond-ram-v5                                         Box(0, 255, (128,), uint8)
# ALE/JourneyEscape-v5                                  Box(0, 255, (230, 160, 3), uint8)
# ALE/JourneyEscape-ram-v5                                     Box(0, 255, (128,), uint8)
# ALE/Kaboom-v5                                         Box(0, 255, (210, 160, 3), uint8)
# ALE/Kaboom-ram-v5                                            Box(0, 255, (128,), uint8)
# ALE/Kangaroo-v5                                       Box(0, 255, (210, 160, 3), uint8)
# ALE/Kangaroo-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/KeystoneKapers-v5                                 Box(0, 255, (250, 160, 3), uint8)
# ALE/KeystoneKapers-ram-v5                                    Box(0, 255, (128,), uint8)
# ALE/KingKong-v5                                       Box(0, 255, (250, 160, 3), uint8)
# ALE/KingKong-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/Klax-v5                                           Box(0, 255, (250, 160, 3), uint8)
# ALE/Klax-ram-v5                                              Box(0, 255, (128,), uint8)
# ALE/Koolaid-v5                                        Box(0, 255, (210, 160, 3), uint8)
# ALE/Koolaid-ram-v5                                           Box(0, 255, (128,), uint8)
# ALE/Krull-v5                                          Box(0, 255, (210, 160, 3), uint8)
# ALE/Krull-ram-v5                                             Box(0, 255, (128,), uint8)
# ALE/KungFuMaster-v5                                   Box(0, 255, (210, 160, 3), uint8)
# ALE/KungFuMaster-ram-v5                                      Box(0, 255, (128,), uint8)
# ALE/LaserGates-v5                                     Box(0, 255, (250, 160, 3), uint8)
# ALE/LaserGates-ram-v5                                        Box(0, 255, (128,), uint8)
# ALE/LostLuggage-v5                                    Box(0, 255, (210, 160, 3), uint8)
# ALE/LostLuggage-ram-v5                                       Box(0, 255, (128,), uint8)
# ALE/MarioBros-v5                                      Box(0, 255, (210, 160, 3), uint8)
# ALE/MarioBros-ram-v5                                         Box(0, 255, (128,), uint8)
# ALE/MiniatureGolf-v5                                  Box(0, 255, (210, 160, 3), uint8)
# ALE/MiniatureGolf-ram-v5                                     Box(0, 255, (128,), uint8)
# ALE/MontezumaRevenge-v5                               Box(0, 255, (210, 160, 3), uint8)
# ALE/MontezumaRevenge-ram-v5                                  Box(0, 255, (128,), uint8)
# ALE/MrDo-v5                                           Box(0, 255, (250, 160, 3), uint8)
# ALE/MrDo-ram-v5                                              Box(0, 255, (128,), uint8)
# ALE/MsPacman-v5                                       Box(0, 255, (210, 160, 3), uint8)
# ALE/MsPacman-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/NameThisGame-v5                                   Box(0, 255, (210, 160, 3), uint8)
# ALE/NameThisGame-ram-v5                                      Box(0, 255, (128,), uint8)
# ALE/Othello-v5                                        Box(0, 255, (210, 160, 3), uint8)
# ALE/Othello-ram-v5                                           Box(0, 255, (128,), uint8)
# ALE/Pacman-v5                                         Box(0, 255, (250, 160, 3), uint8)
# ALE/Pacman-ram-v5                                            Box(0, 255, (128,), uint8)
# ALE/Phoenix-v5                                        Box(0, 255, (210, 160, 3), uint8)
# ALE/Phoenix-ram-v5                                           Box(0, 255, (128,), uint8)
# ALE/Pitfall-v5                                        Box(0, 255, (210, 160, 3), uint8)
# ALE/Pitfall-ram-v5                                           Box(0, 255, (128,), uint8)
# ALE/Pitfall2-v5                                       Box(0, 255, (210, 160, 3), uint8)
# ALE/Pitfall2-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/Pong-v5                                           Box(0, 255, (210, 160, 3), uint8)
# ALE/Pong-ram-v5                                              Box(0, 255, (128,), uint8)
# ALE/Pooyan-v5                                         Box(0, 255, (220, 160, 3), uint8)
# ALE/Pooyan-ram-v5                                            Box(0, 255, (128,), uint8)
# ALE/PrivateEye-v5                                     Box(0, 255, (210, 160, 3), uint8)
# ALE/PrivateEye-ram-v5                                        Box(0, 255, (128,), uint8)
# ALE/Qbert-v5                                          Box(0, 255, (210, 160, 3), uint8)
# ALE/Qbert-ram-v5                                             Box(0, 255, (128,), uint8)
# ALE/Riverraid-v5                                      Box(0, 255, (210, 160, 3), uint8)
# ALE/Riverraid-ram-v5                                         Box(0, 255, (128,), uint8)
# ALE/RoadRunner-v5                                     Box(0, 255, (210, 160, 3), uint8)
# ALE/RoadRunner-ram-v5                                        Box(0, 255, (128,), uint8)
# ALE/Robotank-v5                                       Box(0, 255, (210, 160, 3), uint8)
# ALE/Robotank-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/Seaquest-v5                                       Box(0, 255, (210, 160, 3), uint8)
# ALE/Seaquest-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/SirLancelot-v5                                    Box(0, 255, (250, 160, 3), uint8)
# ALE/SirLancelot-ram-v5                                       Box(0, 255, (128,), uint8)
# ALE/Skiing-v5                                         Box(0, 255, (210, 160, 3), uint8)
# ALE/Skiing-ram-v5                                            Box(0, 255, (128,), uint8)
# ALE/Solaris-v5                                        Box(0, 255, (210, 160, 3), uint8)
# ALE/Solaris-ram-v5                                           Box(0, 255, (128,), uint8)
# ALE/SpaceInvaders-v5                                  Box(0, 255, (210, 160, 3), uint8)
# ALE/SpaceInvaders-ram-v5                                     Box(0, 255, (128,), uint8)
# ALE/SpaceWar-v5                                       Box(0, 255, (250, 160, 3), uint8)
# ALE/SpaceWar-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/StarGunner-v5                                     Box(0, 255, (210, 160, 3), uint8)
# ALE/StarGunner-ram-v5                                        Box(0, 255, (128,), uint8)
# ALE/Superman-v5                                       Box(0, 255, (210, 160, 3), uint8)
# ALE/Superman-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/Surround-v5                                       Box(0, 255, (210, 160, 3), uint8)
# ALE/Surround-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/Tennis-v5                                         Box(0, 255, (210, 160, 3), uint8)
# ALE/Tennis-ram-v5                                            Box(0, 255, (128,), uint8)
# ALE/Tetris-v5                                         Box(0, 255, (210, 160, 3), uint8)
# ALE/Tetris-ram-v5                                            Box(0, 255, (128,), uint8)
# ALE/TimePilot-v5                                      Box(0, 255, (210, 160, 3), uint8)
# ALE/TimePilot-ram-v5                                         Box(0, 255, (128,), uint8)
# ALE/Trondead-v5                                       Box(0, 255, (210, 160, 3), uint8)
# ALE/Trondead-ram-v5                                          Box(0, 255, (128,), uint8)
# ALE/Turmoil-v5                                        Box(0, 255, (210, 160, 3), uint8)
# ALE/Turmoil-ram-v5                                           Box(0, 255, (128,), uint8)
# ALE/Tutankham-v5                                      Box(0, 255, (210, 160, 3), uint8)
# ALE/Tutankham-ram-v5                                         Box(0, 255, (128,), uint8)
# ALE/UpNDown-v5                                        Box(0, 255, (210, 160, 3), uint8)
# ALE/UpNDown-ram-v5                                           Box(0, 255, (128,), uint8)
# ALE/Venture-v5                                        Box(0, 255, (210, 160, 3), uint8)
# ALE/Venture-ram-v5                                           Box(0, 255, (128,), uint8)
# ALE/VideoCheckers-v5                                  Box(0, 255, (210, 160, 3), uint8)
# ALE/VideoCheckers-ram-v5                                     Box(0, 255, (128,), uint8)
# ALE/VideoPinball-v5                                   Box(0, 255, (210, 160, 3), uint8)
# ALE/VideoPinball-ram-v5                                      Box(0, 255, (128,), uint8)
# ALE/WizardOfWor-v5                                    Box(0, 255, (210, 160, 3), uint8)
# ALE/WizardOfWor-ram-v5                                       Box(0, 255, (128,), uint8)
# ALE/WordZapper-v5                                     Box(0, 255, (210, 160, 3), uint8)
# ALE/WordZapper-ram-v5                                        Box(0, 255, (128,), uint8)
# ALE/YarsRevenge-v5                                    Box(0, 255, (210, 160, 3), uint8)
# ALE/YarsRevenge-ram-v5                                       Box(0, 255, (128,), uint8)
# ALE/Zaxxon-v5                                         Box(0, 255, (210, 160, 3), uint8)
# ALE/Zaxxon-ram-v5                                            Box(0, 255, (128,), uint8)
# Adventure-v0                                          Box(0, 255, (250, 160, 3), uint8)
# AdventureDeterministic-v0                             Box(0, 255, (250, 160, 3), uint8)
# AdventureNoFrameskip-v0                               Box(0, 255, (250, 160, 3), uint8)
# Adventure-v4                                          Box(0, 255, (250, 160, 3), uint8)
# AdventureDeterministic-v4                             Box(0, 255, (250, 160, 3), uint8)
# AdventureNoFrameskip-v4                               Box(0, 255, (250, 160, 3), uint8)
# Adventure-ram-v0                                             Box(0, 255, (128,), uint8)
# Adventure-ramDeterministic-v0                                Box(0, 255, (128,), uint8)
# Adventure-ramNoFrameskip-v0                                  Box(0, 255, (128,), uint8)
# Adventure-ram-v4                                             Box(0, 255, (128,), uint8)
# Adventure-ramDeterministic-v4                                Box(0, 255, (128,), uint8)
# Adventure-ramNoFrameskip-v4                                  Box(0, 255, (128,), uint8)
# AirRaid-v0                                            Box(0, 255, (250, 160, 3), uint8)
# AirRaidDeterministic-v0                               Box(0, 255, (250, 160, 3), uint8)
# AirRaidNoFrameskip-v0                                 Box(0, 255, (250, 160, 3), uint8)
# AirRaid-v4                                            Box(0, 255, (250, 160, 3), uint8)
# AirRaidDeterministic-v4                               Box(0, 255, (250, 160, 3), uint8)
# AirRaidNoFrameskip-v4                                 Box(0, 255, (250, 160, 3), uint8)
# AirRaid-ram-v0                                               Box(0, 255, (128,), uint8)
# AirRaid-ramDeterministic-v0                                  Box(0, 255, (128,), uint8)
# AirRaid-ramNoFrameskip-v0                                    Box(0, 255, (128,), uint8)
# AirRaid-ram-v4                                               Box(0, 255, (128,), uint8)
# AirRaid-ramDeterministic-v4                                  Box(0, 255, (128,), uint8)
# AirRaid-ramNoFrameskip-v4                                    Box(0, 255, (128,), uint8)
# Alien-v0                                              Box(0, 255, (210, 160, 3), uint8)
# AlienDeterministic-v0                                 Box(0, 255, (210, 160, 3), uint8)
# AlienNoFrameskip-v0                                   Box(0, 255, (210, 160, 3), uint8)
# Alien-v4                                              Box(0, 255, (210, 160, 3), uint8)
# AlienDeterministic-v4                                 Box(0, 255, (210, 160, 3), uint8)
# AlienNoFrameskip-v4                                   Box(0, 255, (210, 160, 3), uint8)
# Alien-ram-v0                                                 Box(0, 255, (128,), uint8)
# Alien-ramDeterministic-v0                                    Box(0, 255, (128,), uint8)
# Alien-ramNoFrameskip-v0                                      Box(0, 255, (128,), uint8)
# Alien-ram-v4                                                 Box(0, 255, (128,), uint8)
# Alien-ramDeterministic-v4                                    Box(0, 255, (128,), uint8)
# Alien-ramNoFrameskip-v4                                      Box(0, 255, (128,), uint8)
# Amidar-v0                                             Box(0, 255, (210, 160, 3), uint8)
# AmidarDeterministic-v0                                Box(0, 255, (210, 160, 3), uint8)
# AmidarNoFrameskip-v0                                  Box(0, 255, (210, 160, 3), uint8)
# Amidar-v4                                             Box(0, 255, (210, 160, 3), uint8)
# AmidarDeterministic-v4                                Box(0, 255, (210, 160, 3), uint8)
# AmidarNoFrameskip-v4                                  Box(0, 255, (210, 160, 3), uint8)
# Amidar-ram-v0                                                Box(0, 255, (128,), uint8)
# Amidar-ramDeterministic-v0                                   Box(0, 255, (128,), uint8)
# Amidar-ramNoFrameskip-v0                                     Box(0, 255, (128,), uint8)
# Amidar-ram-v4                                                Box(0, 255, (128,), uint8)
# Amidar-ramDeterministic-v4                                   Box(0, 255, (128,), uint8)
# Amidar-ramNoFrameskip-v4                                     Box(0, 255, (128,), uint8)
# Assault-v0                                            Box(0, 255, (210, 160, 3), uint8)
# AssaultDeterministic-v0                               Box(0, 255, (210, 160, 3), uint8)
# AssaultNoFrameskip-v0                                 Box(0, 255, (210, 160, 3), uint8)
# Assault-v4                                            Box(0, 255, (210, 160, 3), uint8)
# AssaultDeterministic-v4                               Box(0, 255, (210, 160, 3), uint8)
# AssaultNoFrameskip-v4                                 Box(0, 255, (210, 160, 3), uint8)
# Assault-ram-v0                                               Box(0, 255, (128,), uint8)
# Assault-ramDeterministic-v0                                  Box(0, 255, (128,), uint8)
# Assault-ramNoFrameskip-v0                                    Box(0, 255, (128,), uint8)
# Assault-ram-v4                                               Box(0, 255, (128,), uint8)
# Assault-ramDeterministic-v4                                  Box(0, 255, (128,), uint8)
# Assault-ramNoFrameskip-v4                                    Box(0, 255, (128,), uint8)
# Asterix-v0                                            Box(0, 255, (210, 160, 3), uint8)
# AsterixDeterministic-v0                               Box(0, 255, (210, 160, 3), uint8)
# AsterixNoFrameskip-v0                                 Box(0, 255, (210, 160, 3), uint8)
# Asterix-v4                                            Box(0, 255, (210, 160, 3), uint8)
# AsterixDeterministic-v4                               Box(0, 255, (210, 160, 3), uint8)
# AsterixNoFrameskip-v4                                 Box(0, 255, (210, 160, 3), uint8)
# Asterix-ram-v0                                               Box(0, 255, (128,), uint8)
# Asterix-ramDeterministic-v0                                  Box(0, 255, (128,), uint8)
# Asterix-ramNoFrameskip-v0                                    Box(0, 255, (128,), uint8)
# Asterix-ram-v4                                               Box(0, 255, (128,), uint8)
# Asterix-ramDeterministic-v4                                  Box(0, 255, (128,), uint8)
# Asterix-ramNoFrameskip-v4                                    Box(0, 255, (128,), uint8)
# Asteroids-v0                                          Box(0, 255, (210, 160, 3), uint8)
# AsteroidsDeterministic-v0                             Box(0, 255, (210, 160, 3), uint8)
# AsteroidsNoFrameskip-v0                               Box(0, 255, (210, 160, 3), uint8)
# Asteroids-v4                                          Box(0, 255, (210, 160, 3), uint8)
# AsteroidsDeterministic-v4                             Box(0, 255, (210, 160, 3), uint8)
# AsteroidsNoFrameskip-v4                               Box(0, 255, (210, 160, 3), uint8)
# Asteroids-ram-v0                                             Box(0, 255, (128,), uint8)
# Asteroids-ramDeterministic-v0                                Box(0, 255, (128,), uint8)
# Asteroids-ramNoFrameskip-v0                                  Box(0, 255, (128,), uint8)
# Asteroids-ram-v4                                             Box(0, 255, (128,), uint8)
# Asteroids-ramDeterministic-v4                                Box(0, 255, (128,), uint8)
# Asteroids-ramNoFrameskip-v4                                  Box(0, 255, (128,), uint8)
# Atlantis-v0                                           Box(0, 255, (210, 160, 3), uint8)
# AtlantisDeterministic-v0                              Box(0, 255, (210, 160, 3), uint8)
# AtlantisNoFrameskip-v0                                Box(0, 255, (210, 160, 3), uint8)
# Atlantis-v4                                           Box(0, 255, (210, 160, 3), uint8)
# AtlantisDeterministic-v4                              Box(0, 255, (210, 160, 3), uint8)
# AtlantisNoFrameskip-v4                                Box(0, 255, (210, 160, 3), uint8)
# Atlantis-ram-v0                                              Box(0, 255, (128,), uint8)
# Atlantis-ramDeterministic-v0                                 Box(0, 255, (128,), uint8)
# Atlantis-ramNoFrameskip-v0                                   Box(0, 255, (128,), uint8)
# Atlantis-ram-v4                                              Box(0, 255, (128,), uint8)
# Atlantis-ramDeterministic-v4                                 Box(0, 255, (128,), uint8)
# Atlantis-ramNoFrameskip-v4                                   Box(0, 255, (128,), uint8)
# BankHeist-v0                                          Box(0, 255, (210, 160, 3), uint8)
# BankHeistDeterministic-v0                             Box(0, 255, (210, 160, 3), uint8)
# BankHeistNoFrameskip-v0                               Box(0, 255, (210, 160, 3), uint8)
# BankHeist-v4                                          Box(0, 255, (210, 160, 3), uint8)
# BankHeistDeterministic-v4                             Box(0, 255, (210, 160, 3), uint8)
# BankHeistNoFrameskip-v4                               Box(0, 255, (210, 160, 3), uint8)
# BankHeist-ram-v0                                             Box(0, 255, (128,), uint8)
# BankHeist-ramDeterministic-v0                                Box(0, 255, (128,), uint8)
# BankHeist-ramNoFrameskip-v0                                  Box(0, 255, (128,), uint8)
# BankHeist-ram-v4                                             Box(0, 255, (128,), uint8)
# BankHeist-ramDeterministic-v4                                Box(0, 255, (128,), uint8)
# BankHeist-ramNoFrameskip-v4                                  Box(0, 255, (128,), uint8)
# BattleZone-v0                                         Box(0, 255, (210, 160, 3), uint8)
# BattleZoneDeterministic-v0                            Box(0, 255, (210, 160, 3), uint8)
# BattleZoneNoFrameskip-v0                              Box(0, 255, (210, 160, 3), uint8)
# BattleZone-v4                                         Box(0, 255, (210, 160, 3), uint8)
# BattleZoneDeterministic-v4                            Box(0, 255, (210, 160, 3), uint8)
# BattleZoneNoFrameskip-v4                              Box(0, 255, (210, 160, 3), uint8)
# BattleZone-ram-v0                                            Box(0, 255, (128,), uint8)
# BattleZone-ramDeterministic-v0                               Box(0, 255, (128,), uint8)
# BattleZone-ramNoFrameskip-v0                                 Box(0, 255, (128,), uint8)
# BattleZone-ram-v4                                            Box(0, 255, (128,), uint8)
# BattleZone-ramDeterministic-v4                               Box(0, 255, (128,), uint8)
# BattleZone-ramNoFrameskip-v4                                 Box(0, 255, (128,), uint8)
# BeamRider-v0                                          Box(0, 255, (210, 160, 3), uint8)
# BeamRiderDeterministic-v0                             Box(0, 255, (210, 160, 3), uint8)
# BeamRiderNoFrameskip-v0                               Box(0, 255, (210, 160, 3), uint8)
# BeamRider-v4                                          Box(0, 255, (210, 160, 3), uint8)
# BeamRiderDeterministic-v4                             Box(0, 255, (210, 160, 3), uint8)
# BeamRiderNoFrameskip-v4                               Box(0, 255, (210, 160, 3), uint8)
# BeamRider-ram-v0                                             Box(0, 255, (128,), uint8)
# BeamRider-ramDeterministic-v0                                Box(0, 255, (128,), uint8)
# BeamRider-ramNoFrameskip-v0                                  Box(0, 255, (128,), uint8)
# BeamRider-ram-v4                                             Box(0, 255, (128,), uint8)
# BeamRider-ramDeterministic-v4                                Box(0, 255, (128,), uint8)
# BeamRider-ramNoFrameskip-v4                                  Box(0, 255, (128,), uint8)
# Berzerk-v0                                            Box(0, 255, (210, 160, 3), uint8)
# BerzerkDeterministic-v0                               Box(0, 255, (210, 160, 3), uint8)
# BerzerkNoFrameskip-v0                                 Box(0, 255, (210, 160, 3), uint8)
# Berzerk-v4                                            Box(0, 255, (210, 160, 3), uint8)
# BerzerkDeterministic-v4                               Box(0, 255, (210, 160, 3), uint8)
# BerzerkNoFrameskip-v4                                 Box(0, 255, (210, 160, 3), uint8)
# Berzerk-ram-v0                                               Box(0, 255, (128,), uint8)
# Berzerk-ramDeterministic-v0                                  Box(0, 255, (128,), uint8)
# Berzerk-ramNoFrameskip-v0                                    Box(0, 255, (128,), uint8)
# Berzerk-ram-v4                                               Box(0, 255, (128,), uint8)
# Berzerk-ramDeterministic-v4                                  Box(0, 255, (128,), uint8)
# Berzerk-ramNoFrameskip-v4                                    Box(0, 255, (128,), uint8)
# Bowling-v0                                            Box(0, 255, (210, 160, 3), uint8)
# BowlingDeterministic-v0                               Box(0, 255, (210, 160, 3), uint8)
# BowlingNoFrameskip-v0                                 Box(0, 255, (210, 160, 3), uint8)
# Bowling-v4                                            Box(0, 255, (210, 160, 3), uint8)
# BowlingDeterministic-v4                               Box(0, 255, (210, 160, 3), uint8)
# BowlingNoFrameskip-v4                                 Box(0, 255, (210, 160, 3), uint8)
# Bowling-ram-v0                                               Box(0, 255, (128,), uint8)
# Bowling-ramDeterministic-v0                                  Box(0, 255, (128,), uint8)
# Bowling-ramNoFrameskip-v0                                    Box(0, 255, (128,), uint8)
# Bowling-ram-v4                                               Box(0, 255, (128,), uint8)
# Bowling-ramDeterministic-v4                                  Box(0, 255, (128,), uint8)
# Bowling-ramNoFrameskip-v4                                    Box(0, 255, (128,), uint8)
# Boxing-v0                                             Box(0, 255, (210, 160, 3), uint8)
# BoxingDeterministic-v0                                Box(0, 255, (210, 160, 3), uint8)
# BoxingNoFrameskip-v0                                  Box(0, 255, (210, 160, 3), uint8)
# Boxing-v4                                             Box(0, 255, (210, 160, 3), uint8)
# BoxingDeterministic-v4                                Box(0, 255, (210, 160, 3), uint8)
# BoxingNoFrameskip-v4                                  Box(0, 255, (210, 160, 3), uint8)
# Boxing-ram-v0                                                Box(0, 255, (128,), uint8)
# Boxing-ramDeterministic-v0                                   Box(0, 255, (128,), uint8)
# Boxing-ramNoFrameskip-v0                                     Box(0, 255, (128,), uint8)
# Boxing-ram-v4                                                Box(0, 255, (128,), uint8)
# Boxing-ramDeterministic-v4                                   Box(0, 255, (128,), uint8)
# Boxing-ramNoFrameskip-v4                                     Box(0, 255, (128,), uint8)
# Breakout-v0                                           Box(0, 255, (210, 160, 3), uint8)
# BreakoutDeterministic-v0                              Box(0, 255, (210, 160, 3), uint8)
# BreakoutNoFrameskip-v0                                Box(0, 255, (210, 160, 3), uint8)
# Breakout-v4                                           Box(0, 255, (210, 160, 3), uint8)
# BreakoutDeterministic-v4                              Box(0, 255, (210, 160, 3), uint8)
# BreakoutNoFrameskip-v4                                Box(0, 255, (210, 160, 3), uint8)
# Breakout-ram-v0                                              Box(0, 255, (128,), uint8)
# Breakout-ramDeterministic-v0                                 Box(0, 255, (128,), uint8)
# Breakout-ramNoFrameskip-v0                                   Box(0, 255, (128,), uint8)
# Breakout-ram-v4                                              Box(0, 255, (128,), uint8)
# Breakout-ramDeterministic-v4                                 Box(0, 255, (128,), uint8)
# Breakout-ramNoFrameskip-v4                                   Box(0, 255, (128,), uint8)
# Carnival-v0                                           Box(0, 255, (214, 160, 3), uint8)
# CarnivalDeterministic-v0                              Box(0, 255, (214, 160, 3), uint8)
# CarnivalNoFrameskip-v0                                Box(0, 255, (214, 160, 3), uint8)
# Carnival-v4                                           Box(0, 255, (214, 160, 3), uint8)
# CarnivalDeterministic-v4                              Box(0, 255, (214, 160, 3), uint8)
# CarnivalNoFrameskip-v4                                Box(0, 255, (214, 160, 3), uint8)
# Carnival-ram-v0                                              Box(0, 255, (128,), uint8)
# Carnival-ramDeterministic-v0                                 Box(0, 255, (128,), uint8)
# Carnival-ramNoFrameskip-v0                                   Box(0, 255, (128,), uint8)
# Carnival-ram-v4                                              Box(0, 255, (128,), uint8)
# Carnival-ramDeterministic-v4                                 Box(0, 255, (128,), uint8)
# Carnival-ramNoFrameskip-v4                                   Box(0, 255, (128,), uint8)
# Centipede-v0                                          Box(0, 255, (210, 160, 3), uint8)
# CentipedeDeterministic-v0                             Box(0, 255, (210, 160, 3), uint8)
# CentipedeNoFrameskip-v0                               Box(0, 255, (210, 160, 3), uint8)
# Centipede-v4                                          Box(0, 255, (210, 160, 3), uint8)
# CentipedeDeterministic-v4                             Box(0, 255, (210, 160, 3), uint8)
# CentipedeNoFrameskip-v4                               Box(0, 255, (210, 160, 3), uint8)
# Centipede-ram-v0                                             Box(0, 255, (128,), uint8)
# Centipede-ramDeterministic-v0                                Box(0, 255, (128,), uint8)
# Centipede-ramNoFrameskip-v0                                  Box(0, 255, (128,), uint8)
# Centipede-ram-v4                                             Box(0, 255, (128,), uint8)
# Centipede-ramDeterministic-v4                                Box(0, 255, (128,), uint8)
# Centipede-ramNoFrameskip-v4                                  Box(0, 255, (128,), uint8)
# ChopperCommand-v0                                     Box(0, 255, (210, 160, 3), uint8)
# ChopperCommandDeterministic-v0                        Box(0, 255, (210, 160, 3), uint8)
# ChopperCommandNoFrameskip-v0                          Box(0, 255, (210, 160, 3), uint8)
# ChopperCommand-v4                                     Box(0, 255, (210, 160, 3), uint8)
# ChopperCommandDeterministic-v4                        Box(0, 255, (210, 160, 3), uint8)
# ChopperCommandNoFrameskip-v4                          Box(0, 255, (210, 160, 3), uint8)
# ChopperCommand-ram-v0                                        Box(0, 255, (128,), uint8)
# ChopperCommand-ramDeterministic-v0                           Box(0, 255, (128,), uint8)
# ChopperCommand-ramNoFrameskip-v0                             Box(0, 255, (128,), uint8)
# ChopperCommand-ram-v4                                        Box(0, 255, (128,), uint8)
# ChopperCommand-ramDeterministic-v4                           Box(0, 255, (128,), uint8)
# ChopperCommand-ramNoFrameskip-v4                             Box(0, 255, (128,), uint8)
# CrazyClimber-v0                                       Box(0, 255, (210, 160, 3), uint8)
# CrazyClimberDeterministic-v0                          Box(0, 255, (210, 160, 3), uint8)
# CrazyClimberNoFrameskip-v0                            Box(0, 255, (210, 160, 3), uint8)
# CrazyClimber-v4                                       Box(0, 255, (210, 160, 3), uint8)
# CrazyClimberDeterministic-v4                          Box(0, 255, (210, 160, 3), uint8)
# CrazyClimberNoFrameskip-v4                            Box(0, 255, (210, 160, 3), uint8)
# CrazyClimber-ram-v0                                          Box(0, 255, (128,), uint8)
# CrazyClimber-ramDeterministic-v0                             Box(0, 255, (128,), uint8)
# CrazyClimber-ramNoFrameskip-v0                               Box(0, 255, (128,), uint8)
# CrazyClimber-ram-v4                                          Box(0, 255, (128,), uint8)
# CrazyClimber-ramDeterministic-v4                             Box(0, 255, (128,), uint8)
# CrazyClimber-ramNoFrameskip-v4                               Box(0, 255, (128,), uint8)
# Defender-v0                                           Box(0, 255, (210, 160, 3), uint8)
# DefenderDeterministic-v0                              Box(0, 255, (210, 160, 3), uint8)
# DefenderNoFrameskip-v0                                Box(0, 255, (210, 160, 3), uint8)
# Defender-v4                                           Box(0, 255, (210, 160, 3), uint8)
# DefenderDeterministic-v4                              Box(0, 255, (210, 160, 3), uint8)
# DefenderNoFrameskip-v4                                Box(0, 255, (210, 160, 3), uint8)
# Defender-ram-v0                                              Box(0, 255, (128,), uint8)
# Defender-ramDeterministic-v0                                 Box(0, 255, (128,), uint8)
# Defender-ramNoFrameskip-v0                                   Box(0, 255, (128,), uint8)
# Defender-ram-v4                                              Box(0, 255, (128,), uint8)
# Defender-ramDeterministic-v4                                 Box(0, 255, (128,), uint8)
# Defender-ramNoFrameskip-v4                                   Box(0, 255, (128,), uint8)
# DemonAttack-v0                                        Box(0, 255, (210, 160, 3), uint8)
# DemonAttackDeterministic-v0                           Box(0, 255, (210, 160, 3), uint8)
# DemonAttackNoFrameskip-v0                             Box(0, 255, (210, 160, 3), uint8)
# DemonAttack-v4                                        Box(0, 255, (210, 160, 3), uint8)
# DemonAttackDeterministic-v4                           Box(0, 255, (210, 160, 3), uint8)
# DemonAttackNoFrameskip-v4                             Box(0, 255, (210, 160, 3), uint8)
# DemonAttack-ram-v0                                           Box(0, 255, (128,), uint8)
# DemonAttack-ramDeterministic-v0                              Box(0, 255, (128,), uint8)
# DemonAttack-ramNoFrameskip-v0                                Box(0, 255, (128,), uint8)
# DemonAttack-ram-v4                                           Box(0, 255, (128,), uint8)
# DemonAttack-ramDeterministic-v4                              Box(0, 255, (128,), uint8)
# DemonAttack-ramNoFrameskip-v4                                Box(0, 255, (128,), uint8)
# DoubleDunk-v0                                         Box(0, 255, (210, 160, 3), uint8)
# DoubleDunkDeterministic-v0                            Box(0, 255, (210, 160, 3), uint8)
# DoubleDunkNoFrameskip-v0                              Box(0, 255, (210, 160, 3), uint8)
# DoubleDunk-v4                                         Box(0, 255, (210, 160, 3), uint8)
# DoubleDunkDeterministic-v4                            Box(0, 255, (210, 160, 3), uint8)
# DoubleDunkNoFrameskip-v4                              Box(0, 255, (210, 160, 3), uint8)
# DoubleDunk-ram-v0                                            Box(0, 255, (128,), uint8)
# DoubleDunk-ramDeterministic-v0                               Box(0, 255, (128,), uint8)
# DoubleDunk-ramNoFrameskip-v0                                 Box(0, 255, (128,), uint8)
# DoubleDunk-ram-v4                                            Box(0, 255, (128,), uint8)
# DoubleDunk-ramDeterministic-v4                               Box(0, 255, (128,), uint8)
# DoubleDunk-ramNoFrameskip-v4                                 Box(0, 255, (128,), uint8)
# ElevatorAction-v0                                     Box(0, 255, (210, 160, 3), uint8)
# ElevatorActionDeterministic-v0                        Box(0, 255, (210, 160, 3), uint8)
# ElevatorActionNoFrameskip-v0                          Box(0, 255, (210, 160, 3), uint8)
# ElevatorAction-v4                                     Box(0, 255, (210, 160, 3), uint8)
# ElevatorActionDeterministic-v4                        Box(0, 255, (210, 160, 3), uint8)
# ElevatorActionNoFrameskip-v4                          Box(0, 255, (210, 160, 3), uint8)
# ElevatorAction-ram-v0                                        Box(0, 255, (128,), uint8)
# ElevatorAction-ramDeterministic-v0                           Box(0, 255, (128,), uint8)
# ElevatorAction-ramNoFrameskip-v0                             Box(0, 255, (128,), uint8)
# ElevatorAction-ram-v4                                        Box(0, 255, (128,), uint8)
# ElevatorAction-ramDeterministic-v4                           Box(0, 255, (128,), uint8)
# ElevatorAction-ramNoFrameskip-v4                             Box(0, 255, (128,), uint8)
# Enduro-v0                                             Box(0, 255, (210, 160, 3), uint8)
# EnduroDeterministic-v0                                Box(0, 255, (210, 160, 3), uint8)
# EnduroNoFrameskip-v0                                  Box(0, 255, (210, 160, 3), uint8)
# Enduro-v4                                             Box(0, 255, (210, 160, 3), uint8)
# EnduroDeterministic-v4                                Box(0, 255, (210, 160, 3), uint8)
# EnduroNoFrameskip-v4                                  Box(0, 255, (210, 160, 3), uint8)
# Enduro-ram-v0                                                Box(0, 255, (128,), uint8)
# Enduro-ramDeterministic-v0                                   Box(0, 255, (128,), uint8)
# Enduro-ramNoFrameskip-v0                                     Box(0, 255, (128,), uint8)
# Enduro-ram-v4                                                Box(0, 255, (128,), uint8)
# Enduro-ramDeterministic-v4                                   Box(0, 255, (128,), uint8)
# Enduro-ramNoFrameskip-v4                                     Box(0, 255, (128,), uint8)
# FishingDerby-v0                                       Box(0, 255, (210, 160, 3), uint8)
# FishingDerbyDeterministic-v0                          Box(0, 255, (210, 160, 3), uint8)
# FishingDerbyNoFrameskip-v0                            Box(0, 255, (210, 160, 3), uint8)
# FishingDerby-v4                                       Box(0, 255, (210, 160, 3), uint8)
# FishingDerbyDeterministic-v4                          Box(0, 255, (210, 160, 3), uint8)
# FishingDerbyNoFrameskip-v4                            Box(0, 255, (210, 160, 3), uint8)
# FishingDerby-ram-v0                                          Box(0, 255, (128,), uint8)
# FishingDerby-ramDeterministic-v0                             Box(0, 255, (128,), uint8)
# FishingDerby-ramNoFrameskip-v0                               Box(0, 255, (128,), uint8)
# FishingDerby-ram-v4                                          Box(0, 255, (128,), uint8)
# FishingDerby-ramDeterministic-v4                             Box(0, 255, (128,), uint8)
# FishingDerby-ramNoFrameskip-v4                               Box(0, 255, (128,), uint8)
# Freeway-v0                                            Box(0, 255, (210, 160, 3), uint8)
# FreewayDeterministic-v0                               Box(0, 255, (210, 160, 3), uint8)
# FreewayNoFrameskip-v0                                 Box(0, 255, (210, 160, 3), uint8)
# Freeway-v4                                            Box(0, 255, (210, 160, 3), uint8)
# FreewayDeterministic-v4                               Box(0, 255, (210, 160, 3), uint8)
# FreewayNoFrameskip-v4                                 Box(0, 255, (210, 160, 3), uint8)
# Freeway-ram-v0                                               Box(0, 255, (128,), uint8)
# Freeway-ramDeterministic-v0                                  Box(0, 255, (128,), uint8)
# Freeway-ramNoFrameskip-v0                                    Box(0, 255, (128,), uint8)
# Freeway-ram-v4                                               Box(0, 255, (128,), uint8)
# Freeway-ramDeterministic-v4                                  Box(0, 255, (128,), uint8)
# Freeway-ramNoFrameskip-v4                                    Box(0, 255, (128,), uint8)
# Frostbite-v0                                          Box(0, 255, (210, 160, 3), uint8)
# FrostbiteDeterministic-v0                             Box(0, 255, (210, 160, 3), uint8)
# FrostbiteNoFrameskip-v0                               Box(0, 255, (210, 160, 3), uint8)
# Frostbite-v4                                          Box(0, 255, (210, 160, 3), uint8)
# FrostbiteDeterministic-v4                             Box(0, 255, (210, 160, 3), uint8)
# FrostbiteNoFrameskip-v4                               Box(0, 255, (210, 160, 3), uint8)
# Frostbite-ram-v0                                             Box(0, 255, (128,), uint8)
# Frostbite-ramDeterministic-v0                                Box(0, 255, (128,), uint8)
# Frostbite-ramNoFrameskip-v0                                  Box(0, 255, (128,), uint8)
# Frostbite-ram-v4                                             Box(0, 255, (128,), uint8)
# Frostbite-ramDeterministic-v4                                Box(0, 255, (128,), uint8)
# Frostbite-ramNoFrameskip-v4                                  Box(0, 255, (128,), uint8)
# ...
# PongDeterministic-v4                  (-inf, inf)  None
# PongNoFrameskip-v4                    (-inf, inf)  None
# Pong-ram-v0                           (-inf, inf)  None
# Pong-ramDeterministic-v0              (-inf, inf)  None
# Pong-ramNoFrameskip-v0                (-inf, inf)  None
# Pong-ram-v4                           (-inf, inf)  None
# Pong-ramDeterministic-v4              (-inf, inf)  None
# Pong-ramNoFrameskip-v4                (-inf, inf)  None
# Pooyan-v0                             (-inf, inf)  None
# PooyanDeterministic-v0                (-inf, inf)  None
# PooyanNoFrameskip-v0                  (-inf, inf)  None
# Pooyan-v4                             (-inf, inf)  None
# PooyanDeterministic-v4                (-inf, inf)  None
# PooyanNoFrameskip-v4                  (-inf, inf)  None
# Pooyan-ram-v0                         (-inf, inf)  None
# Pooyan-ramDeterministic-v0            (-inf, inf)  None
# Pooyan-ramNoFrameskip-v0              (-inf, inf)  None
# Pooyan-ram-v4                         (-inf, inf)  None
# Pooyan-ramDeterministic-v4            (-inf, inf)  None
# Pooyan-ramNoFrameskip-v4              (-inf, inf)  None
# PrivateEye-v0                         (-inf, inf)  None
# PrivateEyeDeterministic-v0            (-inf, inf)  None
# PrivateEyeNoFrameskip-v0              (-inf, inf)  None
# PrivateEye-v4                         (-inf, inf)  None
# PrivateEyeDeterministic-v4            (-inf, inf)  None
# PrivateEyeNoFrameskip-v4              (-inf, inf)  None
# PrivateEye-ram-v0                     (-inf, inf)  None
# PrivateEye-ramDeterministic-v0        (-inf, inf)  None
# PrivateEye-ramNoFrameskip-v0          (-inf, inf)  None
# PrivateEye-ram-v4                     (-inf, inf)  None
# PrivateEye-ramDeterministic-v4        (-inf, inf)  None
# PrivateEye-ramNoFrameskip-v4          (-inf, inf)  None
# Qbert-v0                              (-inf, inf)  None
# QbertDeterministic-v0                 (-inf, inf)  None
# QbertNoFrameskip-v0                   (-inf, inf)  None
# Qbert-v4                              (-inf, inf)  None
# QbertDeterministic-v4                 (-inf, inf)  None
# QbertNoFrameskip-v4                   (-inf, inf)  None
# Qbert-ram-v0                          (-inf, inf)  None
# Qbert-ramDeterministic-v0             (-inf, inf)  None
# Qbert-ramNoFrameskip-v0               (-inf, inf)  None
# Qbert-ram-v4                          (-inf, inf)  None
# Qbert-ramDeterministic-v4             (-inf, inf)  None
# Qbert-ramNoFrameskip-v4               (-inf, inf)  None
# Riverraid-v0                          (-inf, inf)  None
# RiverraidDeterministic-v0             (-inf, inf)  None
# RiverraidNoFrameskip-v0               (-inf, inf)  None
# Riverraid-v4                          (-inf, inf)  None
# RiverraidDeterministic-v4             (-inf, inf)  None
# RiverraidNoFrameskip-v4               (-inf, inf)  None
# Riverraid-ram-v0                      (-inf, inf)  None
# Riverraid-ramDeterministic-v0         (-inf, inf)  None
# Riverraid-ramNoFrameskip-v0           (-inf, inf)  None
# Riverraid-ram-v4                      (-inf, inf)  None
# Riverraid-ramDeterministic-v4         (-inf, inf)  None
# Riverraid-ramNoFrameskip-v4           (-inf, inf)  None
# RoadRunner-v0                         (-inf, inf)  None
# RoadRunnerDeterministic-v0            (-inf, inf)  None
# RoadRunnerNoFrameskip-v0              (-inf, inf)  None
# RoadRunner-v4                         (-inf, inf)  None
# RoadRunnerDeterministic-v4            (-inf, inf)  None
# RoadRunnerNoFrameskip-v4              (-inf, inf)  None
# RoadRunner-ram-v0                     (-inf, inf)  None
# RoadRunner-ramDeterministic-v0        (-inf, inf)  None
# RoadRunner-ramNoFrameskip-v0          (-inf, inf)  None
# RoadRunner-ram-v4                     (-inf, inf)  None
# RoadRunner-ramDeterministic-v4        (-inf, inf)  None
# RoadRunner-ramNoFrameskip-v4          (-inf, inf)  None
# Robotank-v0                           (-inf, inf)  None
# RobotankDeterministic-v0              (-inf, inf)  None
# RobotankNoFrameskip-v0                (-inf, inf)  None
# Robotank-v4                           (-inf, inf)  None
# RobotankDeterministic-v4              (-inf, inf)  None
# RobotankNoFrameskip-v4                (-inf, inf)  None
# Robotank-ram-v0                       (-inf, inf)  None
# Robotank-ramDeterministic-v0          (-inf, inf)  None
# Robotank-ramNoFrameskip-v0            (-inf, inf)  None
# Robotank-ram-v4                       (-inf, inf)  None
# Robotank-ramDeterministic-v4          (-inf, inf)  None
# Robotank-ramNoFrameskip-v4            (-inf, inf)  None
# Seaquest-v0                           (-inf, inf)  None
# SeaquestDeterministic-v0              (-inf, inf)  None
# SeaquestNoFrameskip-v0                (-inf, inf)  None
# Seaquest-v4                           (-inf, inf)  None
# SeaquestDeterministic-v4              (-inf, inf)  None
# SeaquestNoFrameskip-v4                (-inf, inf)  None
# Seaquest-ram-v0                       (-inf, inf)  None
# Seaquest-ramDeterministic-v0          (-inf, inf)  None
# Seaquest-ramNoFrameskip-v0            (-inf, inf)  None
# Seaquest-ram-v4                       (-inf, inf)  None
# Seaquest-ramDeterministic-v4          (-inf, inf)  None
# Seaquest-ramNoFrameskip-v4            (-inf, inf)  None
# Skiing-v0                             (-inf, inf)  None
# SkiingDeterministic-v0                (-inf, inf)  None
# SkiingNoFrameskip-v0                  (-inf, inf)  None
# Skiing-v4                             (-inf, inf)  None
# SkiingDeterministic-v4                (-inf, inf)  None
# SkiingNoFrameskip-v4                  (-inf, inf)  None
# Skiing-ram-v0                         (-inf, inf)  None
# Skiing-ramDeterministic-v0            (-inf, inf)  None
# Skiing-ramNoFrameskip-v0              (-inf, inf)  None
# Skiing-ram-v4                         (-inf, inf)  None
# Skiing-ramDeterministic-v4            (-inf, inf)  None
# Skiing-ramNoFrameskip-v4              (-inf, inf)  None
# Solaris-v0                            (-inf, inf)  None
# SolarisDeterministic-v0               (-inf, inf)  None
# SolarisNoFrameskip-v0                 (-inf, inf)  None
# Solaris-v4                            (-inf, inf)  None
# SolarisDeterministic-v4               (-inf, inf)  None
# SolarisNoFrameskip-v4                 (-inf, inf)  None
# Solaris-ram-v0                        (-inf, inf)  None
# Solaris-ramDeterministic-v0           (-inf, inf)  None
# Solaris-ramNoFrameskip-v0             (-inf, inf)  None
# Solaris-ram-v4                        (-inf, inf)  None
# Solaris-ramDeterministic-v4           (-inf, inf)  None
# Solaris-ramNoFrameskip-v4             (-inf, inf)  None
# SpaceInvaders-v0                      (-inf, inf)  None
# SpaceInvadersDeterministic-v0         (-inf, inf)  None
# SpaceInvadersNoFrameskip-v0           (-inf, inf)  None
# SpaceInvaders-v4                      (-inf, inf)  None
# SpaceInvadersDeterministic-v4         (-inf, inf)  None
# SpaceInvadersNoFrameskip-v4           (-inf, inf)  None
# SpaceInvaders-ram-v0                  (-inf, inf)  None
# SpaceInvaders-ramDeterministic-v0     (-inf, inf)  None
# SpaceInvaders-ramNoFrameskip-v0       (-inf, inf)  None
# SpaceInvaders-ram-v4                  (-inf, inf)  None
# SpaceInvaders-ramDeterministic-v4     (-inf, inf)  None
# SpaceInvaders-ramNoFrameskip-v4       (-inf, inf)  None
# StarGunner-v0                         (-inf, inf)  None
# StarGunnerDeterministic-v0            (-inf, inf)  None
# StarGunnerNoFrameskip-v0              (-inf, inf)  None
# StarGunner-v4                         (-inf, inf)  None
# StarGunnerDeterministic-v4            (-inf, inf)  None
# StarGunnerNoFrameskip-v4              (-inf, inf)  None
# StarGunner-ram-v0                     (-inf, inf)  None
# StarGunner-ramDeterministic-v0        (-inf, inf)  None
# StarGunner-ramNoFrameskip-v0          (-inf, inf)  None
# StarGunner-ram-v4                     (-inf, inf)  None
# StarGunner-ramDeterministic-v4        (-inf, inf)  None
# StarGunner-ramNoFrameskip-v4          (-inf, inf)  None
# Tennis-v0                             (-inf, inf)  None
# TennisDeterministic-v0                (-inf, inf)  None
# TennisNoFrameskip-v0                  (-inf, inf)  None
# Tennis-v4                             (-inf, inf)  None
# TennisDeterministic-v4                (-inf, inf)  None
# TennisNoFrameskip-v4                  (-inf, inf)  None
# Tennis-ram-v0                         (-inf, inf)  None
# Tennis-ramDeterministic-v0            (-inf, inf)  None
# Tennis-ramNoFrameskip-v0              (-inf, inf)  None
# Tennis-ram-v4                         (-inf, inf)  None
# Tennis-ramDeterministic-v4            (-inf, inf)  None
# Tennis-ramNoFrameskip-v4              (-inf, inf)  None
# TimePilot-v0                          (-inf, inf)  None
# TimePilotDeterministic-v0             (-inf, inf)  None
# TimePilotNoFrameskip-v0               (-inf, inf)  None
# TimePilot-v4                          (-inf, inf)  None
# TimePilotDeterministic-v4             (-inf, inf)  None
# TimePilotNoFrameskip-v4               (-inf, inf)  None
# TimePilot-ram-v0                      (-inf, inf)  None
# TimePilot-ramDeterministic-v0         (-inf, inf)  None
# TimePilot-ramNoFrameskip-v0           (-inf, inf)  None
# TimePilot-ram-v4                      (-inf, inf)  None
# TimePilot-ramDeterministic-v4         (-inf, inf)  None
# TimePilot-ramNoFrameskip-v4           (-inf, inf)  None
# Tutankham-v0                          (-inf, inf)  None
# TutankhamDeterministic-v0             (-inf, inf)  None
# TutankhamNoFrameskip-v0               (-inf, inf)  None
# Tutankham-v4                          (-inf, inf)  None
# TutankhamDeterministic-v4             (-inf, inf)  None
# TutankhamNoFrameskip-v4               (-inf, inf)  None
# Tutankham-ram-v0                      (-inf, inf)  None
# Tutankham-ramDeterministic-v0         (-inf, inf)  None
# Tutankham-ramNoFrameskip-v0           (-inf, inf)  None
# Tutankham-ram-v4                      (-inf, inf)  None
# Tutankham-ramDeterministic-v4         (-inf, inf)  None
# Tutankham-ramNoFrameskip-v4           (-inf, inf)  None
# UpNDown-v0                            (-inf, inf)  None
# UpNDownDeterministic-v0               (-inf, inf)  None
# UpNDownNoFrameskip-v0                 (-inf, inf)  None
# UpNDown-v4                            (-inf, inf)  None
# UpNDownDeterministic-v4               (-inf, inf)  None
# UpNDownNoFrameskip-v4                 (-inf, inf)  None
# UpNDown-ram-v0                        (-inf, inf)  None
# UpNDown-ramDeterministic-v0           (-inf, inf)  None
# UpNDown-ramNoFrameskip-v0             (-inf, inf)  None
# UpNDown-ram-v4                        (-inf, inf)  None
# UpNDown-ramDeterministic-v4           (-inf, inf)  None
# UpNDown-ramNoFrameskip-v4             (-inf, inf)  None
# Venture-v0                            (-inf, inf)  None
# VentureDeterministic-v0               (-inf, inf)  None
# VentureNoFrameskip-v0                 (-inf, inf)  None
# Venture-v4                            (-inf, inf)  None
# VentureDeterministic-v4               (-inf, inf)  None
# VentureNoFrameskip-v4                 (-inf, inf)  None
# Venture-ram-v0                        (-inf, inf)  None
# Venture-ramDeterministic-v0           (-inf, inf)  None
# Venture-ramNoFrameskip-v0             (-inf, inf)  None
# Venture-ram-v4                        (-inf, inf)  None
# Venture-ramDeterministic-v4           (-inf, inf)  None
# Venture-ramNoFrameskip-v4             (-inf, inf)  None
# VideoPinball-v0                       (-inf, inf)  None
# VideoPinballDeterministic-v0          (-inf, inf)  None
# VideoPinballNoFrameskip-v0            (-inf, inf)  None
# VideoPinball-v4                       (-inf, inf)  None
# VideoPinballDeterministic-v4          (-inf, inf)  None
# VideoPinballNoFrameskip-v4            (-inf, inf)  None
# VideoPinball-ram-v0                   (-inf, inf)  None
# VideoPinball-ramDeterministic-v0      (-inf, inf)  None
# VideoPinball-ramNoFrameskip-v0        (-inf, inf)  None
# VideoPinball-ram-v4                   (-inf, inf)  None
# VideoPinball-ramDeterministic-v4      (-inf, inf)  None
# VideoPinball-ramNoFrameskip-v4        (-inf, inf)  None
# WizardOfWor-v0                        (-inf, inf)  None
# WizardOfWorDeterministic-v0           (-inf, inf)  None
# WizardOfWorNoFrameskip-v0             (-inf, inf)  None
# WizardOfWor-v4                        (-inf, inf)  None
# WizardOfWorDeterministic-v4           (-inf, inf)  None
# WizardOfWorNoFrameskip-v4             (-inf, inf)  None
# WizardOfWor-ram-v0                    (-inf, inf)  None
# WizardOfWor-ramDeterministic-v0       (-inf, inf)  None
# WizardOfWor-ramNoFrameskip-v0         (-inf, inf)  None
# WizardOfWor-ram-v4                    (-inf, inf)  None
# WizardOfWor-ramDeterministic-v4       (-inf, inf)  None
# WizardOfWor-ramNoFrameskip-v4         (-inf, inf)  None
# YarsRevenge-v0                        (-inf, inf)  None
# YarsRevengeDeterministic-v0           (-inf, inf)  None
# YarsRevengeNoFrameskip-v0             (-inf, inf)  None
# YarsRevenge-v4                        (-inf, inf)  None
# YarsRevengeDeterministic-v4           (-inf, inf)  None
# YarsRevengeNoFrameskip-v4             (-inf, inf)  None
# YarsRevenge-ram-v0                    (-inf, inf)  None
# YarsRevenge-ramDeterministic-v0       (-inf, inf)  None
# YarsRevenge-ramNoFrameskip-v0         (-inf, inf)  None
# YarsRevenge-ram-v4                    (-inf, inf)  None
# YarsRevenge-ramDeterministic-v4       (-inf, inf)  None
# YarsRevenge-ramNoFrameskip-v4         (-inf, inf)  None
# Zaxxon-v0                             (-inf, inf)  None
# ZaxxonDeterministic-v0                (-inf, inf)  None
# ZaxxonNoFrameskip-v0                  (-inf, inf)  None
# Zaxxon-v4                             (-inf, inf)  None
# ZaxxonDeterministic-v4                (-inf, inf)  None
# ZaxxonNoFrameskip-v4                  (-inf, inf)  None
# Zaxxon-ram-v0                         (-inf, inf)  None
# Zaxxon-ramDeterministic-v0            (-inf, inf)  None
# Zaxxon-ramNoFrameskip-v0              (-inf, inf)  None
# Zaxxon-ram-v4                         (-inf, inf)  None
# Zaxxon-ramDeterministic-v4            (-inf, inf)  None
# Zaxxon-ramNoFrameskip-v4              (-inf, inf)  None
# CartPole-v0                           (-inf, inf)   200
# CartPole-v1                           (-inf, inf)   500
# MountainCar-v0                        (-inf, inf)   200
# MountainCarContinuous-v0              (-inf, inf)   999
# Pendulum-v1                           (-inf, inf)   200
# Acrobot-v1                            (-inf, inf)   500
# LunarLander-v2                        (-inf, inf)  1000
# LunarLanderContinuous-v2              (-inf, inf)  1000
# BipedalWalker-v3                      (-inf, inf)  1600
# BipedalWalkerHardcore-v3              (-inf, inf)  2000
# CarRacing-v2                          (-inf, inf)  1000
# Blackjack-v1                          (-inf, inf)  None
# FrozenLake-v1                              (0, 1)   100
# FrozenLake8x8-v1                           (0, 1)   200
# CliffWalking-v0                       (-inf, inf)  None
# Taxi-v3                               (-inf, inf)   200
# Reacher-v4                            (-inf, inf)    50
# Pusher-v4                             (-inf, inf)   100
# InvertedPendulum-v4                   (-inf, inf)  1000
# InvertedDoublePendulum-v4             (-inf, inf)  1000
# HalfCheetah-v4                        (-inf, inf)  1000
# Hopper-v4                             (-inf, inf)  1000
# Swimmer-v4                            (-inf, inf)  1000
# Walker2d-v4                           (-inf, inf)  1000
# Ant-v4                                (-inf, inf)  1000
# Humanoid-v4                           (-inf, inf)  1000
# HumanoidStandup-v4                    (-inf, inf)  1000

# %% [markdown]
# # 小车上山 MountainCar-v0

# %% [markdown]
# 环境：Gym库的 MountainCar-v0

# %%
env = gym.make('MountainCar-v0')
print('观测空间 = {}'.format(env.observation_space))
print('动作空间 = {}'.format(env.action_space))
print('观测范围 = {} ~ {}'.format(env.observation_space.low,
        env.observation_space.high))
print('动作数 = {}'.format(env.action_space.n))
# Out:
# 观测空间 = Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# 动作空间 = Discrete(3)
# 观测范围 = [-1.2  -0.07] ~ [0.6  0.07]
# 动作数 = 3

# %% [markdown]
# 智能体：一个根据指定确定性策略决定动作并且不学习的智能体

# %%
class BespokeAgent:
    def __init__(self, env):
        pass

    def decide(self, observation): # 决策
        position, velocity = observation
        lb = min(-0.09 * (position + 0.25) ** 2 + 0.03,
                0.3 * (position + 0.9) ** 4 - 0.008)
        ub = -0.07 * (position + 0.38) ** 2 + 0.07
        if lb < velocity < ub:
            action = 2
        else:
            action = 0
        return action # 返回动作

    def learn(self, *args): # 学习
        pass

agent = BespokeAgent(env)

# %% [markdown]
# 智能体与环境交互

# %%
def play_montecarlo(env, agent, render=False, train=False):
    episode_reward = 0. # 记录回合总奖励，初始化为0
    observation, _ = env.reset() # 重置游戏环境，开始新回合
    while True: # 不断循环，直到回合结束
        if render: # 判断是否显示
            env.render() # 显示图形界面，图形界面可以用 env.close() 语句关闭
        action = agent.decide(observation)
        next_observation, reward, terminated, truncated, _ = env.step(action) # 执行动作
        episode_reward += reward # 收集回合奖励
        if train: # 判断是否训练智能体
            agent.learn(observation, action, reward, terminated, truncated) # 学习
        if terminated or truncated: # 回合结束，跳出循环
            break
        observation = next_observation
    return episode_reward # 返回回合总奖励

# %% [markdown]
# 交互1回合，并图形化显示

# %%
episode_reward = play_montecarlo(env, agent, render=True)
print('回合奖励 = {}'.format(episode_reward))
env.close() # 此语句可关闭图形界面
# Out:
# 回合奖励 = -103.0

# %% [markdown]
# 评估性能：交互100回合求平均

# %%
episode_rewards = [play_montecarlo(env, agent) for _ in range(100)]
print('平均回合奖励 = {}'.format(np.mean(episode_rewards)))
# Out:
# 平均回合奖励 = -107.42
