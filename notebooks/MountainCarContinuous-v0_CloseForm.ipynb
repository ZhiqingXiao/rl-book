# %% [markdown]
# # Use Close-Form Policy to Play MoutainCarContinuous-v0

# %%
import sys
import logging
import imp
import itertools

import numpy as np
np.random.seed(0)
import gym

imp.reload(logging)
logging.basicConfig(level=logging.DEBUG,
        format='%(asctime)s [%(levelname)s] %(message)s',
        stream=sys.stdout, datefmt='%H:%M:%S')

# %%
env = gym.make('MountainCarContinuous-v0')
env.seed(0)
for key in vars(env):
    logging.info('%s: %s', key, vars(env)[key])
# Out:
# 19:59:17 [INFO] env: <Continuous_MountainCarEnv<MountainCarContinuous-v0>>
# 19:59:17 [INFO] action_space: Box(1,)
# 19:59:17 [INFO] observation_space: Box(2,)
# 19:59:17 [INFO] reward_range: (-inf, inf)
# 19:59:17 [INFO] metadata: {'render.modes': ['human', 'rgb_array'], 'video.frames_per_second': 30}
# 19:59:17 [INFO] _max_episode_steps: 999
# 19:59:17 [INFO] _elapsed_steps: None

# %%
class CloseFormAgent:
    def __init__(self, _):
        pass

    def reset(self, mode=None):
        pass

    def step(self, observation, _reward, _done):
        position, velocity = observation
        if position > -4 * velocity or position < 13 * velocity - 0.6:
            force = 1.
        else:
            force = -1.
        action = np.array([force,])
        return action

    def close(self):
        pass


agent = CloseFormAgent(env)

# %%
def play_episode(env, agent, max_episode_steps=None, mode=None, render=False):
    observation, reward, done = env.reset(), 0., False
    agent.reset(mode=mode)
    episode_reward, elapsed_steps = 0., 0
    while True:
        action = agent.step(observation, reward, done)
        if render:
            env.render()
        if done:
            break
        observation, reward, done, _ = env.step(action)
        episode_reward += reward
        elapsed_steps += 1
        if max_episode_steps and elapsed_steps >= max_episode_steps:
            break
    agent.close()
    return episode_reward, elapsed_steps


logging.info('==== test ====')
episode_rewards = []
for episode in range(100):
    episode_reward, elapsed_steps = play_episode(env, agent)
    episode_rewards.append(episode_reward)
    logging.debug('test episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
logging.info('average episode reward = %.2f ± %.2f',
        np.mean(episode_rewards), np.std(episode_rewards))
# Out:
# 19:59:17 [INFO] ==== test ====
# 19:59:17 [DEBUG] test episode 0: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 1: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 2: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 3: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 4: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 5: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 6: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 7: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 8: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 9: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 10: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 11: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 12: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 13: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 14: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 15: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 16: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 17: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 18: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 19: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 20: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 21: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 22: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 23: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 24: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 25: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 26: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 27: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 28: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 29: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 30: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 31: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 32: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 33: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 34: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 35: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 36: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 37: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 38: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 39: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 40: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 41: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 42: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 43: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 44: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 45: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 46: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 47: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 48: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 49: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 50: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 51: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 52: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 53: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 54: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 55: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 56: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 57: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 58: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 59: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 60: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 61: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 62: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 63: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 64: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 65: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 66: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 67: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 68: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 69: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 70: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 71: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 72: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 73: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 74: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 75: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 76: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 77: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 78: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 79: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 80: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 81: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 82: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 83: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 84: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 85: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 86: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 87: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 88: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 89: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 90: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 91: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 92: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 93: reward = 93.30, steps = 67
# 19:59:17 [DEBUG] test episode 94: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 95: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 96: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 97: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 98: reward = 93.40, steps = 66
# 19:59:17 [DEBUG] test episode 99: reward = 93.30, steps = 67
# 19:59:17 [INFO] average episode reward = 93.35 ± 0.05

# %%
env.close()
