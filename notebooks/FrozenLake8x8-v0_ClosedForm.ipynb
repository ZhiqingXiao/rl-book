# %% [markdown]
# # Use Closed-Form Policy to Play FrozenLake8x8-v0

# %%
import sys
import logging
import imp
import itertools

import numpy as np
np.random.seed(0)
import gym

imp.reload(logging)
logging.basicConfig(level=logging.DEBUG,
        format='%(asctime)s [%(levelname)s] %(message)s',
        stream=sys.stdout, datefmt='%H:%M:%S')

# %%
env = gym.make('FrozenLake8x8-v0')
env.seed(0)
for key in vars(env):
    logging.info('%s: %s', key, vars(env)[key])
for key in vars(env.spec):
    logging.info('%s: %s', key, vars(env.spec)[key])
# Out:
# 00:00:00 [INFO] env: <FrozenLakeEnv<FrozenLake8x8-v0>>
# 00:00:00 [INFO] action_space: Discrete(4)
# 00:00:00 [INFO] observation_space: Discrete(64)
# 00:00:00 [INFO] reward_range: (0, 1)
# 00:00:00 [INFO] metadata: {'render.modes': ['human', 'ansi']}
# 00:00:00 [INFO] _max_episode_steps: 200
# 00:00:00 [INFO] _elapsed_steps: None
# 00:00:00 [INFO] id: FrozenLake8x8-v0
# 00:00:00 [INFO] entry_point: gym.envs.toy_text:FrozenLakeEnv
# 00:00:00 [INFO] reward_threshold: 0.99
# 00:00:00 [INFO] nondeterministic: False
# 00:00:00 [INFO] max_episode_steps: 200
# 00:00:00 [INFO] _kwargs: {'map_name': '8x8'}
# 00:00:00 [INFO] _env_name: FrozenLake8x8

# %%
class ClosedFormAgent:
    def __init__(self, env):
        state_n, action_n = env.observation_space.n, env.action_space.n
        v = np.zeros((env.spec.max_episode_steps+1, state_n))
        q = np.zeros((env.spec.max_episode_steps+1, state_n, action_n))
        pi = np.zeros((env.spec.max_episode_steps+1, state_n))
        for t in range(env.spec.max_episode_steps-1, -1, -1):
            for s in range(state_n):
                for a in range(action_n):
                    for p, next_s, r, d in env.P[s][a]:
                        q[t, s, a] += p * (r + (1. - float(d)) * v[t+1, next_s])
                v[t, s] = q[t, s].max()
                pi[t, s] = q[t, s].argmax()
        self.pi = pi

    def reset(self, mode=None):
        self.t = 0

    def step(self, observation, _reward, _done):
        action = self.pi[self.t, observation]
        self.t += 1
        return action

    def close(self):
        pass


agent = ClosedFormAgent(env)

# %%
def play_episode(env, agent, max_episode_steps=None, mode=None, render=False):
    observation, reward, done = env.reset(), 0., False
    agent.reset(mode=mode)
    episode_reward, elapsed_steps = 0., 0
    while True:
        action = agent.step(observation, reward, done)
        if render:
            env.render()
        if done:
            break
        observation, reward, done, _ = env.step(action)
        episode_reward += reward
        elapsed_steps += 1
        if max_episode_steps and elapsed_steps >= max_episode_steps:
            break
    agent.close()
    return episode_reward, elapsed_steps


logging.info('==== test ====')
episode_rewards = []
for episode in range(100):
    episode_reward, elapsed_steps = play_episode(env, agent)
    episode_rewards.append(episode_reward)
    logging.debug('test episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
logging.info('average episode reward = %.2f ± %.2f',
        np.mean(episode_rewards), np.std(episode_rewards))
# Out:
# 00:00:00 [INFO] ==== test ====
# 00:00:00 [DEBUG] test episode 0: reward = 1.00, steps = 160
# 00:00:00 [DEBUG] test episode 1: reward = 1.00, steps = 89
# 00:00:00 [DEBUG] test episode 2: reward = 0.00, steps = 195
# 00:00:00 [DEBUG] test episode 3: reward = 1.00, steps = 94
# 00:00:00 [DEBUG] test episode 4: reward = 1.00, steps = 196
# 00:00:00 [DEBUG] test episode 5: reward = 0.00, steps = 200
# 00:00:00 [DEBUG] test episode 6: reward = 1.00, steps = 189
# 00:00:00 [DEBUG] test episode 7: reward = 1.00, steps = 141
# 00:00:00 [DEBUG] test episode 8: reward = 1.00, steps = 103
# 00:00:00 [DEBUG] test episode 9: reward = 1.00, steps = 191
# 00:00:00 [DEBUG] test episode 10: reward = 1.00, steps = 83
# 00:00:00 [DEBUG] test episode 11: reward = 1.00, steps = 120
# 00:00:00 [DEBUG] test episode 12: reward = 1.00, steps = 83
# 00:00:00 [DEBUG] test episode 13: reward = 1.00, steps = 140
# 00:00:00 [DEBUG] test episode 14: reward = 1.00, steps = 70
# 00:00:00 [DEBUG] test episode 15: reward = 1.00, steps = 132
# 00:00:00 [DEBUG] test episode 16: reward = 1.00, steps = 100
# 00:00:00 [DEBUG] test episode 17: reward = 1.00, steps = 146
# 00:00:00 [DEBUG] test episode 18: reward = 0.00, steps = 198
# 00:00:00 [DEBUG] test episode 19: reward = 1.00, steps = 44
# 00:00:00 [DEBUG] test episode 20: reward = 1.00, steps = 75
# 00:00:00 [DEBUG] test episode 21: reward = 1.00, steps = 51
# 00:00:00 [DEBUG] test episode 22: reward = 1.00, steps = 111
# 00:00:00 [DEBUG] test episode 23: reward = 1.00, steps = 28
# 00:00:00 [DEBUG] test episode 24: reward = 1.00, steps = 189
# 00:00:00 [DEBUG] test episode 25: reward = 1.00, steps = 59
# 00:00:00 [DEBUG] test episode 26: reward = 1.00, steps = 36
# 00:00:00 [DEBUG] test episode 27: reward = 1.00, steps = 50
# 00:00:00 [DEBUG] test episode 28: reward = 1.00, steps = 136
# 00:00:00 [DEBUG] test episode 29: reward = 0.00, steps = 194
# 00:00:00 [DEBUG] test episode 30: reward = 1.00, steps = 177
# 00:00:00 [DEBUG] test episode 31: reward = 0.00, steps = 198
# 00:00:00 [DEBUG] test episode 32: reward = 1.00, steps = 167
# 00:00:00 [DEBUG] test episode 33: reward = 1.00, steps = 36
# 00:00:00 [DEBUG] test episode 34: reward = 1.00, steps = 66
# 00:00:00 [DEBUG] test episode 35: reward = 1.00, steps = 121
# 00:00:00 [DEBUG] test episode 36: reward = 0.00, steps = 174
# 00:00:00 [DEBUG] test episode 37: reward = 1.00, steps = 117
# 00:00:00 [DEBUG] test episode 38: reward = 0.00, steps = 200
# 00:00:00 [DEBUG] test episode 39: reward = 1.00, steps = 132
# 00:00:00 [DEBUG] test episode 40: reward = 1.00, steps = 176
# 00:00:00 [DEBUG] test episode 41: reward = 0.00, steps = 197
# 00:00:00 [DEBUG] test episode 42: reward = 1.00, steps = 59
# 00:00:00 [DEBUG] test episode 43: reward = 1.00, steps = 125
# 00:00:00 [DEBUG] test episode 44: reward = 1.00, steps = 117
# 00:00:00 [DEBUG] test episode 45: reward = 1.00, steps = 109
# 00:00:00 [DEBUG] test episode 46: reward = 1.00, steps = 39
# 00:00:00 [DEBUG] test episode 47: reward = 1.00, steps = 165
# 00:00:00 [DEBUG] test episode 48: reward = 1.00, steps = 118
# 00:00:00 [DEBUG] test episode 49: reward = 1.00, steps = 164
# 00:00:00 [DEBUG] test episode 50: reward = 1.00, steps = 133
# 00:00:00 [DEBUG] test episode 51: reward = 1.00, steps = 96
# 00:00:01 [DEBUG] test episode 52: reward = 1.00, steps = 74
# 00:00:01 [DEBUG] test episode 53: reward = 1.00, steps = 84
# 00:00:01 [DEBUG] test episode 54: reward = 1.00, steps = 61
# 00:00:01 [DEBUG] test episode 55: reward = 1.00, steps = 111
# 00:00:01 [DEBUG] test episode 56: reward = 1.00, steps = 40
# 00:00:01 [DEBUG] test episode 57: reward = 1.00, steps = 81
# 00:00:01 [DEBUG] test episode 58: reward = 1.00, steps = 153
# 00:00:01 [DEBUG] test episode 59: reward = 1.00, steps = 59
# 00:00:01 [DEBUG] test episode 60: reward = 1.00, steps = 57
# 00:00:01 [DEBUG] test episode 61: reward = 1.00, steps = 28
# 00:00:01 [DEBUG] test episode 62: reward = 1.00, steps = 115
# 00:00:01 [DEBUG] test episode 63: reward = 1.00, steps = 101
# 00:00:01 [DEBUG] test episode 64: reward = 1.00, steps = 135
# 00:00:01 [DEBUG] test episode 65: reward = 1.00, steps = 115
# 00:00:01 [DEBUG] test episode 66: reward = 1.00, steps = 120
# 00:00:01 [DEBUG] test episode 67: reward = 1.00, steps = 112
# 00:00:01 [DEBUG] test episode 68: reward = 1.00, steps = 50
# 00:00:01 [DEBUG] test episode 69: reward = 1.00, steps = 81
# 00:00:01 [DEBUG] test episode 70: reward = 0.00, steps = 199
# 00:00:01 [DEBUG] test episode 71: reward = 1.00, steps = 122
# 00:00:01 [DEBUG] test episode 72: reward = 1.00, steps = 85
# 00:00:01 [DEBUG] test episode 73: reward = 1.00, steps = 136
# 00:00:01 [DEBUG] test episode 74: reward = 1.00, steps = 33
# 00:00:01 [DEBUG] test episode 75: reward = 1.00, steps = 134
# 00:00:01 [DEBUG] test episode 76: reward = 1.00, steps = 91
# 00:00:01 [DEBUG] test episode 77: reward = 1.00, steps = 98
# 00:00:01 [DEBUG] test episode 78: reward = 1.00, steps = 34
# 00:00:01 [DEBUG] test episode 79: reward = 1.00, steps = 83
# 00:00:01 [DEBUG] test episode 80: reward = 1.00, steps = 96
# 00:00:01 [DEBUG] test episode 81: reward = 1.00, steps = 103
# 00:00:01 [DEBUG] test episode 82: reward = 1.00, steps = 160
# 00:00:01 [DEBUG] test episode 83: reward = 1.00, steps = 73
# 00:00:01 [DEBUG] test episode 84: reward = 1.00, steps = 104
# 00:00:01 [DEBUG] test episode 85: reward = 1.00, steps = 67
# 00:00:01 [DEBUG] test episode 86: reward = 1.00, steps = 78
# 00:00:01 [DEBUG] test episode 87: reward = 1.00, steps = 82
# 00:00:01 [DEBUG] test episode 88: reward = 1.00, steps = 173
# 00:00:01 [DEBUG] test episode 89: reward = 1.00, steps = 79
# 00:00:01 [DEBUG] test episode 90: reward = 1.00, steps = 67
# 00:00:01 [DEBUG] test episode 91: reward = 1.00, steps = 176
# 00:00:01 [DEBUG] test episode 92: reward = 1.00, steps = 164
# 00:00:01 [DEBUG] test episode 93: reward = 1.00, steps = 200
# 00:00:01 [DEBUG] test episode 94: reward = 1.00, steps = 88
# 00:00:01 [DEBUG] test episode 95: reward = 1.00, steps = 129
# 00:00:01 [DEBUG] test episode 96: reward = 1.00, steps = 165
# 00:00:01 [DEBUG] test episode 97: reward = 1.00, steps = 144
# 00:00:01 [DEBUG] test episode 98: reward = 1.00, steps = 164
# 00:00:01 [DEBUG] test episode 99: reward = 1.00, steps = 135
# 00:00:01 [INFO] average episode reward = 0.91 ± 0.29

# %%
env.close()
