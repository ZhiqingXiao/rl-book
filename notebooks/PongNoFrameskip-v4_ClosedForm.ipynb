# %% [markdown]
# # Use Closed-Form Policy to Play PongNoFrameskip-v4

# %%
import sys
import logging
import itertools

import numpy as np
np.random.seed(0)
import gym

logging.basicConfig(level=logging.DEBUG,
        format='%(asctime)s [%(levelname)s] %(message)s',
        stream=sys.stdout, datefmt='%H:%M:%S')

# %%
env = gym.make('PongNoFrameskip-v4')
env.seed(0)
for key in vars(env):
    logging.info('%s: %s', key, vars(env)[key])
for key in vars(env.spec):
    logging.info('%s: %s', key, vars(env.spec)[key])
# Out:
# 00:00:00 [INFO] env: <AtariEnv<PongNoFrameskip-v4>>
# 00:00:00 [INFO] action_space: Discrete(6)
# 00:00:00 [INFO] observation_space: Box(0, 255, (210, 160, 3), uint8)
# 00:00:00 [INFO] reward_range: (-inf, inf)
# 00:00:00 [INFO] metadata: {'render.modes': ['human', 'rgb_array']}
# 00:00:00 [INFO] _max_episode_steps: 400000
# 00:00:00 [INFO] _elapsed_steps: None
# 00:00:00 [INFO] id: PongNoFrameskip-v4
# 00:00:00 [INFO] entry_point: gym.envs.atari:AtariEnv
# 00:00:00 [INFO] reward_threshold: None
# 00:00:00 [INFO] nondeterministic: False
# 00:00:00 [INFO] max_episode_steps: 400000
# 00:00:00 [INFO] _kwargs: {'game': 'pong', 'obs_type': 'image', 'frameskip': 1}
# 00:00:00 [INFO] _env_name: PongNoFrameskip

# %%
class ClosedFormAgent:
    def __init__(self, _):
        pass

    def reset(self, mode=None):
        pass

    def step(self, observation, _reward, _done):
        racket = np.where((observation[34:193, :, 0] == 92).any(axis=1))[0].mean()
        ball = np.where((observation[34:193, :, 0] == 236).any(axis=1))[0].mean()
        return 2 + int(racket < ball)

    def close(self):
        pass


agent = ClosedFormAgent(env)

# %%
def play_episode(env, agent, max_episode_steps=None, mode=None, render=False):
    observation, reward, done = env.reset(), 0., False
    agent.reset(mode=mode)
    episode_reward, elapsed_steps = 0., 0
    while True:
        action = agent.step(observation, reward, done)
        if render:
            env.render()
        if done:
            break
        observation, reward, done, _ = env.step(action)
        episode_reward += reward
        elapsed_steps += 1
        if max_episode_steps and elapsed_steps >= max_episode_steps:
            break
    agent.close()
    return episode_reward, elapsed_steps


logging.info('==== test ====')
episode_rewards = []
for episode in range(100):
    episode_reward, elapsed_steps = play_episode(env, agent)
    episode_rewards.append(episode_reward)
    logging.debug('test episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
logging.info('average episode reward = %.2f ± %.2f',
        np.mean(episode_rewards), np.std(episode_rewards))
# Out:
# 00:05:52 [INFO] ==== test ====
# 00:06:35 [DEBUG] test episode 0: reward = 21.00, steps = 29819
# 00:07:17 [DEBUG] test episode 1: reward = 21.00, steps = 29819
# 00:07:58 [DEBUG] test episode 2: reward = 21.00, steps = 29819
# 00:08:43 [DEBUG] test episode 3: reward = 21.00, steps = 29819
# 00:09:26 [DEBUG] test episode 4: reward = 21.00, steps = 29819
# 00:10:09 [DEBUG] test episode 5: reward = 21.00, steps = 29819
# 00:10:53 [DEBUG] test episode 6: reward = 21.00, steps = 29819
# 00:11:37 [DEBUG] test episode 7: reward = 21.00, steps = 29819
# 00:12:22 [DEBUG] test episode 8: reward = 21.00, steps = 29819
# 00:13:09 [DEBUG] test episode 9: reward = 21.00, steps = 29819
# 00:13:54 [DEBUG] test episode 10: reward = 21.00, steps = 29819
# 00:14:37 [DEBUG] test episode 11: reward = 21.00, steps = 29819
# 00:15:20 [DEBUG] test episode 12: reward = 21.00, steps = 29819
# 00:16:02 [DEBUG] test episode 13: reward = 21.00, steps = 29819
# 00:16:44 [DEBUG] test episode 14: reward = 21.00, steps = 29819
# 00:17:27 [DEBUG] test episode 15: reward = 21.00, steps = 29819
# 00:18:10 [DEBUG] test episode 16: reward = 21.00, steps = 29819
# 00:18:54 [DEBUG] test episode 17: reward = 21.00, steps = 29819
# 00:19:38 [DEBUG] test episode 18: reward = 21.00, steps = 29819
# 00:20:21 [DEBUG] test episode 19: reward = 21.00, steps = 29819
# 00:21:03 [DEBUG] test episode 20: reward = 21.00, steps = 29819
# 00:21:46 [DEBUG] test episode 21: reward = 21.00, steps = 29819
# 00:22:29 [DEBUG] test episode 22: reward = 21.00, steps = 29819
# 00:23:12 [DEBUG] test episode 23: reward = 21.00, steps = 29819
# 00:23:55 [DEBUG] test episode 24: reward = 21.00, steps = 29819
# 00:24:37 [DEBUG] test episode 25: reward = 21.00, steps = 29819
# 00:25:20 [DEBUG] test episode 26: reward = 21.00, steps = 29819
# 00:26:03 [DEBUG] test episode 27: reward = 21.00, steps = 29819
# 00:26:47 [DEBUG] test episode 28: reward = 21.00, steps = 29819
# 00:27:30 [DEBUG] test episode 29: reward = 21.00, steps = 29819
# 00:28:14 [DEBUG] test episode 30: reward = 21.00, steps = 29819
# 00:28:57 [DEBUG] test episode 31: reward = 21.00, steps = 29819
# 00:29:42 [DEBUG] test episode 32: reward = 21.00, steps = 29819
# 00:30:24 [DEBUG] test episode 33: reward = 21.00, steps = 29819
# 00:31:08 [DEBUG] test episode 34: reward = 21.00, steps = 29819
# 00:31:51 [DEBUG] test episode 35: reward = 21.00, steps = 29819
# 00:32:34 [DEBUG] test episode 36: reward = 21.00, steps = 29819
# 00:33:17 [DEBUG] test episode 37: reward = 21.00, steps = 29819
# 00:34:00 [DEBUG] test episode 38: reward = 21.00, steps = 29819
# 00:34:44 [DEBUG] test episode 39: reward = 21.00, steps = 29819
# 00:35:27 [DEBUG] test episode 40: reward = 21.00, steps = 29819
# 00:36:10 [DEBUG] test episode 41: reward = 21.00, steps = 29819
# 00:36:52 [DEBUG] test episode 42: reward = 21.00, steps = 29819
# 00:37:35 [DEBUG] test episode 43: reward = 21.00, steps = 29819
# 00:38:19 [DEBUG] test episode 44: reward = 21.00, steps = 29819
# 00:39:03 [DEBUG] test episode 45: reward = 21.00, steps = 29819
# 00:39:47 [DEBUG] test episode 46: reward = 21.00, steps = 29819
# 00:40:31 [DEBUG] test episode 47: reward = 21.00, steps = 29819
# 00:41:15 [DEBUG] test episode 48: reward = 21.00, steps = 29819
# 00:41:58 [DEBUG] test episode 49: reward = 21.00, steps = 29819
# 00:42:41 [DEBUG] test episode 50: reward = 21.00, steps = 29819
# 00:43:24 [DEBUG] test episode 51: reward = 21.00, steps = 29819
# 00:44:07 [DEBUG] test episode 52: reward = 21.00, steps = 29819
# 00:44:50 [DEBUG] test episode 53: reward = 21.00, steps = 29819
# 00:45:35 [DEBUG] test episode 54: reward = 21.00, steps = 29819
# 00:46:20 [DEBUG] test episode 55: reward = 21.00, steps = 29819
# 00:47:07 [DEBUG] test episode 56: reward = 21.00, steps = 29819
# 00:47:53 [DEBUG] test episode 57: reward = 21.00, steps = 29819
# 00:48:37 [DEBUG] test episode 58: reward = 21.00, steps = 29819
# 00:49:22 [DEBUG] test episode 59: reward = 21.00, steps = 29819
# 00:50:06 [DEBUG] test episode 60: reward = 21.00, steps = 29819
# 00:50:49 [DEBUG] test episode 61: reward = 21.00, steps = 29819
# 00:51:34 [DEBUG] test episode 62: reward = 21.00, steps = 29819
# 00:52:18 [DEBUG] test episode 63: reward = 21.00, steps = 29819
# 00:53:03 [DEBUG] test episode 64: reward = 21.00, steps = 29819
# 00:53:46 [DEBUG] test episode 65: reward = 21.00, steps = 29819
# 00:54:30 [DEBUG] test episode 66: reward = 21.00, steps = 29819
# 00:55:12 [DEBUG] test episode 67: reward = 21.00, steps = 29819
# 00:55:55 [DEBUG] test episode 68: reward = 21.00, steps = 29819
# 00:56:38 [DEBUG] test episode 69: reward = 21.00, steps = 29819
# 00:57:21 [DEBUG] test episode 70: reward = 21.00, steps = 29819
# 00:58:04 [DEBUG] test episode 71: reward = 21.00, steps = 29819
# 00:58:48 [DEBUG] test episode 72: reward = 21.00, steps = 29819
# 00:59:31 [DEBUG] test episode 73: reward = 21.00, steps = 29819
# 01:00:14 [DEBUG] test episode 74: reward = 21.00, steps = 29819
# 01:00:59 [DEBUG] test episode 75: reward = 21.00, steps = 29819
# 01:01:42 [DEBUG] test episode 76: reward = 21.00, steps = 29819
# 01:02:25 [DEBUG] test episode 77: reward = 21.00, steps = 29819
# 01:03:09 [DEBUG] test episode 78: reward = 21.00, steps = 29819
# 01:03:52 [DEBUG] test episode 79: reward = 21.00, steps = 29819
# 01:04:36 [DEBUG] test episode 80: reward = 21.00, steps = 29819
# 01:05:19 [DEBUG] test episode 81: reward = 21.00, steps = 29819
# 01:06:03 [DEBUG] test episode 82: reward = 21.00, steps = 29819
# 01:06:47 [DEBUG] test episode 83: reward = 21.00, steps = 29819
# 01:07:32 [DEBUG] test episode 84: reward = 21.00, steps = 29819
# 01:08:16 [DEBUG] test episode 85: reward = 21.00, steps = 29819
# 01:09:00 [DEBUG] test episode 86: reward = 21.00, steps = 29819
# 01:09:44 [DEBUG] test episode 87: reward = 21.00, steps = 29819
# 01:10:28 [DEBUG] test episode 88: reward = 21.00, steps = 29819
# 01:11:12 [DEBUG] test episode 89: reward = 21.00, steps = 29819
# 01:11:55 [DEBUG] test episode 90: reward = 21.00, steps = 29819
# 01:12:38 [DEBUG] test episode 91: reward = 21.00, steps = 29819
# 01:13:21 [DEBUG] test episode 92: reward = 21.00, steps = 29819
# 01:14:03 [DEBUG] test episode 93: reward = 21.00, steps = 29819
# 01:14:46 [DEBUG] test episode 94: reward = 21.00, steps = 29819
# 01:15:28 [DEBUG] test episode 95: reward = 21.00, steps = 29819
# 01:16:12 [DEBUG] test episode 96: reward = 21.00, steps = 29819
# 01:16:54 [DEBUG] test episode 97: reward = 21.00, steps = 29819
# 01:17:37 [DEBUG] test episode 98: reward = 21.00, steps = 29819
# 01:18:20 [DEBUG] test episode 99: reward = 21.00, steps = 29819
# 01:18:20 [INFO] average episode reward = 21.00 ± 0.00

# %%
env.close()
