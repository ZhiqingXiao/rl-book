# %% [markdown]
# # Use DDPG to Play Pendulum-v0
#
# TensorFlow version

# %%
# %matplotlib inline

import sys
import logging
import imp
import itertools

import numpy as np
np.random.seed(0)
import pandas as pd
import gym
import matplotlib.pyplot as plt
import tensorflow.compat.v2 as tf
tf.random.set_seed(0)
from tensorflow import keras
from tensorflow import nn
from tensorflow import optimizers
from tensorflow import losses
from tensorflow.keras import layers
from tensorflow.keras import models

imp.reload(logging)
logging.basicConfig(level=logging.DEBUG,
        format='%(asctime)s [%(levelname)s] %(message)s',
        stream=sys.stdout, datefmt='%H:%M:%S')

# %%
env = gym.make('Pendulum-v0')
env.seed(0)
for key in vars(env):
    logging.info('%s: %s', key, vars(env)[key])
# Out:
# 17:58:25 [INFO] env: <PendulumEnv<Pendulum-v0>>
# 17:58:25 [INFO] action_space: Box(-2.0, 2.0, (1,), float32)
# 17:58:25 [INFO] observation_space: Box(-8.0, 8.0, (3,), float32)
# 17:58:25 [INFO] reward_range: (-inf, inf)
# 17:58:25 [INFO] metadata: {'render.modes': ['human', 'rgb_array'], 'video.frames_per_second': 30}
# 17:58:25 [INFO] _max_episode_steps: 200
# 17:58:25 [INFO] _elapsed_steps: None

# %%
class DQNReplayer:
    def __init__(self, capacity):
        self.memory = pd.DataFrame(index=range(capacity),
                columns=['state', 'action', 'reward', 'next_state', 'done'])
        self.i = 0
        self.count = 0
        self.capacity = capacity
    
    def store(self, *args):
        self.memory.loc[self.i] = args
        self.i = (self.i + 1) % self.capacity
        self.count = min(self.count + 1, self.capacity)
        
    def sample(self, size):
        indices = np.random.choice(self.count, size=size)
        return (np.stack(self.memory.loc[indices, field]) for field in
                self.memory.columns)

# %%
class OrnsteinUhlenbeckProcess:
    def __init__(self, x0):
        self.x = x0

    def __call__(self, mu=0., sigma=1., theta=.15, dt=.01):
        n = np.random.normal(size=self.x.shape)
        self.x += (theta * (mu - self.x) * dt + sigma * np.sqrt(dt) * n)
        return self.x

# %%
class DDPGAgent:
    def __init__(self, env):
        state_dim = env.observation_space.shape[0]
        self.action_dim = env.action_space.shape[0]
        self.action_low = env.action_space.low
        self.action_high = env.action_space.high
        self.gamma = 0.99

        self.replayer = DQNReplayer(20000)

        self.actor_evaluate_net = self.build_net(
                input_size=state_dim, hidden_sizes=[32, 64],
                output_size=self.action_dim, output_activation=nn.tanh,
                learning_rate=0.0001)
        self.actor_target_net = models.clone_model(self.actor_evaluate_net)
        self.actor_target_net.set_weights(self.actor_evaluate_net.get_weights())

        self.critic_evaluate_net = self.build_net(
                input_size=state_dim+self.action_dim, hidden_sizes=[64, 128],
                learning_rate=0.001)
        self.critic_target_net = models.clone_model(self.critic_evaluate_net)
        self.critic_target_net.set_weights(self.critic_evaluate_net.get_weights())

    def build_net(self, input_size=None, hidden_sizes=None, output_size=1,
                activation=nn.relu, output_activation=None,
                loss=losses.mse, learning_rate=0.001):
        model = keras.Sequential()
        for layer, hidden_size in enumerate(hidden_sizes):
            kwargs = {'input_shape' : (input_size,)} if layer == 0 else {}
            model.add(layers.Dense(units=hidden_size,
                    activation=activation, **kwargs))
        model.add(layers.Dense(units=output_size,
                activation=output_activation))
        optimizer = optimizers.Adam(learning_rate)
        model.compile(optimizer=optimizer, loss=loss)
        return model

    def reset(self, mode=None):
        self.mode = mode
        if self.mode == 'train':
            self.trajectory = []
            self.noise = OrnsteinUhlenbeckProcess(np.zeros((self.action_dim,)))

    def step(self, observation, reward, done):
        if self.mode == 'train' and self.replayer.count < 3000:
            action = np.random.uniform(self.action_low, self.action_high)
        else:
            action = self.actor_evaluate_net.predict(observation[np.newaxis])[0]
        if self.mode == 'train':
            noise = self.noise(sigma=0.1)
            action = (action + noise).clip(self.action_low, self.action_high)

            self.trajectory += [observation, reward, done, action]
            if len(self.trajectory) >= 8:
                state, _, _, action, next_state, reward, done, _ = self.trajectory[-8:]
                self.replayer.store(state, action, reward, next_state, done)

            if self.replayer.count >= 3000:
                self.learn()
        return action

    def close(self):
        pass

    def update_net(self, target_net, evaluate_net, learning_rate=0.005):
        average_weights = [(1. - learning_rate) * t + learning_rate * e for t, e
                in zip(target_net.get_weights(), evaluate_net.get_weights())]
        target_net.set_weights(average_weights)

    def learn(self):
        # replay
        states, actions, rewards, next_states, dones = self.replayer.sample(64)
        state_tensor = tf.convert_to_tensor(states, dtype=tf.float32)
        
        # learn critic
        next_actions = self.actor_target_net.predict(next_states)
        next_noises = np.random.normal(0, 0.2, size=next_actions.shape)
        next_actions = (next_actions + next_noises).clip(self.action_low, self.action_high)
        state_actions = np.hstack([states, actions])
        next_state_actions = np.hstack([next_states, next_actions])
        next_qs = self.critic_target_net.predict(next_state_actions)[:, 0]
        targets = rewards + (1. - dones) * self.gamma * next_qs
        self.critic_evaluate_net.fit(state_actions, targets[:, np.newaxis], verbose=0)

        # learn actor
        with tf.GradientTape() as tape:
            action_tensor = self.actor_evaluate_net(state_tensor)
            state_action_tensor = tf.concat([state_tensor, action_tensor], axis=1)
            q_tensor = self.critic_evaluate_net(state_action_tensor)
            loss_tensor = -tf.reduce_mean(q_tensor)
        grad_tensors = tape.gradient(loss_tensor, self.actor_evaluate_net.variables)
        self.actor_evaluate_net.optimizer.apply_gradients(zip(
                grad_tensors, self.actor_evaluate_net.variables))

        self.update_net(self.critic_target_net, self.critic_evaluate_net)
        self.update_net(self.actor_target_net, self.actor_evaluate_net)


agent = DDPGAgent(env)

# %%
def play_episode(env, agent, max_episode_steps=None, mode=None, render=False):
    observation, reward, done = env.reset(), 0., False
    agent.reset(mode=mode)
    episode_reward, elapsed_steps = 0., 0
    while True:
        action = agent.step(observation, reward, done)
        if render:
            env.render()
        if done:
            break
        observation, reward, done, _ = env.step(action)
        episode_reward += reward
        elapsed_steps += 1
        if max_episode_steps and elapsed_steps >= max_episode_steps:
            break
    agent.close()
    return episode_reward, elapsed_steps


logging.info('==== train ====')
episode_rewards = []
for episode in itertools.count():
    episode_reward, elapsed_steps = play_episode(env.unwrapped, agent,
            max_episode_steps=env._max_episode_steps, mode='train')
    episode_rewards.append(episode_reward)
    logging.debug('train episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
    if np.mean(episode_rewards[-10:]) > -150:
        break
plt.plot(episode_rewards)


logging.info('==== test ====')
episode_rewards = []
for episode in range(100):
    episode_reward, elapsed_steps = play_episode(env, agent)
    episode_rewards.append(episode_reward)
    logging.debug('test episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
logging.info('average episode reward = %.2f ± %.2f',
        np.mean(episode_rewards), np.std(episode_rewards))
# Out:
# 17:58:27 [INFO] ==== train ====
# 17:58:27 [DEBUG] train episode 0: reward = -1779.61, steps = 200
# 17:58:27 [DEBUG] train episode 1: reward = -1026.05, steps = 200
# 17:58:27 [DEBUG] train episode 2: reward = -1556.83, steps = 200
# 17:58:28 [DEBUG] train episode 3: reward = -1127.41, steps = 200
# 17:58:28 [DEBUG] train episode 4: reward = -1675.42, steps = 200
# 17:58:28 [DEBUG] train episode 5: reward = -1632.59, steps = 200
# 17:58:28 [DEBUG] train episode 6: reward = -750.72, steps = 200
# 17:58:28 [DEBUG] train episode 7: reward = -1794.28, steps = 200
# 17:58:28 [DEBUG] train episode 8: reward = -928.49, steps = 200
# 17:58:28 [DEBUG] train episode 9: reward = -1680.41, steps = 200
# 17:58:29 [DEBUG] train episode 10: reward = -1312.04, steps = 200
# 17:58:29 [DEBUG] train episode 11: reward = -873.37, steps = 200
# 17:58:29 [DEBUG] train episode 12: reward = -1509.77, steps = 200
# 17:58:29 [DEBUG] train episode 13: reward = -994.03, steps = 200
# 17:58:29 [DEBUG] train episode 14: reward = -909.50, steps = 200
# 18:00:02 [DEBUG] train episode 15: reward = -1156.61, steps = 200
# 18:01:36 [DEBUG] train episode 16: reward = -1146.90, steps = 200
# 18:03:10 [DEBUG] train episode 17: reward = -1029.70, steps = 200
# 18:04:47 [DEBUG] train episode 18: reward = -1444.45, steps = 200
# 18:06:19 [DEBUG] train episode 19: reward = -1125.84, steps = 200
# 18:07:53 [DEBUG] train episode 20: reward = -1259.18, steps = 200
# 18:09:31 [DEBUG] train episode 21: reward = -1778.14, steps = 200
# 18:11:04 [DEBUG] train episode 22: reward = -1689.90, steps = 200
# 18:12:37 [DEBUG] train episode 23: reward = -1523.84, steps = 200
# 18:14:14 [DEBUG] train episode 24: reward = -1133.08, steps = 200
# 18:15:49 [DEBUG] train episode 25: reward = -1707.24, steps = 200
# 18:17:23 [DEBUG] train episode 26: reward = -1300.07, steps = 200
# 18:18:58 [DEBUG] train episode 27: reward = -953.63, steps = 200
# 18:20:32 [DEBUG] train episode 28: reward = -1250.99, steps = 200
# 18:22:05 [DEBUG] train episode 29: reward = -1367.90, steps = 200
# 18:23:40 [DEBUG] train episode 30: reward = -1200.18, steps = 200
# 18:25:13 [DEBUG] train episode 31: reward = -1202.38, steps = 200
# 18:26:47 [DEBUG] train episode 32: reward = -878.58, steps = 200
# 18:28:21 [DEBUG] train episode 33: reward = -1119.34, steps = 200
# 18:29:56 [DEBUG] train episode 34: reward = -1177.31, steps = 200
# 18:31:30 [DEBUG] train episode 35: reward = -1178.57, steps = 200
# 18:33:05 [DEBUG] train episode 36: reward = -1154.00, steps = 200
# 18:34:39 [DEBUG] train episode 37: reward = -939.50, steps = 200
# 18:36:13 [DEBUG] train episode 38: reward = -785.51, steps = 200
# 18:37:50 [DEBUG] train episode 39: reward = -955.81, steps = 200
# 18:39:14 [DEBUG] train episode 40: reward = -1196.98, steps = 200
# 18:40:35 [DEBUG] train episode 41: reward = -1199.39, steps = 200
# 18:41:57 [DEBUG] train episode 42: reward = -657.42, steps = 200
# 18:43:20 [DEBUG] train episode 43: reward = -747.51, steps = 200
# 18:44:43 [DEBUG] train episode 44: reward = -627.42, steps = 200
# 18:46:07 [DEBUG] train episode 45: reward = -880.26, steps = 200
# 18:47:30 [DEBUG] train episode 46: reward = -971.33, steps = 200
# 18:48:54 [DEBUG] train episode 47: reward = -857.25, steps = 200
# 18:50:17 [DEBUG] train episode 48: reward = -854.22, steps = 200
# 18:51:39 [DEBUG] train episode 49: reward = -858.49, steps = 200
# 18:53:03 [DEBUG] train episode 50: reward = -748.48, steps = 200
# 18:54:25 [DEBUG] train episode 51: reward = -748.22, steps = 200
# 18:55:49 [DEBUG] train episode 52: reward = -854.99, steps = 200
# 18:57:11 [DEBUG] train episode 53: reward = -748.65, steps = 200
# 18:58:34 [DEBUG] train episode 54: reward = -805.72, steps = 200
# 18:59:56 [DEBUG] train episode 55: reward = -879.13, steps = 200
# 19:01:18 [DEBUG] train episode 56: reward = -637.89, steps = 200
# 19:02:41 [DEBUG] train episode 57: reward = -752.31, steps = 200
# 19:04:04 [DEBUG] train episode 58: reward = -626.06, steps = 200
# 19:05:26 [DEBUG] train episode 59: reward = -843.18, steps = 200
# 19:06:49 [DEBUG] train episode 60: reward = -628.09, steps = 200
# 19:08:11 [DEBUG] train episode 61: reward = -374.01, steps = 200
# 19:09:34 [DEBUG] train episode 62: reward = -494.32, steps = 200
# 19:10:56 [DEBUG] train episode 63: reward = -499.64, steps = 200
# 19:12:18 [DEBUG] train episode 64: reward = -615.67, steps = 200
# 19:13:41 [DEBUG] train episode 65: reward = -123.15, steps = 200
# 19:15:05 [DEBUG] train episode 66: reward = -126.64, steps = 200
# 19:16:28 [DEBUG] train episode 67: reward = -504.88, steps = 200
# 19:17:50 [DEBUG] train episode 68: reward = -608.23, steps = 200
# 19:19:13 [DEBUG] train episode 69: reward = -367.41, steps = 200
# 19:20:35 [DEBUG] train episode 70: reward = -248.88, steps = 200
# 19:21:58 [DEBUG] train episode 71: reward = -126.51, steps = 200
# 19:23:22 [DEBUG] train episode 72: reward = -479.09, steps = 200
# 19:24:44 [DEBUG] train episode 73: reward = -127.64, steps = 200
# 19:26:07 [DEBUG] train episode 74: reward = -238.31, steps = 200
# 19:27:31 [DEBUG] train episode 75: reward = -127.64, steps = 200
# 19:28:54 [DEBUG] train episode 76: reward = -361.34, steps = 200
# 19:30:19 [DEBUG] train episode 77: reward = -124.97, steps = 200
# 19:31:43 [DEBUG] train episode 78: reward = -244.61, steps = 200
# 19:33:06 [DEBUG] train episode 79: reward = -250.14, steps = 200
# 19:34:29 [DEBUG] train episode 80: reward = -525.79, steps = 200
# 19:35:52 [DEBUG] train episode 81: reward = -126.88, steps = 200
# 19:37:16 [DEBUG] train episode 82: reward = -620.25, steps = 200
# 19:38:38 [DEBUG] train episode 83: reward = -126.81, steps = 200
# 19:40:00 [DEBUG] train episode 84: reward = -247.68, steps = 200
# 19:41:23 [DEBUG] train episode 85: reward = -123.71, steps = 200
# 19:42:45 [DEBUG] train episode 86: reward = -741.01, steps = 200
# 19:44:07 [DEBUG] train episode 87: reward = -243.79, steps = 200
# 19:45:31 [DEBUG] train episode 88: reward = -126.39, steps = 200
# 19:46:54 [DEBUG] train episode 89: reward = -122.38, steps = 200
# 19:48:18 [DEBUG] train episode 90: reward = -123.54, steps = 200
# 19:49:39 [DEBUG] train episode 91: reward = -122.39, steps = 200
# 19:51:03 [DEBUG] train episode 92: reward = -365.76, steps = 200
# 19:52:25 [DEBUG] train episode 93: reward = -125.66, steps = 200
# 19:53:47 [DEBUG] train episode 94: reward = -126.24, steps = 200
# 19:55:10 [DEBUG] train episode 95: reward = -516.20, steps = 200
# 19:56:38 [DEBUG] train episode 96: reward = -376.46, steps = 200
# 19:58:03 [DEBUG] train episode 97: reward = -362.74, steps = 200
# 19:59:30 [DEBUG] train episode 98: reward = -121.41, steps = 200
# 20:00:59 [DEBUG] train episode 99: reward = -480.92, steps = 200
# 20:02:28 [DEBUG] train episode 100: reward = -369.92, steps = 200
# 20:03:55 [DEBUG] train episode 101: reward = -238.28, steps = 200
# 20:05:25 [DEBUG] train episode 102: reward = -937.15, steps = 200
# 20:06:54 [DEBUG] train episode 103: reward = -626.77, steps = 200
# 20:08:24 [DEBUG] train episode 104: reward = -626.06, steps = 200
# 20:09:54 [DEBUG] train episode 105: reward = -124.81, steps = 200
# 20:11:20 [DEBUG] train episode 106: reward = -246.57, steps = 200
# 20:12:52 [DEBUG] train episode 107: reward = -483.03, steps = 200
# 20:14:29 [DEBUG] train episode 108: reward = -246.09, steps = 200
# 20:16:21 [DEBUG] train episode 109: reward = -496.32, steps = 200
# 20:18:23 [DEBUG] train episode 110: reward = -125.44, steps = 200
# 20:20:11 [DEBUG] train episode 111: reward = -126.04, steps = 200
# 20:22:00 [DEBUG] train episode 112: reward = -357.56, steps = 200
# 20:23:48 [DEBUG] train episode 113: reward = -122.39, steps = 200
# 20:25:42 [DEBUG] train episode 114: reward = -120.00, steps = 200
# 20:27:56 [DEBUG] train episode 115: reward = -867.42, steps = 200
# 20:30:10 [DEBUG] train episode 116: reward = -498.24, steps = 200
# 20:32:08 [DEBUG] train episode 117: reward = -125.27, steps = 200
# 20:34:06 [DEBUG] train episode 118: reward = -239.27, steps = 200
# 20:36:13 [DEBUG] train episode 119: reward = -124.69, steps = 200
# 20:38:15 [DEBUG] train episode 120: reward = -368.24, steps = 200
# 20:40:18 [DEBUG] train episode 121: reward = -121.69, steps = 200
# 20:42:17 [DEBUG] train episode 122: reward = -243.42, steps = 200
# 20:44:12 [DEBUG] train episode 123: reward = -505.89, steps = 200
# 20:46:10 [DEBUG] train episode 124: reward = -122.79, steps = 200
# 20:48:03 [DEBUG] train episode 125: reward = -363.37, steps = 200
# 20:49:59 [DEBUG] train episode 126: reward = -124.84, steps = 200
# 20:51:56 [DEBUG] train episode 127: reward = -124.83, steps = 200
# 20:53:47 [DEBUG] train episode 128: reward = -122.11, steps = 200
# 20:55:47 [DEBUG] train episode 129: reward = -353.26, steps = 200
# 20:57:45 [DEBUG] train episode 130: reward = -0.81, steps = 200
# 20:59:51 [DEBUG] train episode 131: reward = -362.03, steps = 200
# 21:01:47 [DEBUG] train episode 132: reward = -125.22, steps = 200
# 21:04:06 [DEBUG] train episode 133: reward = -118.26, steps = 200
# 21:06:21 [DEBUG] train episode 134: reward = -497.27, steps = 200
# 21:08:19 [DEBUG] train episode 135: reward = -523.56, steps = 200
# 21:10:17 [DEBUG] train episode 136: reward = -241.96, steps = 200
# 21:12:12 [DEBUG] train episode 137: reward = -481.87, steps = 200
# 21:14:11 [DEBUG] train episode 138: reward = -243.67, steps = 200
# 21:16:05 [DEBUG] train episode 139: reward = -360.16, steps = 200
# 21:18:05 [DEBUG] train episode 140: reward = -365.15, steps = 200
# 21:20:02 [DEBUG] train episode 141: reward = -357.22, steps = 200
# 21:22:06 [DEBUG] train episode 142: reward = -518.37, steps = 200
# 21:24:13 [DEBUG] train episode 143: reward = -120.88, steps = 200
# 21:26:22 [DEBUG] train episode 144: reward = -119.92, steps = 200
# 21:28:18 [DEBUG] train episode 145: reward = -121.72, steps = 200
# 21:30:35 [DEBUG] train episode 146: reward = -126.31, steps = 200
# 21:32:37 [DEBUG] train episode 147: reward = -246.20, steps = 200
# 21:34:44 [DEBUG] train episode 148: reward = -505.21, steps = 200
# 21:36:37 [DEBUG] train episode 149: reward = -478.51, steps = 200
# 21:38:32 [DEBUG] train episode 150: reward = -496.00, steps = 200
# 21:40:28 [DEBUG] train episode 151: reward = -362.56, steps = 200
# 21:42:24 [DEBUG] train episode 152: reward = -1.31, steps = 200
# 21:44:19 [DEBUG] train episode 153: reward = -238.62, steps = 200
# 21:46:16 [DEBUG] train episode 154: reward = -247.33, steps = 200
# 21:48:12 [DEBUG] train episode 155: reward = -371.37, steps = 200
# 21:50:13 [DEBUG] train episode 156: reward = -240.82, steps = 200
# 21:52:14 [DEBUG] train episode 157: reward = -124.75, steps = 200
# 21:54:15 [DEBUG] train episode 158: reward = -237.76, steps = 200
# 21:56:20 [DEBUG] train episode 159: reward = -123.52, steps = 200
# 21:58:20 [DEBUG] train episode 160: reward = -353.77, steps = 200
# 22:00:22 [DEBUG] train episode 161: reward = -245.07, steps = 200
# 22:02:15 [DEBUG] train episode 162: reward = -604.93, steps = 200
# 22:04:05 [DEBUG] train episode 163: reward = -121.70, steps = 200
# 22:05:51 [DEBUG] train episode 164: reward = -123.66, steps = 200
# 22:07:37 [DEBUG] train episode 165: reward = -124.44, steps = 200
# 22:09:29 [DEBUG] train episode 166: reward = -245.99, steps = 200
# 22:11:20 [DEBUG] train episode 167: reward = -603.65, steps = 200
# 22:13:13 [DEBUG] train episode 168: reward = -246.42, steps = 200
# 22:15:09 [DEBUG] train episode 169: reward = -781.35, steps = 200
# 22:17:09 [DEBUG] train episode 170: reward = -1071.34, steps = 200
# 22:19:12 [DEBUG] train episode 171: reward = -123.30, steps = 200
# 22:21:12 [DEBUG] train episode 172: reward = -124.45, steps = 200
# 22:23:17 [DEBUG] train episode 173: reward = -572.22, steps = 200
# 22:25:25 [DEBUG] train episode 174: reward = -239.52, steps = 200
# 22:27:33 [DEBUG] train episode 175: reward = -478.95, steps = 200
# 22:29:33 [DEBUG] train episode 176: reward = -125.50, steps = 200
# 22:31:55 [DEBUG] train episode 177: reward = -503.68, steps = 200
# 22:34:16 [DEBUG] train episode 178: reward = -123.60, steps = 200
# 22:36:06 [DEBUG] train episode 179: reward = -357.24, steps = 200
# 22:37:54 [DEBUG] train episode 180: reward = -617.51, steps = 200
# 22:39:48 [DEBUG] train episode 181: reward = -244.27, steps = 200
# 22:41:33 [DEBUG] train episode 182: reward = -237.88, steps = 200
# 22:43:10 [DEBUG] train episode 183: reward = -246.43, steps = 200
# 22:44:47 [DEBUG] train episode 184: reward = -361.51, steps = 200
# 22:46:27 [DEBUG] train episode 185: reward = -126.14, steps = 200
# 22:48:12 [DEBUG] train episode 186: reward = -122.72, steps = 200
# 22:49:58 [DEBUG] train episode 187: reward = -3.74, steps = 200
# 22:51:59 [DEBUG] train episode 188: reward = -358.94, steps = 200
# 22:53:45 [DEBUG] train episode 189: reward = -3.41, steps = 200
# 22:56:14 [DEBUG] train episode 190: reward = -239.94, steps = 200
# 22:58:48 [DEBUG] train episode 191: reward = -473.62, steps = 200
# 23:00:50 [DEBUG] train episode 192: reward = -117.82, steps = 200
# 23:02:33 [DEBUG] train episode 193: reward = -580.30, steps = 200
# 23:04:13 [DEBUG] train episode 194: reward = -126.05, steps = 200
# 23:05:47 [DEBUG] train episode 195: reward = -364.47, steps = 200
# 23:07:21 [DEBUG] train episode 196: reward = -241.57, steps = 200
# 23:08:54 [DEBUG] train episode 197: reward = -483.64, steps = 200
# 23:10:40 [DEBUG] train episode 198: reward = -365.76, steps = 200
# 23:12:27 [DEBUG] train episode 199: reward = -127.41, steps = 200
# 23:14:00 [DEBUG] train episode 200: reward = -494.31, steps = 200
# 23:15:35 [DEBUG] train episode 201: reward = -118.71, steps = 200
# 23:17:08 [DEBUG] train episode 202: reward = -126.01, steps = 200
# 23:18:42 [DEBUG] train episode 203: reward = -119.94, steps = 200
# 23:20:26 [DEBUG] train episode 204: reward = -246.74, steps = 200
# 23:22:02 [DEBUG] train episode 205: reward = -125.03, steps = 200
# 23:23:46 [DEBUG] train episode 206: reward = -125.28, steps = 200
# 23:25:27 [DEBUG] train episode 207: reward = -119.93, steps = 200
# 23:27:10 [DEBUG] train episode 208: reward = -118.87, steps = 200
# 23:28:57 [DEBUG] train episode 209: reward = -127.37, steps = 200
# 23:30:40 [DEBUG] train episode 210: reward = -249.90, steps = 200
# 23:30:40 [INFO] ==== test ====
# 23:31:54 [DEBUG] test episode 0: reward = -120.12, steps = 200
# 23:33:19 [DEBUG] test episode 1: reward = -123.10, steps = 200
# 23:34:41 [DEBUG] test episode 2: reward = -3.43, steps = 200
# 23:36:05 [DEBUG] test episode 3: reward = -610.69, steps = 200
# 23:37:29 [DEBUG] test episode 4: reward = -127.20, steps = 200
# 23:38:49 [DEBUG] test episode 5: reward = -128.00, steps = 200
# 23:40:13 [DEBUG] test episode 6: reward = -121.53, steps = 200
# 23:41:39 [DEBUG] test episode 7: reward = -489.15, steps = 200
# 23:43:01 [DEBUG] test episode 8: reward = -497.10, steps = 200
# 23:44:30 [DEBUG] test episode 9: reward = -121.74, steps = 200
# 23:46:01 [DEBUG] test episode 10: reward = -125.91, steps = 200
# 23:47:30 [DEBUG] test episode 11: reward = -3.22, steps = 200
# 23:48:58 [DEBUG] test episode 12: reward = -485.51, steps = 200
# 23:50:31 [DEBUG] test episode 13: reward = -359.20, steps = 200
# 23:52:02 [DEBUG] test episode 14: reward = -127.04, steps = 200
# 23:53:31 [DEBUG] test episode 15: reward = -637.05, steps = 200
# 23:54:56 [DEBUG] test episode 16: reward = -243.36, steps = 200
# 23:56:21 [DEBUG] test episode 17: reward = -496.93, steps = 200
# 23:57:45 [DEBUG] test episode 18: reward = -128.88, steps = 200
# 23:59:11 [DEBUG] test episode 19: reward = -235.42, steps = 200
# 00:00:37 [DEBUG] test episode 20: reward = -363.41, steps = 200
# 00:02:03 [DEBUG] test episode 21: reward = -125.40, steps = 200
# 00:03:29 [DEBUG] test episode 22: reward = -127.11, steps = 200
# 00:04:55 [DEBUG] test episode 23: reward = -366.44, steps = 200
# 00:06:21 [DEBUG] test episode 24: reward = -588.76, steps = 200
# 00:07:46 [DEBUG] test episode 25: reward = -122.61, steps = 200
# 00:09:11 [DEBUG] test episode 26: reward = -127.48, steps = 200
# 00:10:37 [DEBUG] test episode 27: reward = -240.30, steps = 200
# 00:12:02 [DEBUG] test episode 28: reward = -235.43, steps = 200
# 00:13:27 [DEBUG] test episode 29: reward = -125.91, steps = 200
# 00:14:52 [DEBUG] test episode 30: reward = -562.61, steps = 200
# 00:16:19 [DEBUG] test episode 31: reward = -127.76, steps = 200
# 00:17:43 [DEBUG] test episode 32: reward = -243.93, steps = 200
# 00:19:09 [DEBUG] test episode 33: reward = -636.31, steps = 200
# 00:20:34 [DEBUG] test episode 34: reward = -128.08, steps = 200
# 00:22:00 [DEBUG] test episode 35: reward = -495.43, steps = 200
# 00:23:23 [DEBUG] test episode 36: reward = -474.44, steps = 200
# 00:24:48 [DEBUG] test episode 37: reward = -553.01, steps = 200
# 00:26:12 [DEBUG] test episode 38: reward = -126.96, steps = 200
# 00:27:38 [DEBUG] test episode 39: reward = -123.49, steps = 200
# 00:29:02 [DEBUG] test episode 40: reward = -358.97, steps = 200
# 00:30:29 [DEBUG] test episode 41: reward = -126.16, steps = 200
# 00:31:54 [DEBUG] test episode 42: reward = -500.74, steps = 200
# 00:33:21 [DEBUG] test episode 43: reward = -126.08, steps = 200
# 00:34:47 [DEBUG] test episode 44: reward = -353.40, steps = 200
# 00:36:12 [DEBUG] test episode 45: reward = -238.25, steps = 200
# 00:37:38 [DEBUG] test episode 46: reward = -125.15, steps = 200
# 00:39:02 [DEBUG] test episode 47: reward = -123.95, steps = 200
# 00:40:28 [DEBUG] test episode 48: reward = -358.74, steps = 200
# 00:41:52 [DEBUG] test episode 49: reward = -123.49, steps = 200
# 00:43:18 [DEBUG] test episode 50: reward = -482.21, steps = 200
# 00:44:44 [DEBUG] test episode 51: reward = -126.86, steps = 200
# 00:46:09 [DEBUG] test episode 52: reward = -3.14, steps = 200
# 00:47:34 [DEBUG] test episode 53: reward = -243.44, steps = 200
# 00:48:57 [DEBUG] test episode 54: reward = -359.34, steps = 200
# 00:50:19 [DEBUG] test episode 55: reward = -358.29, steps = 200
# 00:51:40 [DEBUG] test episode 56: reward = -121.73, steps = 200
# 00:53:02 [DEBUG] test episode 57: reward = -125.23, steps = 200
# 00:54:23 [DEBUG] test episode 58: reward = -125.56, steps = 200
# 00:55:44 [DEBUG] test episode 59: reward = -586.70, steps = 200
# 00:57:04 [DEBUG] test episode 60: reward = -3.19, steps = 200
# 00:58:26 [DEBUG] test episode 61: reward = -125.08, steps = 200
# 00:59:48 [DEBUG] test episode 62: reward = -120.47, steps = 200
# 01:01:09 [DEBUG] test episode 63: reward = -363.31, steps = 200
# 01:02:30 [DEBUG] test episode 64: reward = -125.28, steps = 200
# 01:03:52 [DEBUG] test episode 65: reward = -238.42, steps = 200
# 01:05:13 [DEBUG] test episode 66: reward = -245.67, steps = 200
# 01:06:34 [DEBUG] test episode 67: reward = -621.88, steps = 200
# 01:07:55 [DEBUG] test episode 68: reward = -121.81, steps = 200
# 01:09:15 [DEBUG] test episode 69: reward = -124.82, steps = 200
# 01:10:36 [DEBUG] test episode 70: reward = -247.92, steps = 200
# 01:11:57 [DEBUG] test episode 71: reward = -125.42, steps = 200
# 01:13:19 [DEBUG] test episode 72: reward = -237.26, steps = 200
# 01:14:40 [DEBUG] test episode 73: reward = -246.07, steps = 200
# 01:16:01 [DEBUG] test episode 74: reward = -127.20, steps = 200
# 01:17:21 [DEBUG] test episode 75: reward = -120.82, steps = 200
# 01:18:40 [DEBUG] test episode 76: reward = -618.58, steps = 200
# 01:19:59 [DEBUG] test episode 77: reward = -125.99, steps = 200
# 01:21:20 [DEBUG] test episode 78: reward = -128.66, steps = 200
# 01:22:40 [DEBUG] test episode 79: reward = -121.94, steps = 200
# 01:24:00 [DEBUG] test episode 80: reward = -351.42, steps = 200
# 01:25:20 [DEBUG] test episode 81: reward = -234.77, steps = 200
# 01:26:40 [DEBUG] test episode 82: reward = -3.41, steps = 200
# 01:27:59 [DEBUG] test episode 83: reward = -127.57, steps = 200
# 01:29:07 [DEBUG] test episode 84: reward = -235.86, steps = 200
# 01:29:55 [DEBUG] test episode 85: reward = -3.08, steps = 200
# 01:30:46 [DEBUG] test episode 86: reward = -361.78, steps = 200
# 01:31:39 [DEBUG] test episode 87: reward = -363.21, steps = 200
# 01:32:30 [DEBUG] test episode 88: reward = -238.12, steps = 200
# 01:33:22 [DEBUG] test episode 89: reward = -125.21, steps = 200
# 01:34:15 [DEBUG] test episode 90: reward = -354.63, steps = 200
# 01:35:05 [DEBUG] test episode 91: reward = -237.61, steps = 200
# 01:36:03 [DEBUG] test episode 92: reward = -124.79, steps = 200
# 01:36:53 [DEBUG] test episode 93: reward = -495.56, steps = 200
# 01:37:44 [DEBUG] test episode 94: reward = -246.68, steps = 200
# 01:38:39 [DEBUG] test episode 95: reward = -125.05, steps = 200
# 01:39:32 [DEBUG] test episode 96: reward = -3.74, steps = 200
# 01:40:22 [DEBUG] test episode 97: reward = -245.34, steps = 200
# 01:41:07 [DEBUG] test episode 98: reward = -127.91, steps = 200
# 01:41:55 [DEBUG] test episode 99: reward = -126.39, steps = 200
# 01:41:55 [INFO] average episode reward = -243.69 ± 170.56

# %%
env.close()
