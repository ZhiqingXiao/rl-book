# %% [markdown]
# # Use Double DQN to Play MoutainCar-v0
#
# TensorFlow version

# %%
# %matplotlib inline

import sys
import logging
import imp
import itertools

import numpy as np
np.random.seed(0)
import pandas as pd
import gym
import matplotlib.pyplot as plt
import tensorflow.compat.v2 as tf
tf.random.set_seed(0)
from tensorflow import nn
from tensorflow import losses
from tensorflow import optimizers
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import models

imp.reload(logging)
logging.basicConfig(level=logging.DEBUG,
        format='%(asctime)s [%(levelname)s] %(message)s',
        stream=sys.stdout, datefmt='%H:%M:%S')

# %%
env = gym.make('MountainCar-v0')
env.seed(0)
for key in vars(env):
    logging.info('%s: %s', key, vars(env)[key])
# Out:
# 09:44:27 [INFO] env: <MountainCarEnv<MountainCar-v0>>
# 09:44:27 [INFO] action_space: Discrete(3)
# 09:44:27 [INFO] observation_space: Box(-1.2000000476837158, 0.6000000238418579, (2,), float32)
# 09:44:27 [INFO] reward_range: (-inf, inf)
# 09:44:27 [INFO] metadata: {'render.modes': ['human', 'rgb_array'], 'video.frames_per_second': 30}
# 09:44:27 [INFO] _max_episode_steps: 200
# 09:44:27 [INFO] _elapsed_steps: None

# %%
class DQNReplayer:
    def __init__(self, capacity):
        self.memory = pd.DataFrame(index=range(capacity),
                columns=['state', 'action', 'reward', 'next_state', 'done'])
        self.i = 0
        self.count = 0
        self.capacity = capacity

    def store(self, *args):
        self.memory.loc[self.i] = args
        self.i = (self.i + 1) % self.capacity
        self.count = min(self.count + 1, self.capacity)

    def sample(self, size):
        indices = np.random.choice(self.count, size=size)
        return (np.stack(self.memory.loc[indices, field]) for field in
                self.memory.columns)

# %%
class DoubleDQNAgent:
    def __init__(self, env):
        self.action_n = env.action_space.n
        self.gamma = 0.99

        self.replayer = DQNReplayer(10000)

        self.evaluate_net = self.build_net(
                input_size=env.observation_space.shape[0],
                hidden_sizes=[64, 64], output_size=self.action_n)
        self.target_net = models.clone_model(self.evaluate_net)

    def build_net(self, input_size, hidden_sizes, output_size):
        model = keras.Sequential()
        for layer, hidden_size in enumerate(hidden_sizes):
            kwargs = dict(input_shape=(input_size,)) if not layer else {}
            model.add(layers.Dense(units=hidden_size,
                    activation=nn.relu, **kwargs))
        model.add(layers.Dense(units=output_size))
        optimizer = optimizers.Adam(lr=0.001)
        model.compile(loss=losses.mse, optimizer=optimizer)
        return model

    def reset(self, mode=None):
        self.mode = mode
        if self.mode == 'train':
            self.trajectory = []
            self.target_net.set_weights(self.evaluate_net.get_weights())

    def step(self, observation, reward, done):
        if self.mode == 'train' and np.random.rand() < 0.001:
            # epsilon-greedy policy in train mode
            action = np.random.randint(self.action_n)
        else:
            qs = self.evaluate_net.predict(observation[np.newaxis])
            action = np.argmax(qs)
        if self.mode == 'train':
            self.trajectory += [observation, reward, done, action]
            if len(self.trajectory) >= 8:
                state, _, _, action, next_state, reward, done, _ = \
                        self.trajectory[-8:]
                self.replayer.store(state, action, reward, next_state, done)
            if self.replayer.count >= self.replayer.capacity * 0.95:
                    # skip first few episodes for speed
                self.learn()
        return action

    def close(self):
        pass

    def learn(self):
        # replay
        states, actions, rewards, next_states, dones = self.replayer.sample(1024)

        # train
        next_eval_qs = self.evaluate_net.predict(next_states)
        next_actions = next_eval_qs.argmax(axis=-1)
        next_qs = self.target_net.predict(next_states)
        next_max_qs = next_qs[np.arange(next_qs.shape[0]), next_actions] 
        us = rewards + self.gamma * next_max_qs * (1. - dones)
        targets = self.evaluate_net.predict(states)
        targets[np.arange(us.shape[0]), actions] = us
        self.evaluate_net.fit(states, targets, verbose=0)


agent = DoubleDQNAgent(env)

# %%
def play_episode(env, agent, max_episode_steps=None, mode=None, render=False):
    observation, reward, done = env.reset(), 0., False
    agent.reset(mode=mode)
    episode_reward, elapsed_steps = 0., 0
    while True:
        action = agent.step(observation, reward, done)
        if render:
            env.render()
        if done:
            break
        observation, reward, done, _ = env.step(action)
        episode_reward += reward
        elapsed_steps += 1
        if max_episode_steps and elapsed_steps >= max_episode_steps:
            break
    agent.close()
    return episode_reward, elapsed_steps


logging.info('==== train ====')
episode_rewards = []
for episode in itertools.count():
    episode_reward, elapsed_steps = play_episode(env.unwrapped, agent,
            max_episode_steps=env._max_episode_steps, mode='train')
    episode_rewards.append(episode_reward)
    logging.debug('train episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
    if np.mean(episode_rewards[-10:]) > -110:
        break
plt.plot(episode_rewards)


logging.info('==== test ====')
episode_rewards = []
for episode in range(100):
    episode_reward, elapsed_steps = play_episode(env, agent)
    episode_rewards.append(episode_reward)
    logging.debug('test episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
logging.info('average episode reward = %.2f ± %.2f',
        np.mean(episode_rewards), np.std(episode_rewards))
# Out:
# 09:44:28 [INFO] ==== train ====
# 09:44:47 [DEBUG] train episode 0: reward = -200.00, steps = 200
# 09:45:05 [DEBUG] train episode 1: reward = -200.00, steps = 200
# 09:45:23 [DEBUG] train episode 2: reward = -200.00, steps = 200
# 09:45:41 [DEBUG] train episode 3: reward = -200.00, steps = 200
# 09:45:58 [DEBUG] train episode 4: reward = -200.00, steps = 200
# 09:46:16 [DEBUG] train episode 5: reward = -200.00, steps = 200
# 09:46:33 [DEBUG] train episode 6: reward = -200.00, steps = 200
# 09:46:50 [DEBUG] train episode 7: reward = -200.00, steps = 200
# 09:47:07 [DEBUG] train episode 8: reward = -200.00, steps = 200
# 09:47:25 [DEBUG] train episode 9: reward = -200.00, steps = 200
# 09:47:44 [DEBUG] train episode 10: reward = -200.00, steps = 200
# 09:48:03 [DEBUG] train episode 11: reward = -200.00, steps = 200
# 09:48:21 [DEBUG] train episode 12: reward = -200.00, steps = 200
# 09:48:39 [DEBUG] train episode 13: reward = -200.00, steps = 200
# 09:48:57 [DEBUG] train episode 14: reward = -200.00, steps = 200
# 09:49:15 [DEBUG] train episode 15: reward = -200.00, steps = 200
# 09:49:33 [DEBUG] train episode 16: reward = -200.00, steps = 200
# 09:49:51 [DEBUG] train episode 17: reward = -200.00, steps = 200
# 09:50:09 [DEBUG] train episode 18: reward = -200.00, steps = 200
# 09:50:27 [DEBUG] train episode 19: reward = -200.00, steps = 200
# 09:50:45 [DEBUG] train episode 20: reward = -200.00, steps = 200
# 09:51:02 [DEBUG] train episode 21: reward = -200.00, steps = 200
# 09:51:20 [DEBUG] train episode 22: reward = -200.00, steps = 200
# 09:51:39 [DEBUG] train episode 23: reward = -200.00, steps = 200
# 09:51:56 [DEBUG] train episode 24: reward = -200.00, steps = 200
# 09:52:14 [DEBUG] train episode 25: reward = -200.00, steps = 200
# 09:52:32 [DEBUG] train episode 26: reward = -200.00, steps = 200
# 09:52:50 [DEBUG] train episode 27: reward = -200.00, steps = 200
# 09:53:08 [DEBUG] train episode 28: reward = -200.00, steps = 200
# 09:53:25 [DEBUG] train episode 29: reward = -200.00, steps = 200
# 09:53:42 [DEBUG] train episode 30: reward = -200.00, steps = 200
# 09:54:00 [DEBUG] train episode 31: reward = -200.00, steps = 200
# 09:54:18 [DEBUG] train episode 32: reward = -200.00, steps = 200
# 09:54:35 [DEBUG] train episode 33: reward = -200.00, steps = 200
# 09:54:53 [DEBUG] train episode 34: reward = -200.00, steps = 200
# 09:55:11 [DEBUG] train episode 35: reward = -200.00, steps = 200
# 09:55:30 [DEBUG] train episode 36: reward = -200.00, steps = 200
# 09:55:49 [DEBUG] train episode 37: reward = -200.00, steps = 200
# 09:56:07 [DEBUG] train episode 38: reward = -200.00, steps = 200
# 09:56:25 [DEBUG] train episode 39: reward = -200.00, steps = 200
# 09:56:44 [DEBUG] train episode 40: reward = -200.00, steps = 200
# 09:57:03 [DEBUG] train episode 41: reward = -200.00, steps = 200
# 09:57:21 [DEBUG] train episode 42: reward = -200.00, steps = 200
# 09:57:39 [DEBUG] train episode 43: reward = -200.00, steps = 200
# 09:57:57 [DEBUG] train episode 44: reward = -200.00, steps = 200
# 09:58:14 [DEBUG] train episode 45: reward = -200.00, steps = 200
# 09:58:32 [DEBUG] train episode 46: reward = -200.00, steps = 200
# 09:59:15 [DEBUG] train episode 47: reward = -200.00, steps = 200
# 10:01:02 [DEBUG] train episode 48: reward = -200.00, steps = 200
# 10:02:51 [DEBUG] train episode 49: reward = -200.00, steps = 200
# 10:04:41 [DEBUG] train episode 50: reward = -200.00, steps = 200
# 10:06:36 [DEBUG] train episode 51: reward = -200.00, steps = 200
# 10:08:28 [DEBUG] train episode 52: reward = -200.00, steps = 200
# 10:10:15 [DEBUG] train episode 53: reward = -197.00, steps = 197
# 10:12:03 [DEBUG] train episode 54: reward = -200.00, steps = 200
# 10:13:57 [DEBUG] train episode 55: reward = -200.00, steps = 200
# 10:15:46 [DEBUG] train episode 56: reward = -200.00, steps = 200
# 10:17:31 [DEBUG] train episode 57: reward = -200.00, steps = 200
# 10:19:10 [DEBUG] train episode 58: reward = -200.00, steps = 200
# 10:20:54 [DEBUG] train episode 59: reward = -200.00, steps = 200
# 10:22:40 [DEBUG] train episode 60: reward = -200.00, steps = 200
# 10:24:23 [DEBUG] train episode 61: reward = -200.00, steps = 200
# 10:26:06 [DEBUG] train episode 62: reward = -200.00, steps = 200
# 10:27:55 [DEBUG] train episode 63: reward = -200.00, steps = 200
# 10:29:47 [DEBUG] train episode 64: reward = -200.00, steps = 200
# 10:31:34 [DEBUG] train episode 65: reward = -200.00, steps = 200
# 10:33:21 [DEBUG] train episode 66: reward = -200.00, steps = 200
# 10:35:06 [DEBUG] train episode 67: reward = -200.00, steps = 200
# 10:36:50 [DEBUG] train episode 68: reward = -200.00, steps = 200
# 10:38:37 [DEBUG] train episode 69: reward = -200.00, steps = 200
# 10:40:38 [DEBUG] train episode 70: reward = -200.00, steps = 200
# 10:42:41 [DEBUG] train episode 71: reward = -200.00, steps = 200
# 10:44:32 [DEBUG] train episode 72: reward = -200.00, steps = 200
# 10:46:24 [DEBUG] train episode 73: reward = -200.00, steps = 200
# 10:48:16 [DEBUG] train episode 74: reward = -200.00, steps = 200
# 10:50:04 [DEBUG] train episode 75: reward = -200.00, steps = 200
# 10:51:55 [DEBUG] train episode 76: reward = -200.00, steps = 200
# 10:53:48 [DEBUG] train episode 77: reward = -200.00, steps = 200
# 10:55:42 [DEBUG] train episode 78: reward = -200.00, steps = 200
# 10:57:31 [DEBUG] train episode 79: reward = -200.00, steps = 200
# 10:59:20 [DEBUG] train episode 80: reward = -200.00, steps = 200
# 11:01:09 [DEBUG] train episode 81: reward = -200.00, steps = 200
# 11:02:59 [DEBUG] train episode 82: reward = -200.00, steps = 200
# 11:04:51 [DEBUG] train episode 83: reward = -200.00, steps = 200
# 11:06:43 [DEBUG] train episode 84: reward = -200.00, steps = 200
# 11:08:34 [DEBUG] train episode 85: reward = -200.00, steps = 200
# 11:10:30 [DEBUG] train episode 86: reward = -200.00, steps = 200
# 11:12:28 [DEBUG] train episode 87: reward = -200.00, steps = 200
# 11:14:23 [DEBUG] train episode 88: reward = -200.00, steps = 200
# 11:16:11 [DEBUG] train episode 89: reward = -200.00, steps = 200
# 11:18:03 [DEBUG] train episode 90: reward = -200.00, steps = 200
# 11:19:51 [DEBUG] train episode 91: reward = -200.00, steps = 200
# 11:21:46 [DEBUG] train episode 92: reward = -200.00, steps = 200
# 11:23:35 [DEBUG] train episode 93: reward = -200.00, steps = 200
# 11:25:23 [DEBUG] train episode 94: reward = -200.00, steps = 200
# 11:27:11 [DEBUG] train episode 95: reward = -200.00, steps = 200
# 11:28:59 [DEBUG] train episode 96: reward = -200.00, steps = 200
# 11:30:47 [DEBUG] train episode 97: reward = -200.00, steps = 200
# 11:32:35 [DEBUG] train episode 98: reward = -200.00, steps = 200
# 11:34:27 [DEBUG] train episode 99: reward = -200.00, steps = 200
# 11:35:40 [DEBUG] train episode 100: reward = -133.00, steps = 133
# 11:37:28 [DEBUG] train episode 101: reward = -200.00, steps = 200
# 11:39:16 [DEBUG] train episode 102: reward = -200.00, steps = 200
# 11:41:04 [DEBUG] train episode 103: reward = -200.00, steps = 200
# 11:42:52 [DEBUG] train episode 104: reward = -200.00, steps = 200
# 11:44:40 [DEBUG] train episode 105: reward = -200.00, steps = 200
# 11:46:28 [DEBUG] train episode 106: reward = -200.00, steps = 200
# 11:48:16 [DEBUG] train episode 107: reward = -200.00, steps = 200
# 11:50:04 [DEBUG] train episode 108: reward = -200.00, steps = 200
# 11:51:52 [DEBUG] train episode 109: reward = -200.00, steps = 200
# 11:53:40 [DEBUG] train episode 110: reward = -200.00, steps = 200
# 11:55:28 [DEBUG] train episode 111: reward = -200.00, steps = 200
# 11:57:16 [DEBUG] train episode 112: reward = -200.00, steps = 200
# 11:59:04 [DEBUG] train episode 113: reward = -200.00, steps = 200
# 12:00:52 [DEBUG] train episode 114: reward = -200.00, steps = 200
# 12:02:40 [DEBUG] train episode 115: reward = -200.00, steps = 200
# 12:04:29 [DEBUG] train episode 116: reward = -200.00, steps = 200
# 12:06:17 [DEBUG] train episode 117: reward = -200.00, steps = 200
# 12:08:05 [DEBUG] train episode 118: reward = -200.00, steps = 200
# 12:09:53 [DEBUG] train episode 119: reward = -200.00, steps = 200
# 12:11:41 [DEBUG] train episode 120: reward = -200.00, steps = 200
# 12:13:28 [DEBUG] train episode 121: reward = -200.00, steps = 200
# 12:15:17 [DEBUG] train episode 122: reward = -200.00, steps = 200
# 12:17:04 [DEBUG] train episode 123: reward = -200.00, steps = 200
# 12:18:52 [DEBUG] train episode 124: reward = -200.00, steps = 200
# 12:20:40 [DEBUG] train episode 125: reward = -200.00, steps = 200
# 12:22:28 [DEBUG] train episode 126: reward = -200.00, steps = 200
# 12:24:15 [DEBUG] train episode 127: reward = -200.00, steps = 200
# 12:26:03 [DEBUG] train episode 128: reward = -200.00, steps = 200
# 12:27:50 [DEBUG] train episode 129: reward = -200.00, steps = 200
# 12:29:38 [DEBUG] train episode 130: reward = -200.00, steps = 200
# 12:31:25 [DEBUG] train episode 131: reward = -200.00, steps = 200
# 12:32:47 [DEBUG] train episode 132: reward = -151.00, steps = 151
# 12:34:35 [DEBUG] train episode 133: reward = -200.00, steps = 200
# 12:35:53 [DEBUG] train episode 134: reward = -144.00, steps = 144
# 12:37:18 [DEBUG] train episode 135: reward = -153.00, steps = 153
# 12:39:07 [DEBUG] train episode 136: reward = -200.00, steps = 200
# 12:40:54 [DEBUG] train episode 137: reward = -200.00, steps = 200
# 12:42:38 [DEBUG] train episode 138: reward = -185.00, steps = 185
# 12:44:23 [DEBUG] train episode 139: reward = -191.00, steps = 191
# 12:45:18 [DEBUG] train episode 140: reward = -100.00, steps = 100
# 12:46:13 [DEBUG] train episode 141: reward = -103.00, steps = 103
# 12:47:18 [DEBUG] train episode 142: reward = -120.00, steps = 120
# 12:48:39 [DEBUG] train episode 143: reward = -151.00, steps = 151
# 12:50:27 [DEBUG] train episode 144: reward = -200.00, steps = 200
# 12:52:13 [DEBUG] train episode 145: reward = -200.00, steps = 200
# 12:53:59 [DEBUG] train episode 146: reward = -200.00, steps = 200
# 12:55:32 [DEBUG] train episode 147: reward = -176.00, steps = 176
# 12:57:18 [DEBUG] train episode 148: reward = -200.00, steps = 200
# 12:58:18 [DEBUG] train episode 149: reward = -112.00, steps = 112
# 13:00:05 [DEBUG] train episode 150: reward = -200.00, steps = 200
# 13:01:39 [DEBUG] train episode 151: reward = -170.00, steps = 170
# 13:03:29 [DEBUG] train episode 152: reward = -200.00, steps = 200
# 13:05:18 [DEBUG] train episode 153: reward = -200.00, steps = 200
# 13:06:45 [DEBUG] train episode 154: reward = -158.00, steps = 158
# 13:08:14 [DEBUG] train episode 155: reward = -159.00, steps = 159
# 13:09:12 [DEBUG] train episode 156: reward = -107.00, steps = 107
# 13:11:01 [DEBUG] train episode 157: reward = -200.00, steps = 200
# 13:11:56 [DEBUG] train episode 158: reward = -103.00, steps = 103
# 13:13:18 [DEBUG] train episode 159: reward = -155.00, steps = 155
# 13:14:41 [DEBUG] train episode 160: reward = -153.00, steps = 153
# 13:15:27 [DEBUG] train episode 161: reward = -86.00, steps = 86
# 13:16:53 [DEBUG] train episode 162: reward = -159.00, steps = 159
# 13:17:40 [DEBUG] train episode 163: reward = -87.00, steps = 87
# 13:19:08 [DEBUG] train episode 164: reward = -160.00, steps = 160
# 13:20:06 [DEBUG] train episode 165: reward = -99.00, steps = 99
# 13:21:38 [DEBUG] train episode 166: reward = -158.00, steps = 158
# 13:22:28 [DEBUG] train episode 167: reward = -88.00, steps = 88
# 13:23:23 [DEBUG] train episode 168: reward = -97.00, steps = 97
# 13:24:53 [DEBUG] train episode 169: reward = -161.00, steps = 161
# 13:26:21 [DEBUG] train episode 170: reward = -158.00, steps = 158
# 13:27:50 [DEBUG] train episode 171: reward = -161.00, steps = 161
# 13:28:39 [DEBUG] train episode 172: reward = -88.00, steps = 88
# 13:29:32 [DEBUG] train episode 173: reward = -95.00, steps = 95
# 13:30:24 [DEBUG] train episode 174: reward = -93.00, steps = 93
# 13:31:51 [DEBUG] train episode 175: reward = -157.00, steps = 157
# 13:33:19 [DEBUG] train episode 176: reward = -155.00, steps = 155
# 13:34:09 [DEBUG] train episode 177: reward = -87.00, steps = 87
# 13:35:28 [DEBUG] train episode 178: reward = -136.00, steps = 136
# 13:36:58 [DEBUG] train episode 179: reward = -158.00, steps = 158
# 13:38:26 [DEBUG] train episode 180: reward = -157.00, steps = 157
# 13:39:58 [DEBUG] train episode 181: reward = -167.00, steps = 167
# 13:41:00 [DEBUG] train episode 182: reward = -112.00, steps = 112
# 13:42:10 [DEBUG] train episode 183: reward = -121.00, steps = 121
# 13:43:18 [DEBUG] train episode 184: reward = -124.00, steps = 124
# 13:44:24 [DEBUG] train episode 185: reward = -118.00, steps = 118
# 13:46:16 [DEBUG] train episode 186: reward = -200.00, steps = 200
# 13:47:33 [DEBUG] train episode 187: reward = -123.00, steps = 123
# 13:48:31 [DEBUG] train episode 188: reward = -114.00, steps = 114
# 13:49:50 [DEBUG] train episode 189: reward = -157.00, steps = 157
# 13:50:34 [DEBUG] train episode 190: reward = -87.00, steps = 87
# 13:51:30 [DEBUG] train episode 191: reward = -113.00, steps = 113
# 13:52:27 [DEBUG] train episode 192: reward = -111.00, steps = 111
# 13:53:22 [DEBUG] train episode 193: reward = -111.00, steps = 111
# 13:54:18 [DEBUG] train episode 194: reward = -111.00, steps = 111
# 13:55:11 [DEBUG] train episode 195: reward = -105.00, steps = 105
# 13:56:05 [DEBUG] train episode 196: reward = -109.00, steps = 109
# 13:57:02 [DEBUG] train episode 197: reward = -112.00, steps = 112
# 13:57:47 [DEBUG] train episode 198: reward = -90.00, steps = 90
# 13:58:35 [DEBUG] train episode 199: reward = -94.00, steps = 94
# 13:58:35 [INFO] ==== test ====
# 13:58:46 [DEBUG] test episode 0: reward = -117.00, steps = 117
# 13:58:54 [DEBUG] test episode 1: reward = -91.00, steps = 91
# 13:59:03 [DEBUG] test episode 2: reward = -91.00, steps = 91
# 13:59:21 [DEBUG] test episode 3: reward = -200.00, steps = 200
# 13:59:32 [DEBUG] test episode 4: reward = -119.00, steps = 119
# 13:59:43 [DEBUG] test episode 5: reward = -115.00, steps = 115
# 13:59:51 [DEBUG] test episode 6: reward = -87.00, steps = 87
# 14:00:05 [DEBUG] test episode 7: reward = -146.00, steps = 146
# 14:00:16 [DEBUG] test episode 8: reward = -117.00, steps = 117
# 14:00:30 [DEBUG] test episode 9: reward = -146.00, steps = 146
# 14:00:40 [DEBUG] test episode 10: reward = -113.00, steps = 113
# 14:00:49 [DEBUG] test episode 11: reward = -87.00, steps = 87
# 14:01:00 [DEBUG] test episode 12: reward = -119.00, steps = 119
# 14:01:08 [DEBUG] test episode 13: reward = -89.00, steps = 89
# 14:01:16 [DEBUG] test episode 14: reward = -87.00, steps = 87
# 14:01:35 [DEBUG] test episode 15: reward = -200.00, steps = 200
# 14:01:45 [DEBUG] test episode 16: reward = -109.00, steps = 109
# 14:01:54 [DEBUG] test episode 17: reward = -92.00, steps = 92
# 14:02:02 [DEBUG] test episode 18: reward = -85.00, steps = 85
# 14:02:16 [DEBUG] test episode 19: reward = -148.00, steps = 148
# 14:02:26 [DEBUG] test episode 20: reward = -112.00, steps = 112
# 14:02:37 [DEBUG] test episode 21: reward = -112.00, steps = 112
# 14:02:51 [DEBUG] test episode 22: reward = -148.00, steps = 148
# 14:02:59 [DEBUG] test episode 23: reward = -95.00, steps = 95
# 14:03:08 [DEBUG] test episode 24: reward = -88.00, steps = 88
# 14:03:18 [DEBUG] test episode 25: reward = -109.00, steps = 109
# 14:03:29 [DEBUG] test episode 26: reward = -117.00, steps = 117
# 14:03:43 [DEBUG] test episode 27: reward = -146.00, steps = 146
# 14:03:53 [DEBUG] test episode 28: reward = -113.00, steps = 113
# 14:04:04 [DEBUG] test episode 29: reward = -118.00, steps = 118
# 14:04:15 [DEBUG] test episode 30: reward = -117.00, steps = 117
# 14:04:26 [DEBUG] test episode 31: reward = -117.00, steps = 117
# 14:04:34 [DEBUG] test episode 32: reward = -88.00, steps = 88
# 14:04:46 [DEBUG] test episode 33: reward = -119.00, steps = 119
# 14:05:04 [DEBUG] test episode 34: reward = -200.00, steps = 200
# 14:05:18 [DEBUG] test episode 35: reward = -148.00, steps = 148
# 14:05:26 [DEBUG] test episode 36: reward = -92.00, steps = 92
# 14:05:40 [DEBUG] test episode 37: reward = -146.00, steps = 146
# 14:05:51 [DEBUG] test episode 38: reward = -112.00, steps = 112
# 14:06:09 [DEBUG] test episode 39: reward = -200.00, steps = 200
# 14:06:18 [DEBUG] test episode 40: reward = -89.00, steps = 89
# 14:06:29 [DEBUG] test episode 41: reward = -118.00, steps = 118
# 14:06:40 [DEBUG] test episode 42: reward = -117.00, steps = 117
# 14:06:54 [DEBUG] test episode 43: reward = -146.00, steps = 146
# 14:07:05 [DEBUG] test episode 44: reward = -119.00, steps = 119
# 14:07:15 [DEBUG] test episode 45: reward = -113.00, steps = 113
# 14:07:23 [DEBUG] test episode 46: reward = -87.00, steps = 87
# 14:07:35 [DEBUG] test episode 47: reward = -118.00, steps = 118
# 14:07:46 [DEBUG] test episode 48: reward = -114.00, steps = 114
# 14:07:59 [DEBUG] test episode 49: reward = -146.00, steps = 146
# 14:08:10 [DEBUG] test episode 50: reward = -118.00, steps = 118
# 14:08:24 [DEBUG] test episode 51: reward = -153.00, steps = 153
# 14:08:35 [DEBUG] test episode 52: reward = -113.00, steps = 113
# 14:08:44 [DEBUG] test episode 53: reward = -95.00, steps = 95
# 14:08:54 [DEBUG] test episode 54: reward = -112.00, steps = 112
# 14:09:09 [DEBUG] test episode 55: reward = -157.00, steps = 157
# 14:09:19 [DEBUG] test episode 56: reward = -113.00, steps = 113
# 14:09:30 [DEBUG] test episode 57: reward = -115.00, steps = 115
# 14:09:41 [DEBUG] test episode 58: reward = -118.00, steps = 118
# 14:09:52 [DEBUG] test episode 59: reward = -117.00, steps = 117
# 14:10:06 [DEBUG] test episode 60: reward = -148.00, steps = 148
# 14:10:17 [DEBUG] test episode 61: reward = -120.00, steps = 120
# 14:10:26 [DEBUG] test episode 62: reward = -89.00, steps = 89
# 14:10:36 [DEBUG] test episode 63: reward = -113.00, steps = 113
# 14:10:55 [DEBUG] test episode 64: reward = -200.00, steps = 200
# 14:11:04 [DEBUG] test episode 65: reward = -94.00, steps = 94
# 14:11:13 [DEBUG] test episode 66: reward = -95.00, steps = 95
# 14:11:22 [DEBUG] test episode 67: reward = -89.00, steps = 89
# 14:11:30 [DEBUG] test episode 68: reward = -86.00, steps = 86
# 14:11:42 [DEBUG] test episode 69: reward = -112.00, steps = 112
# 14:11:50 [DEBUG] test episode 70: reward = -85.00, steps = 85
# 14:12:02 [DEBUG] test episode 71: reward = -117.00, steps = 117
# 14:12:14 [DEBUG] test episode 72: reward = -118.00, steps = 118
# 14:12:26 [DEBUG] test episode 73: reward = -118.00, steps = 118
# 14:12:34 [DEBUG] test episode 74: reward = -86.00, steps = 86
# 14:12:43 [DEBUG] test episode 75: reward = -95.00, steps = 95
# 14:12:55 [DEBUG] test episode 76: reward = -118.00, steps = 118
# 14:13:04 [DEBUG] test episode 77: reward = -92.00, steps = 92
# 14:13:13 [DEBUG] test episode 78: reward = -88.00, steps = 88
# 14:13:27 [DEBUG] test episode 79: reward = -146.00, steps = 146
# 14:13:38 [DEBUG] test episode 80: reward = -117.00, steps = 117
# 14:13:52 [DEBUG] test episode 81: reward = -148.00, steps = 148
# 14:14:04 [DEBUG] test episode 82: reward = -119.00, steps = 119
# 14:14:15 [DEBUG] test episode 83: reward = -117.00, steps = 117
# 14:14:23 [DEBUG] test episode 84: reward = -85.00, steps = 85
# 14:14:36 [DEBUG] test episode 85: reward = -119.00, steps = 119
# 14:14:47 [DEBUG] test episode 86: reward = -115.00, steps = 115
# 14:14:57 [DEBUG] test episode 87: reward = -112.00, steps = 112
# 14:15:07 [DEBUG] test episode 88: reward = -115.00, steps = 115
# 14:15:19 [DEBUG] test episode 89: reward = -120.00, steps = 120
# 14:15:30 [DEBUG] test episode 90: reward = -112.00, steps = 112
# 14:15:39 [DEBUG] test episode 91: reward = -87.00, steps = 87
# 14:15:53 [DEBUG] test episode 92: reward = -146.00, steps = 146
# 14:16:04 [DEBUG] test episode 93: reward = -117.00, steps = 117
# 14:16:13 [DEBUG] test episode 94: reward = -92.00, steps = 92
# 14:16:24 [DEBUG] test episode 95: reward = -119.00, steps = 119
# 14:16:35 [DEBUG] test episode 96: reward = -112.00, steps = 112
# 14:16:43 [DEBUG] test episode 97: reward = -89.00, steps = 89
# 14:16:52 [DEBUG] test episode 98: reward = -85.00, steps = 85
# 14:17:00 [DEBUG] test episode 99: reward = -89.00, steps = 89
# 14:17:00 [INFO] average episode reward = -116.57 ± 27.10

# %%
env.close()
