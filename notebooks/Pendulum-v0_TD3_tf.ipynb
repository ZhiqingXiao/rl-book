# %% [markdown]
# # Use TD3 to Play Pendulum-v0
#
# TensorFlow version

# %%
# %matplotlib inline

import sys
import logging
import imp
import itertools

import numpy as np
np.random.seed(0)
import pandas as pd
import gym
import matplotlib.pyplot as plt
import tensorflow.compat.v2 as tf
tf.random.set_seed(0)
from tensorflow import keras
from tensorflow import nn
from tensorflow import optimizers
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import models

imp.reload(logging)
logging.basicConfig(level=logging.DEBUG,
        format='%(asctime)s [%(levelname)s] %(message)s',
        stream=sys.stdout, datefmt='%H:%M:%S')

# %%
env = gym.make('Pendulum-v0')
env.seed(0)
for key in vars(env):
    logging.info('%s: %s', key, vars(env)[key])
# Out:
# 17:58:31 [INFO] env: <PendulumEnv<Pendulum-v0>>
# 17:58:31 [INFO] action_space: Box(-2.0, 2.0, (1,), float32)
# 17:58:31 [INFO] observation_space: Box(-8.0, 8.0, (3,), float32)
# 17:58:31 [INFO] reward_range: (-inf, inf)
# 17:58:31 [INFO] metadata: {'render.modes': ['human', 'rgb_array'], 'video.frames_per_second': 30}
# 17:58:31 [INFO] _max_episode_steps: 200
# 17:58:31 [INFO] _elapsed_steps: None

# %%
class DQNReplayer:
    def __init__(self, capacity):
        self.memory = pd.DataFrame(index=range(capacity),
                columns=['state', 'action', 'reward', 'next_state', 'done'])
        self.i = 0
        self.count = 0
        self.capacity = capacity
    
    def store(self, *args):
        self.memory.loc[self.i] = args
        self.i = (self.i + 1) % self.capacity
        self.count = min(self.count + 1, self.capacity)
        
    def sample(self, size):
        indices = np.random.choice(self.count, size=size)
        return (np.stack(self.memory.loc[indices, field]) for field in
                self.memory.columns)

# %%
class OrnsteinUhlenbeckProcess:
    def __init__(self, x0):
        self.x = x0

    def __call__(self, mu=0., sigma=1., theta=.15, dt=.01):
        n = np.random.normal(size=self.x.shape)
        self.x += (theta * (mu - self.x) * dt + sigma * np.sqrt(dt) * n)
        return self.x

# %%
class TD3Agent:
    def __init__(self, env):
        state_dim = env.observation_space.shape[0]
        self.action_dim = env.action_space.shape[0]
        self.action_low = env.action_space.low
        self.action_high = env.action_space.high
        self.gamma = 0.99

        self.replayer = DQNReplayer(20000)

        self.actor_evaluate_net = self.build_net(
                input_size=state_dim, hidden_sizes=[32, 64],
                output_size=self.action_dim, output_activation=nn.tanh)
        self.actor_target_net = models.clone_model(self.actor_evaluate_net)
        self.actor_target_net.set_weights(self.actor_evaluate_net.get_weights())

        self.critic0_evaluate_net = self.build_net(
                input_size=state_dim+self.action_dim, hidden_sizes=[64, 128])
        self.critic0_target_net = models.clone_model(self.critic0_evaluate_net)
        self.critic0_target_net.set_weights(self.critic0_evaluate_net.get_weights())

        self.critic1_evaluate_net = self.build_net(
                input_size=state_dim+self.action_dim, hidden_sizes=[64, 128])
        self.critic1_target_net = models.clone_model(self.critic1_evaluate_net)
        self.critic1_target_net.set_weights(self.critic1_evaluate_net.get_weights())

    def build_net(self, input_size=None, hidden_sizes=None, output_size=1, 
                activation=nn.relu, output_activation=None,
                loss=losses.mse, learning_rate=0.001):
        model = keras.Sequential()
        for layer, hidden_size in enumerate(hidden_sizes):
            kwargs = {'input_shape' : (input_size,)} if layer == 0 else {}
            model.add(layers.Dense(units=hidden_size,
                    activation=activation, **kwargs))
        model.add(layers.Dense(units=output_size,
                activation=output_activation))
        optimizer = optimizers.Adam(learning_rate)
        model.compile(optimizer=optimizer, loss=loss)
        return model

    def reset(self, mode=None):
        self.mode = mode
        if self.mode == 'train':
            self.trajectory = []
            self.noise = OrnsteinUhlenbeckProcess(np.zeros((self.action_dim,)))

    def step(self, observation, reward, done):
        if self.mode == 'train' and self.replayer.count < 3000:
            action = np.random.uniform(self.action_low, self.action_high)
        else:
            action = self.actor_evaluate_net.predict(observation[np.newaxis])[0]
        if self.mode == 'train':
            noise = self.noise(sigma=0.1)
            action = (action + noise).clip(self.action_low, self.action_high)

            self.trajectory += [observation, reward, done, action]
            if len(self.trajectory) >= 8:
                state, _, _, action, next_state, reward, done, _ = self.trajectory[-8:]
                self.replayer.store(state, action, reward, next_state, done)
            
            if self.replayer.count >= 3000:
                self.learn()
        return action

    def close(self):
        pass

    def update_net(self, target_net, evaluate_net, learning_rate=0.005):
        average_weights = [(1. - learning_rate) * t + learning_rate * e for t, e
                in zip(target_net.get_weights(), evaluate_net.get_weights())]
        target_net.set_weights(average_weights)

    def learn(self):
        # replay
        states, actions, rewards, next_states, dones = self.replayer.sample(64)
        state_tensor = tf.convert_to_tensor(states, dtype=tf.float32)
        
        # learn critic
        next_actions = self.actor_target_net.predict(next_states)
        next_noises = np.random.normal(0, 0.2, size=next_actions.shape)
        next_actions = (next_actions + next_noises).clip(self.action_low, self.action_high)
        state_actions = np.hstack([states, actions])
        next_state_actions = np.hstack([next_states, next_actions])
        next_q0s = self.critic0_target_net.predict(next_state_actions)[:, 0]
        next_q1s = self.critic1_target_net.predict(next_state_actions)[:, 0]
        next_qs = np.minimum(next_q0s, next_q1s)
        targets = rewards + (1. - dones) * self.gamma * next_qs
        self.critic0_evaluate_net.fit(state_actions, targets[:, np.newaxis], verbose=0)
        self.critic1_evaluate_net.fit(state_actions, targets[:, np.newaxis], verbose=0)

        # learn actor
        with tf.GradientTape() as tape:
            action_tensor = self.actor_evaluate_net(state_tensor)
            state_action_tensor = tf.concat([state_tensor, action_tensor], axis=1)
            q_tensor = self.critic0_evaluate_net(state_action_tensor)
            loss_tensor = -tf.reduce_mean(q_tensor)
        grad_tensors = tape.gradient(loss_tensor, self.actor_evaluate_net.variables)
        self.actor_evaluate_net.optimizer.apply_gradients(zip(
                grad_tensors, self.actor_evaluate_net.variables))

        self.update_net(self.critic0_target_net, self.critic0_evaluate_net)
        self.update_net(self.critic1_target_net, self.critic1_evaluate_net)
        self.update_net(self.actor_target_net, self.actor_evaluate_net)


agent = TD3Agent(env)

# %%
def play_episode(env, agent, max_episode_steps=None, mode=None, render=False):
    observation, reward, done = env.reset(), 0., False
    agent.reset(mode=mode)
    episode_reward, elapsed_steps = 0., 0
    while True:
        action = agent.step(observation, reward, done)
        if render:
            env.render()
        if done:
            break
        observation, reward, done, _ = env.step(action)
        episode_reward += reward
        elapsed_steps += 1
        if max_episode_steps and elapsed_steps >= max_episode_steps:
            break
    agent.close()
    return episode_reward, elapsed_steps


logging.info('==== train ====')
episode_rewards = []
for episode in itertools.count():
    episode_reward, elapsed_steps = play_episode(env.unwrapped, agent,
            max_episode_steps=env._max_episode_steps, mode='train')
    episode_rewards.append(episode_reward)
    logging.debug('train episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
    if np.mean(episode_rewards[-10:]) > -150:
        break
plt.plot(episode_rewards)


logging.info('==== test ====')
episode_rewards = []
for episode in range(100):
    episode_reward, elapsed_steps = play_episode(env, agent)
    episode_rewards.append(episode_reward)
    logging.debug('test episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
logging.info('average episode reward = %.2f ± %.2f',
        np.mean(episode_rewards), np.std(episode_rewards))
# Out:
# 17:58:32 [INFO] ==== train ====
# 17:58:32 [DEBUG] train episode 0: reward = -1779.61, steps = 200
# 17:58:32 [DEBUG] train episode 1: reward = -1026.05, steps = 200
# 17:58:33 [DEBUG] train episode 2: reward = -1556.83, steps = 200
# 17:58:33 [DEBUG] train episode 3: reward = -1127.41, steps = 200
# 17:58:33 [DEBUG] train episode 4: reward = -1675.42, steps = 200
# 17:58:33 [DEBUG] train episode 5: reward = -1632.59, steps = 200
# 17:58:33 [DEBUG] train episode 6: reward = -750.72, steps = 200
# 17:58:33 [DEBUG] train episode 7: reward = -1794.28, steps = 200
# 17:58:33 [DEBUG] train episode 8: reward = -928.49, steps = 200
# 17:58:34 [DEBUG] train episode 9: reward = -1680.41, steps = 200
# 17:58:34 [DEBUG] train episode 10: reward = -1312.04, steps = 200
# 17:58:34 [DEBUG] train episode 11: reward = -873.37, steps = 200
# 17:58:34 [DEBUG] train episode 12: reward = -1509.77, steps = 200
# 17:58:34 [DEBUG] train episode 13: reward = -994.03, steps = 200
# 17:58:34 [DEBUG] train episode 14: reward = -909.50, steps = 200
# 18:00:50 [DEBUG] train episode 15: reward = -1102.96, steps = 200
# 18:03:11 [DEBUG] train episode 16: reward = -1074.23, steps = 200
# 18:05:33 [DEBUG] train episode 17: reward = -1355.33, steps = 200
# 18:07:51 [DEBUG] train episode 18: reward = -1613.90, steps = 200
# 18:10:15 [DEBUG] train episode 19: reward = -1369.05, steps = 200
# 18:12:34 [DEBUG] train episode 20: reward = -1407.69, steps = 200
# 18:14:55 [DEBUG] train episode 21: reward = -1751.93, steps = 200
# 18:17:15 [DEBUG] train episode 22: reward = -1680.07, steps = 200
# 18:19:37 [DEBUG] train episode 23: reward = -1687.30, steps = 200
# 18:21:56 [DEBUG] train episode 24: reward = -1039.62, steps = 200
# 18:24:16 [DEBUG] train episode 25: reward = -1374.86, steps = 200
# 18:26:35 [DEBUG] train episode 26: reward = -1257.31, steps = 200
# 18:28:54 [DEBUG] train episode 27: reward = -1025.61, steps = 200
# 18:31:15 [DEBUG] train episode 28: reward = -898.92, steps = 200
# 18:33:35 [DEBUG] train episode 29: reward = -1379.01, steps = 200
# 18:35:56 [DEBUG] train episode 30: reward = -1150.48, steps = 200
# 18:38:15 [DEBUG] train episode 31: reward = -1047.47, steps = 200
# 18:40:19 [DEBUG] train episode 32: reward = -632.49, steps = 200
# 18:42:21 [DEBUG] train episode 33: reward = -913.60, steps = 200
# 18:44:23 [DEBUG] train episode 34: reward = -879.58, steps = 200
# 18:46:26 [DEBUG] train episode 35: reward = -893.98, steps = 200
# 18:48:29 [DEBUG] train episode 36: reward = -998.47, steps = 200
# 18:50:31 [DEBUG] train episode 37: reward = -505.43, steps = 200
# 18:52:34 [DEBUG] train episode 38: reward = -634.26, steps = 200
# 18:54:38 [DEBUG] train episode 39: reward = -881.89, steps = 200
# 18:56:40 [DEBUG] train episode 40: reward = -669.12, steps = 200
# 18:58:43 [DEBUG] train episode 41: reward = -895.32, steps = 200
# 19:00:46 [DEBUG] train episode 42: reward = -375.50, steps = 200
# 19:02:48 [DEBUG] train episode 43: reward = -128.29, steps = 200
# 19:04:50 [DEBUG] train episode 44: reward = -1102.92, steps = 200
# 19:06:52 [DEBUG] train episode 45: reward = -123.20, steps = 200
# 19:08:55 [DEBUG] train episode 46: reward = -367.23, steps = 200
# 19:10:55 [DEBUG] train episode 47: reward = -121.32, steps = 200
# 19:12:57 [DEBUG] train episode 48: reward = -128.63, steps = 200
# 19:15:01 [DEBUG] train episode 49: reward = -128.81, steps = 200
# 19:17:02 [DEBUG] train episode 50: reward = -760.28, steps = 200
# 19:19:04 [DEBUG] train episode 51: reward = -123.40, steps = 200
# 19:21:06 [DEBUG] train episode 52: reward = -243.22, steps = 200
# 19:23:08 [DEBUG] train episode 53: reward = -632.28, steps = 200
# 19:25:11 [DEBUG] train episode 54: reward = -249.19, steps = 200
# 19:27:13 [DEBUG] train episode 55: reward = -504.70, steps = 200
# 19:29:18 [DEBUG] train episode 56: reward = -125.92, steps = 200
# 19:31:20 [DEBUG] train episode 57: reward = -377.21, steps = 200
# 19:33:24 [DEBUG] train episode 58: reward = -246.86, steps = 200
# 19:35:27 [DEBUG] train episode 59: reward = -365.11, steps = 200
# 19:37:29 [DEBUG] train episode 60: reward = -126.74, steps = 200
# 19:39:32 [DEBUG] train episode 61: reward = -371.54, steps = 200
# 19:41:34 [DEBUG] train episode 62: reward = -243.13, steps = 200
# 19:43:36 [DEBUG] train episode 63: reward = -247.13, steps = 200
# 19:45:39 [DEBUG] train episode 64: reward = -241.24, steps = 200
# 19:47:42 [DEBUG] train episode 65: reward = -125.93, steps = 200
# 19:49:44 [DEBUG] train episode 66: reward = -128.35, steps = 200
# 19:51:48 [DEBUG] train episode 67: reward = -504.51, steps = 200
# 19:53:49 [DEBUG] train episode 68: reward = -672.08, steps = 200
# 19:55:55 [DEBUG] train episode 69: reward = -242.26, steps = 200
# 19:58:03 [DEBUG] train episode 70: reward = -121.37, steps = 200
# 20:00:13 [DEBUG] train episode 71: reward = -125.82, steps = 200
# 20:02:25 [DEBUG] train episode 72: reward = -472.35, steps = 200
# 20:04:34 [DEBUG] train episode 73: reward = -129.59, steps = 200
# 20:06:46 [DEBUG] train episode 74: reward = -360.04, steps = 200
# 20:08:59 [DEBUG] train episode 75: reward = -126.74, steps = 200
# 20:11:09 [DEBUG] train episode 76: reward = -363.66, steps = 200
# 20:13:29 [DEBUG] train episode 77: reward = -127.20, steps = 200
# 20:16:03 [DEBUG] train episode 78: reward = -244.91, steps = 200
# 20:19:01 [DEBUG] train episode 79: reward = -124.64, steps = 200
# 20:21:40 [DEBUG] train episode 80: reward = -532.90, steps = 200
# 20:24:20 [DEBUG] train episode 81: reward = -129.29, steps = 200
# 20:27:26 [DEBUG] train episode 82: reward = -623.68, steps = 200
# 20:30:44 [DEBUG] train episode 83: reward = -254.36, steps = 200
# 20:33:38 [DEBUG] train episode 84: reward = -249.83, steps = 200
# 20:36:45 [DEBUG] train episode 85: reward = -886.26, steps = 200
# 20:39:43 [DEBUG] train episode 86: reward = -618.70, steps = 200
# 20:42:39 [DEBUG] train episode 87: reward = -370.19, steps = 200
# 20:45:33 [DEBUG] train episode 88: reward = -129.20, steps = 200
# 20:48:22 [DEBUG] train episode 89: reward = -248.79, steps = 200
# 20:51:19 [DEBUG] train episode 90: reward = -123.74, steps = 200
# 20:54:03 [DEBUG] train episode 91: reward = -247.42, steps = 200
# 20:56:58 [DEBUG] train episode 92: reward = -239.95, steps = 200
# 21:00:02 [DEBUG] train episode 93: reward = -127.96, steps = 200
# 21:03:03 [DEBUG] train episode 94: reward = -127.02, steps = 200
# 21:06:25 [DEBUG] train episode 95: reward = -1041.72, steps = 200
# 21:09:21 [DEBUG] train episode 96: reward = -123.01, steps = 200
# 21:12:07 [DEBUG] train episode 97: reward = -367.17, steps = 200
# 21:14:58 [DEBUG] train episode 98: reward = -246.58, steps = 200
# 21:17:50 [DEBUG] train episode 99: reward = -736.66, steps = 200
# 21:20:47 [DEBUG] train episode 100: reward = -369.60, steps = 200
# 21:23:49 [DEBUG] train episode 101: reward = -240.65, steps = 200
# 21:27:01 [DEBUG] train episode 102: reward = -961.80, steps = 200
# 21:30:17 [DEBUG] train episode 103: reward = -633.99, steps = 200
# 21:33:23 [DEBUG] train episode 104: reward = -646.93, steps = 200
# 21:36:13 [DEBUG] train episode 105: reward = -248.46, steps = 200
# 21:39:02 [DEBUG] train episode 106: reward = -244.34, steps = 200
# 21:41:53 [DEBUG] train episode 107: reward = -360.96, steps = 200
# 21:44:42 [DEBUG] train episode 108: reward = -119.46, steps = 200
# 21:47:37 [DEBUG] train episode 109: reward = -502.17, steps = 200
# 21:50:36 [DEBUG] train episode 110: reward = -511.21, steps = 200
# 21:53:40 [DEBUG] train episode 111: reward = -124.94, steps = 200
# 21:56:43 [DEBUG] train episode 112: reward = -357.23, steps = 200
# 21:59:40 [DEBUG] train episode 113: reward = -246.34, steps = 200
# 22:02:30 [DEBUG] train episode 114: reward = -119.95, steps = 200
# 22:05:12 [DEBUG] train episode 115: reward = -477.45, steps = 200
# 22:07:48 [DEBUG] train episode 116: reward = -375.53, steps = 200
# 22:10:33 [DEBUG] train episode 117: reward = -123.46, steps = 200
# 22:13:20 [DEBUG] train episode 118: reward = -240.16, steps = 200
# 22:16:14 [DEBUG] train episode 119: reward = -125.43, steps = 200
# 22:19:12 [DEBUG] train episode 120: reward = -623.25, steps = 200
# 22:22:11 [DEBUG] train episode 121: reward = -245.70, steps = 200
# 22:25:22 [DEBUG] train episode 122: reward = -243.36, steps = 200
# 22:28:20 [DEBUG] train episode 123: reward = -512.66, steps = 200
# 22:31:35 [DEBUG] train episode 124: reward = -122.48, steps = 200
# 22:34:57 [DEBUG] train episode 125: reward = -368.06, steps = 200
# 22:37:33 [DEBUG] train episode 126: reward = -126.63, steps = 200
# 22:40:22 [DEBUG] train episode 127: reward = -126.61, steps = 200
# 22:42:53 [DEBUG] train episode 128: reward = -122.34, steps = 200
# 22:45:16 [DEBUG] train episode 129: reward = -355.01, steps = 200
# 22:47:50 [DEBUG] train episode 130: reward = -2.74, steps = 200
# 22:50:30 [DEBUG] train episode 131: reward = -362.53, steps = 200
# 22:53:18 [DEBUG] train episode 132: reward = -124.13, steps = 200
# 22:56:52 [DEBUG] train episode 133: reward = -243.08, steps = 200
# 23:00:16 [DEBUG] train episode 134: reward = -509.38, steps = 200
# 23:02:50 [DEBUG] train episode 135: reward = -541.73, steps = 200
# 23:05:14 [DEBUG] train episode 136: reward = -240.73, steps = 200
# 23:07:31 [DEBUG] train episode 137: reward = -484.19, steps = 200
# 23:09:54 [DEBUG] train episode 138: reward = -244.57, steps = 200
# 23:12:33 [DEBUG] train episode 139: reward = -361.16, steps = 200
# 23:14:52 [DEBUG] train episode 140: reward = -241.35, steps = 200
# 23:17:10 [DEBUG] train episode 141: reward = -357.83, steps = 200
# 23:19:34 [DEBUG] train episode 142: reward = -550.68, steps = 200
# 23:21:59 [DEBUG] train episode 143: reward = -124.02, steps = 200
# 23:24:32 [DEBUG] train episode 144: reward = -122.95, steps = 200
# 23:27:04 [DEBUG] train episode 145: reward = -122.13, steps = 200
# 23:29:40 [DEBUG] train episode 146: reward = -127.18, steps = 200
# 23:32:12 [DEBUG] train episode 147: reward = -245.33, steps = 200
# 23:34:22 [DEBUG] train episode 148: reward = -128.38, steps = 200
# 23:36:27 [DEBUG] train episode 149: reward = -480.09, steps = 200
# 23:38:26 [DEBUG] train episode 150: reward = -620.39, steps = 200
# 23:40:34 [DEBUG] train episode 151: reward = -368.15, steps = 200
# 23:42:38 [DEBUG] train episode 152: reward = -2.39, steps = 200
# 23:44:48 [DEBUG] train episode 153: reward = -365.74, steps = 200
# 23:47:14 [DEBUG] train episode 154: reward = -246.53, steps = 200
# 23:49:34 [DEBUG] train episode 155: reward = -372.11, steps = 200
# 23:51:48 [DEBUG] train episode 156: reward = -241.25, steps = 200
# 23:53:52 [DEBUG] train episode 157: reward = -123.62, steps = 200
# 23:55:49 [DEBUG] train episode 158: reward = -238.62, steps = 200
# 23:57:43 [DEBUG] train episode 159: reward = -125.78, steps = 200
# 23:59:39 [DEBUG] train episode 160: reward = -354.99, steps = 200
# 00:01:34 [DEBUG] train episode 161: reward = -373.10, steps = 200
# 00:03:31 [DEBUG] train episode 162: reward = -667.82, steps = 200
# 00:05:27 [DEBUG] train episode 163: reward = -122.83, steps = 200
# 00:07:22 [DEBUG] train episode 164: reward = -122.39, steps = 200
# 00:09:18 [DEBUG] train episode 165: reward = -125.88, steps = 200
# 00:11:13 [DEBUG] train episode 166: reward = -245.32, steps = 200
# 00:13:08 [DEBUG] train episode 167: reward = -617.80, steps = 200
# 00:15:03 [DEBUG] train episode 168: reward = -245.74, steps = 200
# 00:16:58 [DEBUG] train episode 169: reward = -247.57, steps = 200
# 00:18:53 [DEBUG] train episode 170: reward = -592.28, steps = 200
# 00:20:48 [DEBUG] train episode 171: reward = -125.23, steps = 200
# 00:22:47 [DEBUG] train episode 172: reward = -123.50, steps = 200
# 00:24:41 [DEBUG] train episode 173: reward = -567.70, steps = 200
# 00:26:37 [DEBUG] train episode 174: reward = -240.92, steps = 200
# 00:28:33 [DEBUG] train episode 175: reward = -481.52, steps = 200
# 00:30:31 [DEBUG] train episode 176: reward = -126.12, steps = 200
# 00:32:28 [DEBUG] train episode 177: reward = -536.71, steps = 200
# 00:34:23 [DEBUG] train episode 178: reward = -123.87, steps = 200
# 00:36:19 [DEBUG] train episode 179: reward = -358.57, steps = 200
# 00:38:13 [DEBUG] train episode 180: reward = -619.98, steps = 200
# 00:40:09 [DEBUG] train episode 181: reward = -246.35, steps = 200
# 00:42:03 [DEBUG] train episode 182: reward = -239.42, steps = 200
# 00:43:58 [DEBUG] train episode 183: reward = -246.18, steps = 200
# 00:45:54 [DEBUG] train episode 184: reward = -361.80, steps = 200
# 00:47:49 [DEBUG] train episode 185: reward = -123.39, steps = 200
# 00:49:33 [DEBUG] train episode 186: reward = -122.26, steps = 200
# 00:51:14 [DEBUG] train episode 187: reward = -1.81, steps = 200
# 00:52:55 [DEBUG] train episode 188: reward = -356.73, steps = 200
# 00:54:34 [DEBUG] train episode 189: reward = -1.38, steps = 200
# 00:56:15 [DEBUG] train episode 190: reward = -237.34, steps = 200
# 00:57:54 [DEBUG] train episode 191: reward = -476.33, steps = 200
# 00:59:34 [DEBUG] train episode 192: reward = -117.79, steps = 200
# 01:01:14 [DEBUG] train episode 193: reward = -572.26, steps = 200
# 01:02:55 [DEBUG] train episode 194: reward = -125.26, steps = 200
# 01:04:34 [DEBUG] train episode 195: reward = -361.57, steps = 200
# 01:06:15 [DEBUG] train episode 196: reward = -369.19, steps = 200
# 01:07:55 [DEBUG] train episode 197: reward = -486.17, steps = 200
# 01:09:39 [DEBUG] train episode 198: reward = -371.11, steps = 200
# 01:11:19 [DEBUG] train episode 199: reward = -125.76, steps = 200
# 01:12:59 [DEBUG] train episode 200: reward = -506.53, steps = 200
# 01:14:40 [DEBUG] train episode 201: reward = -119.45, steps = 200
# 01:16:18 [DEBUG] train episode 202: reward = -124.93, steps = 200
# 01:17:53 [DEBUG] train episode 203: reward = -121.66, steps = 200
# 01:19:29 [DEBUG] train episode 204: reward = -245.17, steps = 200
# 01:21:04 [DEBUG] train episode 205: reward = -124.76, steps = 200
# 01:22:39 [DEBUG] train episode 206: reward = -125.52, steps = 200
# 01:24:14 [DEBUG] train episode 207: reward = -119.99, steps = 200
# 01:25:50 [DEBUG] train episode 208: reward = -118.43, steps = 200
# 01:27:25 [DEBUG] train episode 209: reward = -126.78, steps = 200
# 01:29:01 [DEBUG] train episode 210: reward = -122.53, steps = 200
# 01:29:01 [INFO] ==== test ====
# 01:29:47 [DEBUG] test episode 0: reward = -118.47, steps = 200
# 01:30:37 [DEBUG] test episode 1: reward = -122.39, steps = 200
# 01:31:30 [DEBUG] test episode 2: reward = -1.54, steps = 200
# 01:32:23 [DEBUG] test episode 3: reward = -606.18, steps = 200
# 01:33:14 [DEBUG] test episode 4: reward = -126.52, steps = 200
# 01:34:06 [DEBUG] test episode 5: reward = -127.36, steps = 200
# 01:34:58 [DEBUG] test episode 6: reward = -120.33, steps = 200
# 01:35:56 [DEBUG] test episode 7: reward = -489.57, steps = 200
# 01:36:46 [DEBUG] test episode 8: reward = -506.19, steps = 200
# 01:37:34 [DEBUG] test episode 9: reward = -121.05, steps = 200
# 01:38:30 [DEBUG] test episode 10: reward = -122.83, steps = 200
# 01:39:24 [DEBUG] test episode 11: reward = -1.32, steps = 200
# 01:40:15 [DEBUG] test episode 12: reward = -485.27, steps = 200
# 01:41:01 [DEBUG] test episode 13: reward = -358.11, steps = 200
# 01:41:47 [DEBUG] test episode 14: reward = -126.70, steps = 200
# 01:42:52 [DEBUG] test episode 15: reward = -570.60, steps = 200
# 01:43:55 [DEBUG] test episode 16: reward = -243.00, steps = 200
# 01:45:00 [DEBUG] test episode 17: reward = -497.47, steps = 200
# 01:46:05 [DEBUG] test episode 18: reward = -126.05, steps = 200
# 01:47:10 [DEBUG] test episode 19: reward = -234.68, steps = 200
# 01:48:16 [DEBUG] test episode 20: reward = -360.24, steps = 200
# 01:49:21 [DEBUG] test episode 21: reward = -124.66, steps = 200
# 01:50:26 [DEBUG] test episode 22: reward = -126.72, steps = 200
# 01:51:32 [DEBUG] test episode 23: reward = -367.22, steps = 200
# 01:52:36 [DEBUG] test episode 24: reward = -584.80, steps = 200
# 01:53:41 [DEBUG] test episode 25: reward = -120.46, steps = 200
# 01:54:48 [DEBUG] test episode 26: reward = -125.22, steps = 200
# 01:55:54 [DEBUG] test episode 27: reward = -239.44, steps = 200
# 01:57:02 [DEBUG] test episode 28: reward = -234.84, steps = 200
# 01:58:07 [DEBUG] test episode 29: reward = -122.84, steps = 200
# 01:59:13 [DEBUG] test episode 30: reward = -557.58, steps = 200
# 02:00:21 [DEBUG] test episode 31: reward = -124.87, steps = 200
# 02:01:25 [DEBUG] test episode 32: reward = -242.42, steps = 200
# 02:02:31 [DEBUG] test episode 33: reward = -636.43, steps = 200
# 02:03:37 [DEBUG] test episode 34: reward = -127.36, steps = 200
# 02:04:43 [DEBUG] test episode 35: reward = -495.57, steps = 200
# 02:05:48 [DEBUG] test episode 36: reward = -474.95, steps = 200
# 02:06:54 [DEBUG] test episode 37: reward = -544.26, steps = 200
# 02:08:00 [DEBUG] test episode 38: reward = -123.77, steps = 200
# 02:09:05 [DEBUG] test episode 39: reward = -122.78, steps = 200
# 02:10:09 [DEBUG] test episode 40: reward = -357.19, steps = 200
# 02:11:13 [DEBUG] test episode 41: reward = -125.26, steps = 200
# 02:12:19 [DEBUG] test episode 42: reward = -510.98, steps = 200
# 02:13:25 [DEBUG] test episode 43: reward = -122.92, steps = 200
# 02:14:30 [DEBUG] test episode 44: reward = -352.75, steps = 200
# 02:15:34 [DEBUG] test episode 45: reward = -235.63, steps = 200
# 02:16:39 [DEBUG] test episode 46: reward = -124.38, steps = 200
# 02:17:41 [DEBUG] test episode 47: reward = -123.12, steps = 200
# 02:18:46 [DEBUG] test episode 48: reward = -356.79, steps = 200
# 02:19:50 [DEBUG] test episode 49: reward = -122.82, steps = 200
# 02:20:55 [DEBUG] test episode 50: reward = -482.93, steps = 200
# 02:21:59 [DEBUG] test episode 51: reward = -123.72, steps = 200
# 02:23:04 [DEBUG] test episode 52: reward = -1.34, steps = 200
# 02:24:10 [DEBUG] test episode 53: reward = -242.64, steps = 200
# 02:25:14 [DEBUG] test episode 54: reward = -357.67, steps = 200
# 02:26:20 [DEBUG] test episode 55: reward = -357.53, steps = 200
# 02:27:27 [DEBUG] test episode 56: reward = -121.04, steps = 200
# 02:28:33 [DEBUG] test episode 57: reward = -124.82, steps = 200
# 02:29:37 [DEBUG] test episode 58: reward = -124.87, steps = 200
# 02:30:42 [DEBUG] test episode 59: reward = -601.13, steps = 200
# 02:31:48 [DEBUG] test episode 60: reward = -1.37, steps = 200
# 02:32:52 [DEBUG] test episode 61: reward = -124.28, steps = 200
# 02:33:57 [DEBUG] test episode 62: reward = -118.79, steps = 200
# 02:35:01 [DEBUG] test episode 63: reward = -364.01, steps = 200
# 02:36:07 [DEBUG] test episode 64: reward = -124.44, steps = 200
# 02:37:11 [DEBUG] test episode 65: reward = -235.55, steps = 200
# 02:38:18 [DEBUG] test episode 66: reward = -243.06, steps = 200
# 02:39:22 [DEBUG] test episode 67: reward = -617.16, steps = 200
# 02:40:28 [DEBUG] test episode 68: reward = -120.09, steps = 200
# 02:41:31 [DEBUG] test episode 69: reward = -124.03, steps = 200
# 02:42:38 [DEBUG] test episode 70: reward = -246.71, steps = 200
# 02:43:44 [DEBUG] test episode 71: reward = -124.56, steps = 200
# 02:44:49 [DEBUG] test episode 72: reward = -235.33, steps = 200
# 02:45:55 [DEBUG] test episode 73: reward = -245.21, steps = 200
# 02:47:00 [DEBUG] test episode 74: reward = -126.59, steps = 200
# 02:48:06 [DEBUG] test episode 75: reward = -119.45, steps = 200
# 02:49:11 [DEBUG] test episode 76: reward = -613.44, steps = 200
# 02:50:17 [DEBUG] test episode 77: reward = -125.26, steps = 200
# 02:51:22 [DEBUG] test episode 78: reward = -126.09, steps = 200
# 02:52:28 [DEBUG] test episode 79: reward = -120.10, steps = 200
# 02:53:34 [DEBUG] test episode 80: reward = -349.80, steps = 200
# 02:54:39 [DEBUG] test episode 81: reward = -232.66, steps = 200
# 02:55:46 [DEBUG] test episode 82: reward = -1.52, steps = 200
# 02:56:51 [DEBUG] test episode 83: reward = -124.42, steps = 200
# 02:57:58 [DEBUG] test episode 84: reward = -234.94, steps = 200
# 02:59:03 [DEBUG] test episode 85: reward = -1.26, steps = 200
# 03:00:09 [DEBUG] test episode 86: reward = -362.64, steps = 200
# 03:01:13 [DEBUG] test episode 87: reward = -361.64, steps = 200
# 03:02:19 [DEBUG] test episode 88: reward = -237.36, steps = 200
# 03:03:25 [DEBUG] test episode 89: reward = -122.29, steps = 200
# 03:04:31 [DEBUG] test episode 90: reward = -353.51, steps = 200
# 03:05:35 [DEBUG] test episode 91: reward = -235.01, steps = 200
# 03:06:41 [DEBUG] test episode 92: reward = -124.26, steps = 200
# 03:07:47 [DEBUG] test episode 93: reward = -504.13, steps = 200
# 03:08:53 [DEBUG] test episode 94: reward = -245.99, steps = 200
# 03:10:01 [DEBUG] test episode 95: reward = -124.82, steps = 200
# 03:11:06 [DEBUG] test episode 96: reward = -2.03, steps = 200
# 03:12:09 [DEBUG] test episode 97: reward = -243.61, steps = 200
# 03:13:13 [DEBUG] test episode 98: reward = -124.90, steps = 200
# 03:14:17 [DEBUG] test episode 99: reward = -123.34, steps = 200
# 03:14:17 [INFO] average episode reward = -241.97 ± 169.82

# %%
env.close()
