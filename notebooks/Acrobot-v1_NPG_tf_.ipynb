# %% [markdown]
# # Use Natural Policy Gradient to Play Acrobot-v1
#
# TensorFlow version

# %%
# %matplotlib inline

import sys
import logging
import imp
import itertools

import numpy as np
np.random.seed(0)
import pandas as pd
import scipy.signal as signal
import gym
import matplotlib.pyplot as plt
import tensorflow.compat.v2 as tf
tf.random.set_seed(0)
from tensorflow import keras
from tensorflow import nn
from tensorflow import optimizers
from tensorflow import losses
from tensorflow.keras import layers


imp.reload(logging)
logging.basicConfig(level=logging.DEBUG,
        format='%(asctime)s [%(levelname)s] %(message)s',
        stream=sys.stdout, datefmt='%H:%M:%S')

# %%
env = gym.make('Acrobot-v1')
env.seed(0)
for key in vars(env):
    logging.info('%s: %s', key, vars(env)[key])
# Out:
# 15:25:36 [INFO] env: <AcrobotEnv<Acrobot-v1>>
# 15:25:36 [INFO] action_space: Discrete(3)
# 15:25:36 [INFO] observation_space: Box(-28.274333953857422, 28.274333953857422, (6,), float32)
# 15:25:36 [INFO] reward_range: (-inf, inf)
# 15:25:36 [INFO] metadata: {'render.modes': ['human', 'rgb_array'], 'video.frames_per_second': 15}
# 15:25:36 [INFO] _max_episode_steps: 500
# 15:25:36 [INFO] _elapsed_steps: None

# %%
class PPOReplayer:
    def __init__(self):
        self.fields = ['state', 'action', 'prob', 'advantage', 'return']
        self.memory = pd.DataFrame(columns=self.fields)
    
    def store(self, df):
        self.memory = pd.concat([self.memory, df[self.fields]], ignore_index=True)
        
    def sample(self, size):
        indices = np.random.choice(self.memory.shape[0], size=size)
        return (np.stack(self.memory.loc[indices, field]) for field in
                self.memory.columns)

# %%
def conjugate_gradient(f, b, iter_count=10, epsilon=1e-12, tol=1e-6):
    x = b * 0.
    r = tf.identity(b)
    p = tf.identity(b)
    rho = tf.reduce_sum(r * r)
    for i in range(iter_count):
        z = f(p)
        alpha = rho / (tf.reduce_sum(p * z) + epsilon)
        x += alpha * p
        r -= alpha * z
        rho_new = tf.reduce_sum(r * r)
        p = r + (rho_new / rho) * p
        rho = rho_new
        if rho < tol:
            break
    return x, f(x)

# %%
class NPGAgent:
    def __init__(self, env):
        self.action_n = env.action_space.n
        self.gamma = 0.99
        
        self.replayer = PPOReplayer()
        self.trajectory = []

        self.max_kl = 0.0005
        self.actor_net = self.build_net(hidden_sizes=[100,],
                output_size=self.action_n, output_activation=nn.softmax)
        self.critic_net = self.build_net(hidden_sizes=[100,],
                learning_rate=0.002)

    def build_net(self, input_size=None, hidden_sizes=None, output_size=1, 
                activation=nn.relu, output_activation=None,
                loss=losses.mse, learning_rate=0.001):
        model = keras.Sequential()
        for hidden_size in hidden_sizes:
            model.add(layers.Dense(units=hidden_size,
                    activation=activation))
        model.add(layers.Dense(units=output_size,
                activation=output_activation))
        optimizer = optimizers.Adam(learning_rate)
        model.compile(optimizer=optimizer, loss=loss)
        return model

    def reset(self, mode=None):
        self.mode = mode
        if self.mode == 'train':
            self.trajectory = []

    def step(self, observation, reward, done):
        probs = self.actor_net.predict(observation[np.newaxis])[0]
        action = np.random.choice(self.action_n, p=probs)
        if self.mode == 'train':
            self.trajectory += [observation, reward, done, action]
        return action

    def close(self):
        if self.mode == 'train':
            self.save_trajectory_to_replayer()
            if len(self.replayer.memory) >= 1000:
                for batch in range(5): # learn multiple times
                    self.learn()
                self.replayer = PPOReplayer() # reset replayer after the agent changes itself

    def save_trajectory_to_replayer(self):
        df = pd.DataFrame(
                np.array(self.trajectory, dtype=object).reshape(-1, 4),
                columns=['state', 'reward', 'done', 'action'], dtype=object)
        states = np.stack(df['state'])
        df['v'] = self.critic_net.predict(states)
        pis = self.actor_net.predict(states)
        df['prob'] = [pi[action] for pi, action in zip(pis, df['action'])]
        df['next_v'] = df['v'].shift(-1).fillna(0.)
        df['u'] = df['reward'] + self.gamma * df['next_v']
        df['delta'] = df['u'] - df['v']
        df['advantage'] = signal.lfilter([1.,], [1., -self.gamma],
                df['delta'][::-1])[::-1]
        df['return'] = signal.lfilter([1.,], [1., -self.gamma],
                df['reward'][::-1])[::-1]
        self.replayer.store(df)

    def learn(self):
        states, actions, old_pis, advantages, returns = \
                self.replayer.sample(size=64)
        state_tensor = tf.convert_to_tensor(states, dtype=tf.float32)
        action_tensor = tf.convert_to_tensor(actions, dtype=tf.int32)
        old_pi_tensor = tf.convert_to_tensor(old_pis, dtype=tf.float32)
        advantage_tensor = tf.convert_to_tensor(advantages, dtype=tf.float32)
        
        # train actor
        # ... calculate first order gradient of KL divergence
        with tf.GradientTape() as tape:
            all_pi_tensor = self.actor_net(state_tensor)
            pi_tensor = tf.gather(all_pi_tensor, action_tensor, batch_dims=1)
            surrogate_tensor = (pi_tensor / old_pi_tensor) * advantage_tensor
        actor_grads = tape.gradient(surrogate_tensor, self.actor_net.variables)
        loss_grad = tf.concat([tf.reshape(grad, (-1,)) for grad in actor_grads], axis=0)
        
        # ... calculate conjugate gradient: Fx = g
        def f(x): # calculate Fx
            with tf.GradientTape() as tape2: # tape for 2nd-order gradient
                with tf.GradientTape() as tape1: # tape for 1st-order gradient
                    prob_tensor = self.actor_net(state_tensor)
                    prob_old_tensor = tf.stop_gradient(prob_tensor)
                    kld_tensor = tf.reduce_sum(prob_old_tensor * (tf.math.log(
                            prob_old_tensor) - tf.math.log(prob_tensor)), axis=1)
                    kld_loss_tensor = tf.reduce_mean(kld_tensor)
                grads = tape1.gradient(kld_loss_tensor, self.actor_net.variables)
                flatten_grad_tensor = tf.concat(
                        [tf.reshape(grad, (-1,)) for grad in grads], axis=-1)
                grad_matmul_x = tf.tensordot(flatten_grad_tensor, x, axes=[[-1], [-1]])
            grad_grads = tape2.gradient(grad_matmul_x, self.actor_net.variables)
            flatten_grad_grad = tf.stop_gradient(tf.concat(
                    [tf.reshape(grad_grad, (-1,)) for grad_grad in grad_grads], axis=-1))
            fx = flatten_grad_grad + x * 1e-2
            return fx
        x, fx = conjugate_gradient(f, loss_grad)

        # ... calculate natural gradient
        natural_gradient_tensor = tf.sqrt(2 * self.max_kl / tf.reduce_sum(fx * x)) * x
        # ....... refactor the flatten gradient into un-flatten version
        flatten_natural_gradient = natural_gradient_tensor.numpy()
        weights = []
        begin = 0
        for weight in self.actor_net.get_weights():
            end = begin + weight.size
            weight += flatten_natural_gradient[begin:end].reshape(weight.shape)
            weights.append(weight)
            begin = end
        self.actor_net.set_weights(weights)
        
        # train critic
        self.critic_net.fit(states, returns, verbose=0)


agent = NPGAgent(env)

# %%
def play_episode(env, agent, max_episode_steps=None, mode=None, render=False):
    observation, reward, done = env.reset(), 0., False
    agent.reset(mode=mode)
    episode_reward, elapsed_steps = 0., 0
    while True:
        action = agent.step(observation, reward, done)
        if render:
            env.render()
        if done:
            break
        observation, reward, done, _ = env.step(action)
        episode_reward += reward
        elapsed_steps += 1
        if max_episode_steps and elapsed_steps >= max_episode_steps:
            break
    agent.close()
    return episode_reward, elapsed_steps


logging.info('==== train ====')
episode_rewards = []
for episode in itertools.count():
    episode_reward, elapsed_steps = play_episode(env.unwrapped, agent,
            max_episode_steps=env._max_episode_steps, mode='train')
    episode_rewards.append(episode_reward)
    logging.debug('train episode %d: reward = %.2f, steps = %d %d',
            episode, episode_reward, elapsed_steps, np.mean(episode_rewards[-10:]))
    if np.mean(episode_rewards[-10:]) > -120:
        break
plt.plot(episode_rewards)


logging.info('==== test ====')
episode_rewards = []
for episode in range(100):
    episode_reward, elapsed_steps = play_episode(env, agent)
    episode_rewards.append(episode_reward)
    logging.debug('test episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
logging.info('average episode reward = %.2f ± %.2f',
        np.mean(episode_rewards), np.std(episode_rewards))
# Out:
# 15:25:37 [INFO] ==== train ====
# 15:26:13 [INFO] NumExpr defaulting to 8 threads.
# 15:26:13 [DEBUG] train episode 0: reward = -500.00, steps = 500 -500
# 15:26:45 [DEBUG] train episode 1: reward = -500.00, steps = 500 -500
# 15:27:16 [DEBUG] train episode 2: reward = -500.00, steps = 500 -500
# 15:27:44 [DEBUG] train episode 3: reward = -500.00, steps = 500 -500
# 15:28:08 [DEBUG] train episode 4: reward = -422.00, steps = 423 -484
# 15:28:30 [DEBUG] train episode 5: reward = -388.00, steps = 389 -468
# 15:28:54 [DEBUG] train episode 6: reward = -411.00, steps = 412 -460
# 15:29:19 [DEBUG] train episode 7: reward = -427.00, steps = 428 -456
# 15:29:46 [DEBUG] train episode 8: reward = -500.00, steps = 500 -460
# 15:30:15 [DEBUG] train episode 9: reward = -500.00, steps = 500 -464
# 15:30:31 [DEBUG] train episode 10: reward = -279.00, steps = 280 -442
# 15:31:00 [DEBUG] train episode 11: reward = -500.00, steps = 500 -442
# 15:31:14 [DEBUG] train episode 12: reward = -237.00, steps = 238 -416
# 15:31:30 [DEBUG] train episode 13: reward = -273.00, steps = 274 -393
# 15:31:46 [DEBUG] train episode 14: reward = -282.00, steps = 283 -379
# 15:32:10 [DEBUG] train episode 15: reward = -426.00, steps = 427 -383
# 15:32:33 [DEBUG] train episode 16: reward = -395.00, steps = 396 -381
# 15:32:54 [DEBUG] train episode 17: reward = -375.00, steps = 376 -376
# 15:33:08 [DEBUG] train episode 18: reward = -252.00, steps = 253 -351
# 15:33:37 [DEBUG] train episode 19: reward = -500.00, steps = 500 -351
# 15:33:53 [DEBUG] train episode 20: reward = -289.00, steps = 290 -352
# 15:34:16 [DEBUG] train episode 21: reward = -401.00, steps = 402 -343
# 15:34:34 [DEBUG] train episode 22: reward = -310.00, steps = 311 -350
# 15:35:01 [DEBUG] train episode 23: reward = -473.00, steps = 474 -370
# 15:35:20 [DEBUG] train episode 24: reward = -341.00, steps = 342 -376
# 15:35:49 [DEBUG] train episode 25: reward = -500.00, steps = 500 -383
# 15:36:09 [DEBUG] train episode 26: reward = -340.00, steps = 341 -378
# 15:36:37 [DEBUG] train episode 27: reward = -500.00, steps = 500 -390
# 15:37:05 [DEBUG] train episode 28: reward = -487.00, steps = 488 -414
# 15:37:28 [DEBUG] train episode 29: reward = -405.00, steps = 406 -404
# 15:37:56 [DEBUG] train episode 30: reward = -500.00, steps = 500 -425
# 15:38:17 [DEBUG] train episode 31: reward = -347.00, steps = 348 -420
# 15:38:40 [DEBUG] train episode 32: reward = -413.00, steps = 414 -430
# 15:39:04 [DEBUG] train episode 33: reward = -426.00, steps = 427 -425
# 15:39:26 [DEBUG] train episode 34: reward = -367.00, steps = 368 -428
# 15:39:54 [DEBUG] train episode 35: reward = -500.00, steps = 500 -428
# 15:40:10 [DEBUG] train episode 36: reward = -295.00, steps = 296 -424
# 15:40:24 [DEBUG] train episode 37: reward = -228.00, steps = 229 -396
# 15:40:52 [DEBUG] train episode 38: reward = -500.00, steps = 500 -398
# 15:41:21 [DEBUG] train episode 39: reward = -500.00, steps = 500 -407
# 15:41:49 [DEBUG] train episode 40: reward = -500.00, steps = 500 -407
# 15:42:18 [DEBUG] train episode 41: reward = -500.00, steps = 500 -422
# 15:42:33 [DEBUG] train episode 42: reward = -266.00, steps = 267 -408
# 15:42:59 [DEBUG] train episode 43: reward = -449.00, steps = 450 -410
# 15:43:27 [DEBUG] train episode 44: reward = -500.00, steps = 500 -423
# 15:43:50 [DEBUG] train episode 45: reward = -400.00, steps = 401 -413
# 15:44:09 [DEBUG] train episode 46: reward = -339.00, steps = 340 -418
# 15:44:26 [DEBUG] train episode 47: reward = -275.00, steps = 276 -422
# 15:44:47 [DEBUG] train episode 48: reward = -383.00, steps = 384 -411
# 15:44:59 [DEBUG] train episode 49: reward = -204.00, steps = 205 -381
# 15:45:14 [DEBUG] train episode 50: reward = -273.00, steps = 274 -358
# 15:45:27 [DEBUG] train episode 51: reward = -216.00, steps = 217 -330
# 15:45:48 [DEBUG] train episode 52: reward = -371.00, steps = 372 -341
# 15:46:16 [DEBUG] train episode 53: reward = -500.00, steps = 500 -346
# 15:46:37 [DEBUG] train episode 54: reward = -355.00, steps = 356 -331
# 15:46:58 [DEBUG] train episode 55: reward = -353.00, steps = 354 -326
# 15:47:15 [DEBUG] train episode 56: reward = -308.00, steps = 309 -323
# 15:47:41 [DEBUG] train episode 57: reward = -456.00, steps = 457 -341
# 15:48:09 [DEBUG] train episode 58: reward = -500.00, steps = 500 -353
# 15:48:22 [DEBUG] train episode 59: reward = -226.00, steps = 227 -355
# 15:48:48 [DEBUG] train episode 60: reward = -449.00, steps = 450 -373
# 15:49:06 [DEBUG] train episode 61: reward = -323.00, steps = 324 -384
# 15:49:24 [DEBUG] train episode 62: reward = -318.00, steps = 319 -378
# 15:49:44 [DEBUG] train episode 63: reward = -346.00, steps = 347 -363
# 15:50:11 [DEBUG] train episode 64: reward = -467.00, steps = 468 -374
# 15:50:20 [DEBUG] train episode 65: reward = -154.00, steps = 155 -354
# 15:50:36 [DEBUG] train episode 66: reward = -281.00, steps = 282 -352
# 15:51:04 [DEBUG] train episode 67: reward = -500.00, steps = 500 -356
# 15:51:33 [DEBUG] train episode 68: reward = -500.00, steps = 500 -356
# 15:51:46 [DEBUG] train episode 69: reward = -239.00, steps = 240 -357
# 15:52:14 [DEBUG] train episode 70: reward = -500.00, steps = 500 -362
# 15:52:41 [DEBUG] train episode 71: reward = -465.00, steps = 466 -377
# 15:52:57 [DEBUG] train episode 72: reward = -277.00, steps = 278 -372
# 15:53:13 [DEBUG] train episode 73: reward = -276.00, steps = 277 -365
# 15:53:25 [DEBUG] train episode 74: reward = -211.00, steps = 212 -340
# 15:53:40 [DEBUG] train episode 75: reward = -260.00, steps = 261 -350
# 15:53:55 [DEBUG] train episode 76: reward = -263.00, steps = 264 -349
# 15:54:23 [DEBUG] train episode 77: reward = -489.00, steps = 490 -348
# 15:54:40 [DEBUG] train episode 78: reward = -293.00, steps = 294 -327
# 15:54:53 [DEBUG] train episode 79: reward = -230.00, steps = 231 -326
# 15:55:14 [DEBUG] train episode 80: reward = -368.00, steps = 369 -313
# 15:55:36 [DEBUG] train episode 81: reward = -384.00, steps = 385 -305
# 15:55:49 [DEBUG] train episode 82: reward = -229.00, steps = 230 -300
# 15:56:17 [DEBUG] train episode 83: reward = -500.00, steps = 500 -322
# 15:56:28 [DEBUG] train episode 84: reward = -198.00, steps = 199 -321
# 15:56:47 [DEBUG] train episode 85: reward = -309.00, steps = 310 -326
# 15:57:15 [DEBUG] train episode 86: reward = -485.00, steps = 486 -348
# 15:57:36 [DEBUG] train episode 87: reward = -389.00, steps = 390 -338
# 15:57:51 [DEBUG] train episode 88: reward = -249.00, steps = 250 -334
# 15:58:05 [DEBUG] train episode 89: reward = -240.00, steps = 241 -335
# 15:58:21 [DEBUG] train episode 90: reward = -285.00, steps = 286 -326
# 15:58:36 [DEBUG] train episode 91: reward = -270.00, steps = 271 -315
# 15:59:01 [DEBUG] train episode 92: reward = -418.00, steps = 419 -334
# 15:59:29 [DEBUG] train episode 93: reward = -500.00, steps = 500 -334
# 15:59:47 [DEBUG] train episode 94: reward = -337.00, steps = 338 -348
# 16:00:05 [DEBUG] train episode 95: reward = -300.00, steps = 301 -347
# 16:00:23 [DEBUG] train episode 96: reward = -324.00, steps = 325 -331
# 16:00:38 [DEBUG] train episode 97: reward = -263.00, steps = 264 -318
# 16:00:57 [DEBUG] train episode 98: reward = -330.00, steps = 331 -326
# 16:01:14 [DEBUG] train episode 99: reward = -277.00, steps = 278 -330
# 16:01:23 [DEBUG] train episode 100: reward = -159.00, steps = 160 -317
# 16:01:37 [DEBUG] train episode 101: reward = -247.00, steps = 248 -315
# 16:01:49 [DEBUG] train episode 102: reward = -212.00, steps = 213 -294
# 16:01:57 [DEBUG] train episode 103: reward = -147.00, steps = 148 -259
# 16:02:09 [DEBUG] train episode 104: reward = -206.00, steps = 207 -246
# 16:02:26 [DEBUG] train episode 105: reward = -298.00, steps = 299 -246
# 16:02:39 [DEBUG] train episode 106: reward = -245.00, steps = 246 -238
# 16:02:46 [DEBUG] train episode 107: reward = -149.00, steps = 150 -227
# 16:03:05 [DEBUG] train episode 108: reward = -372.00, steps = 373 -231
# 16:03:14 [DEBUG] train episode 109: reward = -175.00, steps = 176 -221
# 16:03:27 [DEBUG] train episode 110: reward = -246.00, steps = 247 -229
# 16:03:44 [DEBUG] train episode 111: reward = -354.00, steps = 355 -240
# 16:03:58 [DEBUG] train episode 112: reward = -274.00, steps = 275 -246
# 16:04:21 [DEBUG] train episode 113: reward = -461.00, steps = 462 -278
# 16:04:30 [DEBUG] train episode 114: reward = -160.00, steps = 161 -273
# 16:04:42 [DEBUG] train episode 115: reward = -251.00, steps = 252 -268
# 16:04:56 [DEBUG] train episode 116: reward = -284.00, steps = 285 -272
# 16:05:05 [DEBUG] train episode 117: reward = -173.00, steps = 174 -275
# 16:05:19 [DEBUG] train episode 118: reward = -274.00, steps = 275 -265
# 16:05:32 [DEBUG] train episode 119: reward = -270.00, steps = 271 -274
# 16:05:42 [DEBUG] train episode 120: reward = -198.00, steps = 199 -269
# 16:05:55 [DEBUG] train episode 121: reward = -261.00, steps = 262 -260
# 16:06:05 [DEBUG] train episode 122: reward = -198.00, steps = 199 -253
# 16:06:13 [DEBUG] train episode 123: reward = -139.00, steps = 140 -220
# 16:06:24 [DEBUG] train episode 124: reward = -225.00, steps = 226 -227
# 16:06:33 [DEBUG] train episode 125: reward = -180.00, steps = 181 -220
# 16:06:40 [DEBUG] train episode 126: reward = -143.00, steps = 144 -206
# 16:07:00 [DEBUG] train episode 127: reward = -407.00, steps = 408 -229
# 16:07:11 [DEBUG] train episode 128: reward = -197.00, steps = 198 -221
# 16:07:19 [DEBUG] train episode 129: reward = -169.00, steps = 170 -211
# 16:07:33 [DEBUG] train episode 130: reward = -281.00, steps = 282 -220
# 16:07:42 [DEBUG] train episode 131: reward = -180.00, steps = 181 -211
# 16:07:56 [DEBUG] train episode 132: reward = -273.00, steps = 274 -219
# 16:08:05 [DEBUG] train episode 133: reward = -163.00, steps = 164 -221
# 16:08:16 [DEBUG] train episode 134: reward = -216.00, steps = 217 -220
# 16:08:26 [DEBUG] train episode 135: reward = -201.00, steps = 202 -223
# 16:08:33 [DEBUG] train episode 136: reward = -150.00, steps = 151 -223
# 16:08:41 [DEBUG] train episode 137: reward = -158.00, steps = 159 -198
# 16:08:51 [DEBUG] train episode 138: reward = -192.00, steps = 193 -198
# 16:09:00 [DEBUG] train episode 139: reward = -175.00, steps = 176 -198
# 16:09:11 [DEBUG] train episode 140: reward = -221.00, steps = 222 -192
# 16:09:20 [DEBUG] train episode 141: reward = -182.00, steps = 183 -193
# 16:09:28 [DEBUG] train episode 142: reward = -150.00, steps = 151 -180
# 16:09:37 [DEBUG] train episode 143: reward = -176.00, steps = 177 -182
# 16:09:48 [DEBUG] train episode 144: reward = -239.00, steps = 240 -184
# 16:10:00 [DEBUG] train episode 145: reward = -222.00, steps = 223 -186
# 16:10:12 [DEBUG] train episode 146: reward = -234.00, steps = 235 -194
# 16:10:21 [DEBUG] train episode 147: reward = -175.00, steps = 176 -196
# 16:10:31 [DEBUG] train episode 148: reward = -205.00, steps = 206 -197
# 16:10:49 [DEBUG] train episode 149: reward = -367.00, steps = 368 -217
# 16:11:07 [DEBUG] train episode 150: reward = -341.00, steps = 342 -229
# 16:11:16 [DEBUG] train episode 151: reward = -181.00, steps = 182 -229
# 16:11:25 [DEBUG] train episode 152: reward = -180.00, steps = 181 -232
# 16:11:33 [DEBUG] train episode 153: reward = -153.00, steps = 154 -229
# 16:11:42 [DEBUG] train episode 154: reward = -190.00, steps = 191 -224
# 16:11:51 [DEBUG] train episode 155: reward = -177.00, steps = 178 -220
# 16:11:58 [DEBUG] train episode 156: reward = -132.00, steps = 133 -210
# 16:12:10 [DEBUG] train episode 157: reward = -214.00, steps = 215 -214
# 16:12:16 [DEBUG] train episode 158: reward = -130.00, steps = 131 -206
# 16:12:27 [DEBUG] train episode 159: reward = -219.00, steps = 220 -191
# 16:12:35 [DEBUG] train episode 160: reward = -151.00, steps = 152 -172
# 16:12:41 [DEBUG] train episode 161: reward = -133.00, steps = 134 -167
# 16:12:52 [DEBUG] train episode 162: reward = -202.00, steps = 203 -170
# 16:13:02 [DEBUG] train episode 163: reward = -190.00, steps = 191 -173
# 16:13:13 [DEBUG] train episode 164: reward = -218.00, steps = 219 -176
# 16:13:21 [DEBUG] train episode 165: reward = -161.00, steps = 162 -175
# 16:13:28 [DEBUG] train episode 166: reward = -136.00, steps = 137 -175
# 16:13:37 [DEBUG] train episode 167: reward = -181.00, steps = 182 -172
# 16:13:52 [DEBUG] train episode 168: reward = -288.00, steps = 289 -187
# 16:14:00 [DEBUG] train episode 169: reward = -162.00, steps = 163 -182
# 16:14:09 [DEBUG] train episode 170: reward = -178.00, steps = 179 -184
# 16:14:16 [DEBUG] train episode 171: reward = -146.00, steps = 147 -186
# 16:14:28 [DEBUG] train episode 172: reward = -243.00, steps = 244 -190
# 16:14:35 [DEBUG] train episode 173: reward = -132.00, steps = 133 -184
# 16:14:45 [DEBUG] train episode 174: reward = -184.00, steps = 185 -181
# 16:14:53 [DEBUG] train episode 175: reward = -168.00, steps = 169 -181
# 16:15:00 [DEBUG] train episode 176: reward = -134.00, steps = 135 -181
# 16:15:08 [DEBUG] train episode 177: reward = -160.00, steps = 161 -179
# 16:15:19 [DEBUG] train episode 178: reward = -216.00, steps = 217 -172
# 16:15:28 [DEBUG] train episode 179: reward = -169.00, steps = 170 -173
# 16:15:39 [DEBUG] train episode 180: reward = -216.00, steps = 217 -176
# 16:15:45 [DEBUG] train episode 181: reward = -114.00, steps = 115 -173
# 16:15:58 [DEBUG] train episode 182: reward = -253.00, steps = 254 -174
# 16:16:06 [DEBUG] train episode 183: reward = -157.00, steps = 158 -177
# 16:16:15 [DEBUG] train episode 184: reward = -189.00, steps = 190 -177
# 16:16:23 [DEBUG] train episode 185: reward = -154.00, steps = 155 -176
# 16:16:34 [DEBUG] train episode 186: reward = -210.00, steps = 211 -183
# 16:16:43 [DEBUG] train episode 187: reward = -186.00, steps = 187 -186
# 16:16:51 [DEBUG] train episode 188: reward = -150.00, steps = 151 -179
# 16:17:01 [DEBUG] train episode 189: reward = -199.00, steps = 200 -182
# 16:17:14 [DEBUG] train episode 190: reward = -250.00, steps = 251 -186
# 16:17:24 [DEBUG] train episode 191: reward = -195.00, steps = 196 -194
# 16:17:33 [DEBUG] train episode 192: reward = -173.00, steps = 174 -186
# 16:17:42 [DEBUG] train episode 193: reward = -181.00, steps = 182 -188
# 16:17:49 [DEBUG] train episode 194: reward = -147.00, steps = 148 -184
# 16:17:58 [DEBUG] train episode 195: reward = -181.00, steps = 182 -187
# 16:18:05 [DEBUG] train episode 196: reward = -124.00, steps = 125 -178
# 16:18:29 [DEBUG] train episode 197: reward = -488.00, steps = 489 -208
# 16:18:40 [DEBUG] train episode 198: reward = -220.00, steps = 221 -215
# 16:18:46 [DEBUG] train episode 199: reward = -114.00, steps = 115 -207
# 16:18:59 [DEBUG] train episode 200: reward = -245.00, steps = 246 -206
# 16:19:09 [DEBUG] train episode 201: reward = -203.00, steps = 204 -207
# 16:19:16 [DEBUG] train episode 202: reward = -153.00, steps = 154 -205
# 16:19:26 [DEBUG] train episode 203: reward = -183.00, steps = 184 -205
# 16:19:35 [DEBUG] train episode 204: reward = -173.00, steps = 174 -208
# 16:19:48 [DEBUG] train episode 205: reward = -257.00, steps = 258 -216
# 16:19:58 [DEBUG] train episode 206: reward = -203.00, steps = 204 -223
# 16:20:07 [DEBUG] train episode 207: reward = -191.00, steps = 192 -194
# 16:20:22 [DEBUG] train episode 208: reward = -282.00, steps = 283 -200
# 16:20:34 [DEBUG] train episode 209: reward = -245.00, steps = 246 -213
# 16:20:43 [DEBUG] train episode 210: reward = -172.00, steps = 173 -206
# 16:20:56 [DEBUG] train episode 211: reward = -246.00, steps = 247 -210
# 16:21:03 [DEBUG] train episode 212: reward = -142.00, steps = 143 -209
# 16:21:11 [DEBUG] train episode 213: reward = -164.00, steps = 165 -207
# 16:21:20 [DEBUG] train episode 214: reward = -158.00, steps = 159 -206
# 16:21:27 [DEBUG] train episode 215: reward = -152.00, steps = 153 -195
# 16:21:39 [DEBUG] train episode 216: reward = -222.00, steps = 223 -197
# 16:21:49 [DEBUG] train episode 217: reward = -172.00, steps = 173 -195
# 16:21:58 [DEBUG] train episode 218: reward = -177.00, steps = 178 -185
# 16:22:05 [DEBUG] train episode 219: reward = -143.00, steps = 144 -174
# 16:22:18 [DEBUG] train episode 220: reward = -226.00, steps = 227 -180
# 16:22:29 [DEBUG] train episode 221: reward = -226.00, steps = 227 -178
# 16:22:35 [DEBUG] train episode 222: reward = -128.00, steps = 129 -176
# 16:22:43 [DEBUG] train episode 223: reward = -147.00, steps = 148 -175
# 16:22:51 [DEBUG] train episode 224: reward = -164.00, steps = 165 -175
# 16:23:00 [DEBUG] train episode 225: reward = -166.00, steps = 167 -177
# 16:23:14 [DEBUG] train episode 226: reward = -261.00, steps = 262 -181
# 16:23:22 [DEBUG] train episode 227: reward = -169.00, steps = 170 -180
# 16:23:27 [DEBUG] train episode 228: reward = -103.00, steps = 104 -173
# 16:23:35 [DEBUG] train episode 229: reward = -155.00, steps = 156 -174
# 16:23:42 [DEBUG] train episode 230: reward = -137.00, steps = 138 -165
# 16:23:54 [DEBUG] train episode 231: reward = -238.00, steps = 239 -166
# 16:24:02 [DEBUG] train episode 232: reward = -159.00, steps = 160 -169
# 16:24:13 [DEBUG] train episode 233: reward = -216.00, steps = 217 -176
# 16:24:21 [DEBUG] train episode 234: reward = -144.00, steps = 145 -174
# 16:24:30 [DEBUG] train episode 235: reward = -182.00, steps = 183 -176
# 16:24:44 [DEBUG] train episode 236: reward = -294.00, steps = 295 -179
# 16:24:52 [DEBUG] train episode 237: reward = -156.00, steps = 157 -178
# 16:25:05 [DEBUG] train episode 238: reward = -243.00, steps = 244 -192
# 16:25:11 [DEBUG] train episode 239: reward = -112.00, steps = 113 -188
# 16:25:22 [DEBUG] train episode 240: reward = -219.00, steps = 220 -196
# 16:25:29 [DEBUG] train episode 241: reward = -131.00, steps = 132 -185
# 16:25:37 [DEBUG] train episode 242: reward = -173.00, steps = 174 -187
# 16:25:45 [DEBUG] train episode 243: reward = -148.00, steps = 149 -180
# 16:25:51 [DEBUG] train episode 244: reward = -130.00, steps = 131 -178
# 16:26:07 [DEBUG] train episode 245: reward = -302.00, steps = 303 -190
# 16:26:15 [DEBUG] train episode 246: reward = -148.00, steps = 149 -176
# 16:26:25 [DEBUG] train episode 247: reward = -212.00, steps = 213 -181
# 16:26:32 [DEBUG] train episode 248: reward = -144.00, steps = 145 -171
# 16:26:41 [DEBUG] train episode 249: reward = -168.00, steps = 169 -177
# 16:26:49 [DEBUG] train episode 250: reward = -169.00, steps = 170 -172
# 16:27:01 [DEBUG] train episode 251: reward = -216.00, steps = 217 -181
# 16:27:10 [DEBUG] train episode 252: reward = -175.00, steps = 176 -181
# 16:27:21 [DEBUG] train episode 253: reward = -231.00, steps = 232 -189
# 16:27:29 [DEBUG] train episode 254: reward = -158.00, steps = 159 -192
# 16:27:41 [DEBUG] train episode 255: reward = -234.00, steps = 235 -185
# 16:27:48 [DEBUG] train episode 256: reward = -152.00, steps = 153 -185
# 16:27:58 [DEBUG] train episode 257: reward = -182.00, steps = 183 -182
# 16:28:06 [DEBUG] train episode 258: reward = -143.00, steps = 144 -182
# 16:28:12 [DEBUG] train episode 259: reward = -135.00, steps = 136 -179
# 16:28:22 [DEBUG] train episode 260: reward = -198.00, steps = 199 -182
# 16:28:37 [DEBUG] train episode 261: reward = -302.00, steps = 303 -191
# 16:28:49 [DEBUG] train episode 262: reward = -217.00, steps = 218 -195
# 16:29:03 [DEBUG] train episode 263: reward = -278.00, steps = 279 -199
# 16:29:08 [DEBUG] train episode 264: reward = -99.00, steps = 100 -194
# 16:29:16 [DEBUG] train episode 265: reward = -142.00, steps = 143 -184
# 16:29:22 [DEBUG] train episode 266: reward = -121.00, steps = 122 -181
# 16:29:30 [DEBUG] train episode 267: reward = -165.00, steps = 166 -180
# 16:29:42 [DEBUG] train episode 268: reward = -229.00, steps = 230 -188
# 16:29:49 [DEBUG] train episode 269: reward = -128.00, steps = 129 -187
# 16:29:54 [DEBUG] train episode 270: reward = -100.00, steps = 101 -178
# 16:30:02 [DEBUG] train episode 271: reward = -156.00, steps = 157 -163
# 16:30:10 [DEBUG] train episode 272: reward = -162.00, steps = 163 -158
# 16:30:19 [DEBUG] train episode 273: reward = -194.00, steps = 195 -149
# 16:30:29 [DEBUG] train episode 274: reward = -190.00, steps = 191 -158
# 16:30:36 [DEBUG] train episode 275: reward = -120.00, steps = 121 -156
# 16:30:54 [DEBUG] train episode 276: reward = -366.00, steps = 367 -181
# 16:31:05 [DEBUG] train episode 277: reward = -219.00, steps = 220 -186
# 16:31:21 [DEBUG] train episode 278: reward = -314.00, steps = 315 -194
# 16:31:30 [DEBUG] train episode 279: reward = -159.00, steps = 160 -198
# 16:31:37 [DEBUG] train episode 280: reward = -138.00, steps = 139 -201
# 16:31:43 [DEBUG] train episode 281: reward = -138.00, steps = 139 -200
# 16:31:50 [DEBUG] train episode 282: reward = -135.00, steps = 136 -197
# 16:31:57 [DEBUG] train episode 283: reward = -131.00, steps = 132 -191
# 16:32:07 [DEBUG] train episode 284: reward = -192.00, steps = 193 -191
# 16:32:18 [DEBUG] train episode 285: reward = -224.00, steps = 225 -201
# 16:32:25 [DEBUG] train episode 286: reward = -126.00, steps = 127 -177
# 16:32:34 [DEBUG] train episode 287: reward = -168.00, steps = 169 -172
# 16:32:46 [DEBUG] train episode 288: reward = -237.00, steps = 238 -164
# 16:32:53 [DEBUG] train episode 289: reward = -154.00, steps = 155 -164
# 16:33:00 [DEBUG] train episode 290: reward = -139.00, steps = 140 -164
# 16:33:10 [DEBUG] train episode 291: reward = -192.00, steps = 193 -169
# 16:33:18 [DEBUG] train episode 292: reward = -148.00, steps = 149 -171
# 16:33:26 [DEBUG] train episode 293: reward = -150.00, steps = 151 -173
# 16:33:35 [DEBUG] train episode 294: reward = -176.00, steps = 177 -171
# 16:33:42 [DEBUG] train episode 295: reward = -140.00, steps = 141 -163
# 16:33:48 [DEBUG] train episode 296: reward = -119.00, steps = 120 -162
# 16:33:55 [DEBUG] train episode 297: reward = -146.00, steps = 147 -160
# 16:34:01 [DEBUG] train episode 298: reward = -128.00, steps = 129 -149
# 16:34:16 [DEBUG] train episode 299: reward = -266.00, steps = 267 -160
# 16:34:24 [DEBUG] train episode 300: reward = -170.00, steps = 171 -163
# 16:34:30 [DEBUG] train episode 301: reward = -116.00, steps = 117 -155
# 16:34:36 [DEBUG] train episode 302: reward = -113.00, steps = 114 -152
# 16:34:46 [DEBUG] train episode 303: reward = -207.00, steps = 208 -158
# 16:34:53 [DEBUG] train episode 304: reward = -129.00, steps = 130 -153
# 16:35:00 [DEBUG] train episode 305: reward = -133.00, steps = 134 -152
# 16:35:08 [DEBUG] train episode 306: reward = -150.00, steps = 151 -155
# 16:35:19 [DEBUG] train episode 307: reward = -224.00, steps = 225 -163
# 16:35:25 [DEBUG] train episode 308: reward = -119.00, steps = 120 -162
# 16:35:31 [DEBUG] train episode 309: reward = -129.00, steps = 130 -149
# 16:35:40 [DEBUG] train episode 310: reward = -180.00, steps = 181 -150
# 16:35:47 [DEBUG] train episode 311: reward = -142.00, steps = 143 -152
# 16:35:54 [DEBUG] train episode 312: reward = -125.00, steps = 126 -153
# 16:36:02 [DEBUG] train episode 313: reward = -143.00, steps = 144 -147
# 16:36:09 [DEBUG] train episode 314: reward = -118.00, steps = 119 -146
# 16:36:18 [DEBUG] train episode 315: reward = -163.00, steps = 164 -149
# 16:36:26 [DEBUG] train episode 316: reward = -144.00, steps = 145 -148
# 16:36:34 [DEBUG] train episode 317: reward = -143.00, steps = 144 -140
# 16:36:43 [DEBUG] train episode 318: reward = -153.00, steps = 154 -144

# %%
env.close()
