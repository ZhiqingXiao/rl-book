# %% [markdown]
# # Use Dual DQN to Play MoutainCar-v0
#
# PyTorch version

# %%
# %matplotlib inline

import sys
import logging
import imp
import itertools
import copy

import numpy as np
np.random.seed(0)
import pandas as pd
import gym
import matplotlib.pyplot as plt
import torch
torch.manual_seed(0)
import torch.nn as nn
import torch.optim as optim

imp.reload(logging)
logging.basicConfig(level=logging.DEBUG,
        format='%(asctime)s [%(levelname)s] %(message)s',
        stream=sys.stdout, datefmt='%H:%M:%S')

# %%
env = gym.make('MountainCar-v0')
env.seed(0)
for key in vars(env):
    logging.info('%s: %s', key, vars(env)[key])
# Out:
# 12:57:29 [INFO] env: <MountainCarEnv<MountainCar-v0>>
# 12:57:29 [INFO] action_space: Discrete(3)
# 12:57:29 [INFO] observation_space: Box(-1.2000000476837158, 0.6000000238418579, (2,), float32)
# 12:57:29 [INFO] reward_range: (-inf, inf)
# 12:57:29 [INFO] metadata: {'render.modes': ['human', 'rgb_array'], 'video.frames_per_second': 30}
# 12:57:29 [INFO] _max_episode_steps: 200
# 12:57:29 [INFO] _elapsed_steps: None

# %%
class DQNReplayer:
    def __init__(self, capacity):
        self.memory = pd.DataFrame(index=range(capacity),
                columns=['state', 'action', 'reward', 'next_state', 'done'])
        self.i = 0
        self.count = 0
        self.capacity = capacity

    def store(self, *args):
        self.memory.loc[self.i] = args
        self.i = (self.i + 1) % self.capacity
        self.count = min(self.count + 1, self.capacity)

    def sample(self, size):
        indices = np.random.choice(self.count, size=size)
        return (np.stack(self.memory.loc[indices, field]) for field in
                self.memory.columns)

# %%
class DualNet(nn.Module):
    def __init__(self, input_size, output_size):
        super(DualNet, self).__init__()
        self.common_net = nn.Sequential(nn.Linear(input_size, 64), nn.ReLU())
        self.advantage_net = nn.Sequential(nn.Linear(64, 32), nn.ReLU(),
            nn.Linear(32, output_size))
        self.v_net = nn.Sequential(nn.Linear(64, 32), nn.ReLU(), nn.Linear(32, 1))

    def forward(self, s):
        h = self.common_net(s)
        adv = self.advantage_net(h)
        adv = adv - adv.mean(1).unsqueeze(1)
        v = self.v_net(h)
        q = v + adv 
        return q


class DualDQNAgent:
    def __init__(self, env):
        self.action_n = env.action_space.n
        self.gamma = 0.99

        self.replayer = DQNReplayer(10000)

        self.evaluate_net = DualNet(input_size=env.observation_space.shape[0],
                output_size=self.action_n)
        self.optimizer = optim.Adam(self.evaluate_net.parameters(), lr=0.001)
        self.loss = nn.MSELoss()

    def reset(self, mode=None):
        self.mode = mode
        if self.mode == 'train':
            self.trajectory = []
            self.target_net = copy.deepcopy(self.evaluate_net)

    def step(self, observation, reward, done):
        if self.mode == 'train' and np.random.rand() < 0.001:
            # epsilon-greedy policy in train mode
            action = np.random.randint(self.action_n)
        else:
            state_tensor = torch.as_tensor(observation,
                    dtype=torch.float).reshape(1, -1)
            q_tensor = self.evaluate_net(state_tensor)
            action_tensor = torch.argmax(q_tensor)
            action = action_tensor.item()
        if self.mode == 'train':
            self.trajectory += [observation, reward, done, action]
            if len(self.trajectory) >= 8:
                state, _, _, action, next_state, reward, done, _ = \
                        self.trajectory[-8:]
                self.replayer.store(state, action, reward, next_state, done)
            if self.replayer.count >= self.replayer.capacity * 0.95:
                    # skip first few episodes for speed
                self.learn()
        return action

    def close(self):
        pass

    def learn(self):
        # replay
        states, actions, rewards, next_states, dones = \
                self.replayer.sample(1024) # replay transitions
        state_tensor = torch.as_tensor(states, dtype=torch.float)
        action_tensor = torch.as_tensor(actions, dtype=torch.long)
        reward_tensor = torch.as_tensor(rewards, dtype=torch.float)
        next_state_tensor = torch.as_tensor(next_states, dtype=torch.float)
        done_tensor = torch.as_tensor(dones, dtype=torch.float)

        # train
        next_eval_q_tensor = self.evaluate_net(next_state_tensor)
        next_action_tensor = next_eval_q_tensor.argmax(axis=-1)
        next_q_tensor = self.target_net(next_state_tensor)
        next_max_q_tensor = torch.gather(next_q_tensor, 1,
                next_action_tensor.unsqueeze(1)).squeeze(1)
        target_tensor = reward_tensor + self.gamma * (1. - done_tensor) * \
                next_max_q_tensor
        pred_tensor = self.evaluate_net(state_tensor)
        unsqueeze_tensor = action_tensor.unsqueeze(1)
        q_tensor = pred_tensor.gather(1, action_tensor.unsqueeze(1)).squeeze(1)
        loss_tensor = self.loss(target_tensor, q_tensor)
        self.optimizer.zero_grad()
        loss_tensor.backward()
        self.optimizer.step()


agent = DualDQNAgent(env)

# %%
def play_episode(env, agent, max_episode_steps=None, mode=None, render=False):
    observation, reward, done = env.reset(), 0., False
    agent.reset(mode=mode)
    episode_reward, elapsed_steps = 0., 0
    while True:
        action = agent.step(observation, reward, done)
        if render:
            env.render()
        if done:
            break
        observation, reward, done, _ = env.step(action)
        episode_reward += reward
        elapsed_steps += 1
        if max_episode_steps and elapsed_steps >= max_episode_steps:
            break
    agent.close()
    return episode_reward, elapsed_steps


logging.info('==== train ====')
episode_rewards = []
for episode in itertools.count():
    episode_reward, elapsed_steps = play_episode(env.unwrapped, agent,
            max_episode_steps=env._max_episode_steps, mode='train')
    episode_rewards.append(episode_reward)
    logging.debug('train episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
    if np.mean(episode_rewards[-10:]) > -110:
        break
plt.plot(episode_rewards)


logging.info('==== test ====')
episode_rewards = []
for episode in range(100):
    episode_reward, elapsed_steps = play_episode(env, agent)
    episode_rewards.append(episode_reward)
    logging.debug('test episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
logging.info('average episode reward = %.2f ± %.2f',
        np.mean(episode_rewards), np.std(episode_rewards))
# Out:
# 12:57:29 [INFO] ==== train ====
# 12:57:29 [DEBUG] train episode 0: reward = -200.00, steps = 200
# 12:57:29 [DEBUG] train episode 1: reward = -200.00, steps = 200
# 12:57:29 [DEBUG] train episode 2: reward = -200.00, steps = 200
# 12:57:30 [DEBUG] train episode 3: reward = -200.00, steps = 200
# 12:57:30 [DEBUG] train episode 4: reward = -200.00, steps = 200
# 12:57:30 [DEBUG] train episode 5: reward = -200.00, steps = 200
# 12:57:30 [DEBUG] train episode 6: reward = -200.00, steps = 200
# 12:57:30 [DEBUG] train episode 7: reward = -200.00, steps = 200
# 12:57:30 [DEBUG] train episode 8: reward = -200.00, steps = 200
# 12:57:30 [DEBUG] train episode 9: reward = -200.00, steps = 200
# 12:57:31 [DEBUG] train episode 10: reward = -200.00, steps = 200
# 12:57:31 [DEBUG] train episode 11: reward = -200.00, steps = 200
# 12:57:31 [DEBUG] train episode 12: reward = -200.00, steps = 200
# 12:57:31 [DEBUG] train episode 13: reward = -200.00, steps = 200
# 12:57:31 [DEBUG] train episode 14: reward = -200.00, steps = 200
# 12:57:31 [DEBUG] train episode 15: reward = -200.00, steps = 200
# 12:57:31 [DEBUG] train episode 16: reward = -200.00, steps = 200
# 12:57:32 [DEBUG] train episode 17: reward = -200.00, steps = 200
# 12:57:32 [DEBUG] train episode 18: reward = -200.00, steps = 200
# 12:57:32 [DEBUG] train episode 19: reward = -200.00, steps = 200
# 12:57:32 [DEBUG] train episode 20: reward = -200.00, steps = 200
# 12:57:32 [DEBUG] train episode 21: reward = -200.00, steps = 200
# 12:57:32 [DEBUG] train episode 22: reward = -200.00, steps = 200
# 12:57:33 [DEBUG] train episode 23: reward = -200.00, steps = 200
# 12:57:33 [DEBUG] train episode 24: reward = -200.00, steps = 200
# 12:57:33 [DEBUG] train episode 25: reward = -200.00, steps = 200
# 12:57:33 [DEBUG] train episode 26: reward = -200.00, steps = 200
# 12:57:33 [DEBUG] train episode 27: reward = -200.00, steps = 200
# 12:57:33 [DEBUG] train episode 28: reward = -200.00, steps = 200
# 12:57:33 [DEBUG] train episode 29: reward = -200.00, steps = 200
# 12:57:34 [DEBUG] train episode 30: reward = -200.00, steps = 200
# 12:57:34 [DEBUG] train episode 31: reward = -200.00, steps = 200
# 12:57:34 [DEBUG] train episode 32: reward = -200.00, steps = 200
# 12:57:34 [DEBUG] train episode 33: reward = -200.00, steps = 200
# 12:57:34 [DEBUG] train episode 34: reward = -200.00, steps = 200
# 12:57:34 [DEBUG] train episode 35: reward = -200.00, steps = 200
# 12:57:35 [DEBUG] train episode 36: reward = -200.00, steps = 200
# 12:57:35 [DEBUG] train episode 37: reward = -200.00, steps = 200
# 12:57:35 [DEBUG] train episode 38: reward = -200.00, steps = 200
# 12:57:35 [DEBUG] train episode 39: reward = -200.00, steps = 200
# 12:57:35 [DEBUG] train episode 40: reward = -200.00, steps = 200
# 12:57:35 [DEBUG] train episode 41: reward = -200.00, steps = 200
# 12:57:36 [DEBUG] train episode 42: reward = -200.00, steps = 200
# 12:57:36 [DEBUG] train episode 43: reward = -200.00, steps = 200
# 12:57:36 [DEBUG] train episode 44: reward = -200.00, steps = 200
# 12:57:36 [DEBUG] train episode 45: reward = -200.00, steps = 200
# 12:57:36 [DEBUG] train episode 46: reward = -200.00, steps = 200
# 12:57:39 [DEBUG] train episode 47: reward = -200.00, steps = 200
# 12:57:47 [DEBUG] train episode 48: reward = -200.00, steps = 200
# 12:57:55 [DEBUG] train episode 49: reward = -200.00, steps = 200
# 12:58:02 [DEBUG] train episode 50: reward = -200.00, steps = 200
# 12:58:09 [DEBUG] train episode 51: reward = -200.00, steps = 200
# 12:58:16 [DEBUG] train episode 52: reward = -200.00, steps = 200
# 12:58:23 [DEBUG] train episode 53: reward = -200.00, steps = 200
# 12:58:30 [DEBUG] train episode 54: reward = -200.00, steps = 200
# 12:58:37 [DEBUG] train episode 55: reward = -200.00, steps = 200
# 12:58:44 [DEBUG] train episode 56: reward = -200.00, steps = 200
# 12:58:51 [DEBUG] train episode 57: reward = -200.00, steps = 200
# 12:58:58 [DEBUG] train episode 58: reward = -200.00, steps = 200
# 12:59:05 [DEBUG] train episode 59: reward = -200.00, steps = 200
# 12:59:12 [DEBUG] train episode 60: reward = -200.00, steps = 200
# 12:59:19 [DEBUG] train episode 61: reward = -200.00, steps = 200
# 12:59:26 [DEBUG] train episode 62: reward = -200.00, steps = 200
# 12:59:34 [DEBUG] train episode 63: reward = -200.00, steps = 200
# 12:59:40 [DEBUG] train episode 64: reward = -200.00, steps = 200
# 12:59:48 [DEBUG] train episode 65: reward = -200.00, steps = 200
# 12:59:55 [DEBUG] train episode 66: reward = -200.00, steps = 200
# 13:00:02 [DEBUG] train episode 67: reward = -200.00, steps = 200
# 13:00:09 [DEBUG] train episode 68: reward = -200.00, steps = 200
# 13:00:16 [DEBUG] train episode 69: reward = -200.00, steps = 200
# 13:00:23 [DEBUG] train episode 70: reward = -200.00, steps = 200
# 13:00:30 [DEBUG] train episode 71: reward = -200.00, steps = 200
# 13:00:37 [DEBUG] train episode 72: reward = -200.00, steps = 200
# 13:00:44 [DEBUG] train episode 73: reward = -200.00, steps = 200
# 13:00:51 [DEBUG] train episode 74: reward = -200.00, steps = 200
# 13:00:58 [DEBUG] train episode 75: reward = -200.00, steps = 200
# 13:01:05 [DEBUG] train episode 76: reward = -200.00, steps = 200
# 13:01:12 [DEBUG] train episode 77: reward = -200.00, steps = 200
# 13:01:19 [DEBUG] train episode 78: reward = -200.00, steps = 200
# 13:01:26 [DEBUG] train episode 79: reward = -200.00, steps = 200
# 13:01:32 [DEBUG] train episode 80: reward = -200.00, steps = 200
# 13:01:39 [DEBUG] train episode 81: reward = -200.00, steps = 200
# 13:01:47 [DEBUG] train episode 82: reward = -200.00, steps = 200
# 13:01:54 [DEBUG] train episode 83: reward = -200.00, steps = 200
# 13:02:01 [DEBUG] train episode 84: reward = -200.00, steps = 200
# 13:02:08 [DEBUG] train episode 85: reward = -200.00, steps = 200
# 13:02:15 [DEBUG] train episode 86: reward = -200.00, steps = 200
# 13:02:22 [DEBUG] train episode 87: reward = -200.00, steps = 200
# 13:02:29 [DEBUG] train episode 88: reward = -200.00, steps = 200
# 13:02:36 [DEBUG] train episode 89: reward = -200.00, steps = 200
# 13:02:43 [DEBUG] train episode 90: reward = -200.00, steps = 200
# 13:02:50 [DEBUG] train episode 91: reward = -200.00, steps = 200
# 13:02:57 [DEBUG] train episode 92: reward = -200.00, steps = 200
# 13:03:04 [DEBUG] train episode 93: reward = -200.00, steps = 200
# 13:03:11 [DEBUG] train episode 94: reward = -200.00, steps = 200
# 13:03:18 [DEBUG] train episode 95: reward = -200.00, steps = 200
# 13:03:25 [DEBUG] train episode 96: reward = -200.00, steps = 200
# 13:03:33 [DEBUG] train episode 97: reward = -200.00, steps = 200
# 13:03:39 [DEBUG] train episode 98: reward = -200.00, steps = 200
# 13:03:47 [DEBUG] train episode 99: reward = -200.00, steps = 200
# 13:03:54 [DEBUG] train episode 100: reward = -200.00, steps = 200
# 13:04:01 [DEBUG] train episode 101: reward = -200.00, steps = 200
# 13:04:08 [DEBUG] train episode 102: reward = -200.00, steps = 200
# 13:04:15 [DEBUG] train episode 103: reward = -200.00, steps = 200
# 13:04:23 [DEBUG] train episode 104: reward = -200.00, steps = 200
# 13:04:30 [DEBUG] train episode 105: reward = -200.00, steps = 200
# 13:04:38 [DEBUG] train episode 106: reward = -200.00, steps = 200
# 13:04:45 [DEBUG] train episode 107: reward = -200.00, steps = 200
# 13:04:52 [DEBUG] train episode 108: reward = -200.00, steps = 200
# 13:04:59 [DEBUG] train episode 109: reward = -200.00, steps = 200
# 13:05:06 [DEBUG] train episode 110: reward = -200.00, steps = 200
# 13:05:13 [DEBUG] train episode 111: reward = -200.00, steps = 200
# 13:05:20 [DEBUG] train episode 112: reward = -200.00, steps = 200
# 13:05:27 [DEBUG] train episode 113: reward = -200.00, steps = 200
# 13:05:34 [DEBUG] train episode 114: reward = -200.00, steps = 200
# 13:05:42 [DEBUG] train episode 115: reward = -200.00, steps = 200
# 13:05:49 [DEBUG] train episode 116: reward = -200.00, steps = 200
# 13:05:56 [DEBUG] train episode 117: reward = -200.00, steps = 200
# 13:06:03 [DEBUG] train episode 118: reward = -200.00, steps = 200
# 13:06:10 [DEBUG] train episode 119: reward = -200.00, steps = 200
# 13:06:17 [DEBUG] train episode 120: reward = -200.00, steps = 200
# 13:06:24 [DEBUG] train episode 121: reward = -200.00, steps = 200
# 13:06:32 [DEBUG] train episode 122: reward = -200.00, steps = 200
# 13:06:39 [DEBUG] train episode 123: reward = -200.00, steps = 200
# 13:06:46 [DEBUG] train episode 124: reward = -200.00, steps = 200
# 13:06:53 [DEBUG] train episode 125: reward = -200.00, steps = 200
# 13:07:00 [DEBUG] train episode 126: reward = -200.00, steps = 200
# 13:07:07 [DEBUG] train episode 127: reward = -200.00, steps = 200
# 13:07:14 [DEBUG] train episode 128: reward = -200.00, steps = 200
# 13:07:21 [DEBUG] train episode 129: reward = -200.00, steps = 200
# 13:07:28 [DEBUG] train episode 130: reward = -200.00, steps = 200
# 13:07:35 [DEBUG] train episode 131: reward = -200.00, steps = 200
# 13:07:42 [DEBUG] train episode 132: reward = -200.00, steps = 200
# 13:07:49 [DEBUG] train episode 133: reward = -200.00, steps = 200
# 13:07:56 [DEBUG] train episode 134: reward = -200.00, steps = 200
# 13:08:03 [DEBUG] train episode 135: reward = -200.00, steps = 200
# 13:08:10 [DEBUG] train episode 136: reward = -200.00, steps = 200
# 13:08:17 [DEBUG] train episode 137: reward = -200.00, steps = 200
# 13:08:25 [DEBUG] train episode 138: reward = -200.00, steps = 200
# 13:08:32 [DEBUG] train episode 139: reward = -200.00, steps = 200
# 13:08:39 [DEBUG] train episode 140: reward = -200.00, steps = 200
# 13:08:46 [DEBUG] train episode 141: reward = -200.00, steps = 200
# 13:08:53 [DEBUG] train episode 142: reward = -200.00, steps = 200
# 13:09:00 [DEBUG] train episode 143: reward = -200.00, steps = 200
# 13:09:08 [DEBUG] train episode 144: reward = -200.00, steps = 200
# 13:09:15 [DEBUG] train episode 145: reward = -200.00, steps = 200
# 13:09:22 [DEBUG] train episode 146: reward = -200.00, steps = 200
# 13:09:29 [DEBUG] train episode 147: reward = -200.00, steps = 200
# 13:09:36 [DEBUG] train episode 148: reward = -200.00, steps = 200
# 13:09:43 [DEBUG] train episode 149: reward = -200.00, steps = 200
# 13:09:50 [DEBUG] train episode 150: reward = -200.00, steps = 200
# 13:09:57 [DEBUG] train episode 151: reward = -200.00, steps = 200
# 13:10:04 [DEBUG] train episode 152: reward = -200.00, steps = 200
# 13:10:11 [DEBUG] train episode 153: reward = -200.00, steps = 200
# 13:10:18 [DEBUG] train episode 154: reward = -200.00, steps = 200
# 13:10:25 [DEBUG] train episode 155: reward = -200.00, steps = 200
# 13:10:32 [DEBUG] train episode 156: reward = -200.00, steps = 200
# 13:10:39 [DEBUG] train episode 157: reward = -200.00, steps = 200
# 13:10:46 [DEBUG] train episode 158: reward = -200.00, steps = 200
# 13:10:54 [DEBUG] train episode 159: reward = -200.00, steps = 200
# 13:11:01 [DEBUG] train episode 160: reward = -200.00, steps = 200
# 13:11:08 [DEBUG] train episode 161: reward = -200.00, steps = 200
# 13:11:15 [DEBUG] train episode 162: reward = -200.00, steps = 200
# 13:11:22 [DEBUG] train episode 163: reward = -200.00, steps = 200
# 13:11:29 [DEBUG] train episode 164: reward = -200.00, steps = 200
# 13:11:36 [DEBUG] train episode 165: reward = -200.00, steps = 200
# 13:11:43 [DEBUG] train episode 166: reward = -200.00, steps = 200
# 13:11:50 [DEBUG] train episode 167: reward = -200.00, steps = 200
# 13:11:57 [DEBUG] train episode 168: reward = -200.00, steps = 200
# 13:12:04 [DEBUG] train episode 169: reward = -200.00, steps = 200
# 13:12:11 [DEBUG] train episode 170: reward = -200.00, steps = 200
# 13:12:18 [DEBUG] train episode 171: reward = -200.00, steps = 200
# 13:12:25 [DEBUG] train episode 172: reward = -200.00, steps = 200
# 13:12:32 [DEBUG] train episode 173: reward = -200.00, steps = 200
# 13:12:39 [DEBUG] train episode 174: reward = -200.00, steps = 200
# 13:12:46 [DEBUG] train episode 175: reward = -200.00, steps = 200
# 13:12:54 [DEBUG] train episode 176: reward = -200.00, steps = 200
# 13:13:01 [DEBUG] train episode 177: reward = -200.00, steps = 200
# 13:13:08 [DEBUG] train episode 178: reward = -200.00, steps = 200
# 13:13:15 [DEBUG] train episode 179: reward = -200.00, steps = 200
# 13:13:22 [DEBUG] train episode 180: reward = -200.00, steps = 200
# 13:13:29 [DEBUG] train episode 181: reward = -200.00, steps = 200
# 13:13:36 [DEBUG] train episode 182: reward = -200.00, steps = 200
# 13:13:44 [DEBUG] train episode 183: reward = -200.00, steps = 200
# 13:13:51 [DEBUG] train episode 184: reward = -200.00, steps = 200
# 13:13:58 [DEBUG] train episode 185: reward = -200.00, steps = 200
# 13:14:05 [DEBUG] train episode 186: reward = -200.00, steps = 200
# 13:14:12 [DEBUG] train episode 187: reward = -200.00, steps = 200
# 13:14:19 [DEBUG] train episode 188: reward = -200.00, steps = 200
# 13:14:26 [DEBUG] train episode 189: reward = -200.00, steps = 200
# 13:14:33 [DEBUG] train episode 190: reward = -200.00, steps = 200
# 13:14:40 [DEBUG] train episode 191: reward = -200.00, steps = 200
# 13:14:47 [DEBUG] train episode 192: reward = -200.00, steps = 200
# 13:14:54 [DEBUG] train episode 193: reward = -200.00, steps = 200
# 13:15:01 [DEBUG] train episode 194: reward = -200.00, steps = 200
# 13:15:08 [DEBUG] train episode 195: reward = -200.00, steps = 200
# 13:15:15 [DEBUG] train episode 196: reward = -200.00, steps = 200
# 13:15:22 [DEBUG] train episode 197: reward = -200.00, steps = 200
# 13:15:29 [DEBUG] train episode 198: reward = -200.00, steps = 200
# 13:15:36 [DEBUG] train episode 199: reward = -200.00, steps = 200
# 13:15:43 [DEBUG] train episode 200: reward = -200.00, steps = 200
# 13:15:50 [DEBUG] train episode 201: reward = -200.00, steps = 200
# 13:15:57 [DEBUG] train episode 202: reward = -200.00, steps = 200
# 13:16:04 [DEBUG] train episode 203: reward = -200.00, steps = 200
# 13:16:11 [DEBUG] train episode 204: reward = -200.00, steps = 200
# 13:16:18 [DEBUG] train episode 205: reward = -200.00, steps = 200
# 13:16:26 [DEBUG] train episode 206: reward = -200.00, steps = 200
# 13:16:33 [DEBUG] train episode 207: reward = -200.00, steps = 200
# 13:16:40 [DEBUG] train episode 208: reward = -200.00, steps = 200
# 13:16:47 [DEBUG] train episode 209: reward = -200.00, steps = 200
# 13:16:54 [DEBUG] train episode 210: reward = -200.00, steps = 200
# 13:17:02 [DEBUG] train episode 211: reward = -200.00, steps = 200
# 13:17:10 [DEBUG] train episode 212: reward = -200.00, steps = 200
# 13:17:17 [DEBUG] train episode 213: reward = -200.00, steps = 200
# 13:17:24 [DEBUG] train episode 214: reward = -200.00, steps = 200
# 13:17:32 [DEBUG] train episode 215: reward = -200.00, steps = 200
# 13:17:39 [DEBUG] train episode 216: reward = -200.00, steps = 200
# 13:17:46 [DEBUG] train episode 217: reward = -200.00, steps = 200
# 13:17:54 [DEBUG] train episode 218: reward = -200.00, steps = 200
# 13:18:01 [DEBUG] train episode 219: reward = -200.00, steps = 200
# 13:18:08 [DEBUG] train episode 220: reward = -200.00, steps = 200
# 13:18:15 [DEBUG] train episode 221: reward = -200.00, steps = 200
# 13:18:22 [DEBUG] train episode 222: reward = -200.00, steps = 200
# 13:18:29 [DEBUG] train episode 223: reward = -200.00, steps = 200
# 13:18:36 [DEBUG] train episode 224: reward = -200.00, steps = 200
# 13:18:43 [DEBUG] train episode 225: reward = -200.00, steps = 200
# 13:18:50 [DEBUG] train episode 226: reward = -200.00, steps = 200
# 13:18:57 [DEBUG] train episode 227: reward = -200.00, steps = 200
# 13:19:04 [DEBUG] train episode 228: reward = -200.00, steps = 200
# 13:19:11 [DEBUG] train episode 229: reward = -200.00, steps = 200
# 13:19:18 [DEBUG] train episode 230: reward = -200.00, steps = 200
# 13:19:25 [DEBUG] train episode 231: reward = -200.00, steps = 200
# 13:19:33 [DEBUG] train episode 232: reward = -200.00, steps = 200
# 13:19:40 [DEBUG] train episode 233: reward = -200.00, steps = 200
# 13:19:47 [DEBUG] train episode 234: reward = -200.00, steps = 200
# 13:19:54 [DEBUG] train episode 235: reward = -200.00, steps = 200
# 13:20:01 [DEBUG] train episode 236: reward = -200.00, steps = 200
# 13:20:08 [DEBUG] train episode 237: reward = -200.00, steps = 200
# 13:20:15 [DEBUG] train episode 238: reward = -200.00, steps = 200
# 13:20:22 [DEBUG] train episode 239: reward = -200.00, steps = 200
# 13:20:29 [DEBUG] train episode 240: reward = -200.00, steps = 200
# 13:20:36 [DEBUG] train episode 241: reward = -200.00, steps = 200
# 13:20:44 [DEBUG] train episode 242: reward = -200.00, steps = 200
# 13:20:52 [DEBUG] train episode 243: reward = -200.00, steps = 200
# 13:21:00 [DEBUG] train episode 244: reward = -200.00, steps = 200
# 13:21:07 [DEBUG] train episode 245: reward = -200.00, steps = 200
# 13:21:14 [DEBUG] train episode 246: reward = -200.00, steps = 200
# 13:21:21 [DEBUG] train episode 247: reward = -200.00, steps = 200
# 13:21:28 [DEBUG] train episode 248: reward = -200.00, steps = 200
# 13:21:35 [DEBUG] train episode 249: reward = -200.00, steps = 200
# 13:21:42 [DEBUG] train episode 250: reward = -200.00, steps = 200
# 13:21:49 [DEBUG] train episode 251: reward = -200.00, steps = 200
# 13:21:57 [DEBUG] train episode 252: reward = -200.00, steps = 200
# 13:22:04 [DEBUG] train episode 253: reward = -200.00, steps = 200
# 13:22:11 [DEBUG] train episode 254: reward = -200.00, steps = 200
# 13:22:18 [DEBUG] train episode 255: reward = -200.00, steps = 200
# 13:22:25 [DEBUG] train episode 256: reward = -200.00, steps = 200
# 13:22:32 [DEBUG] train episode 257: reward = -200.00, steps = 200
# 13:22:39 [DEBUG] train episode 258: reward = -200.00, steps = 200
# 13:22:47 [DEBUG] train episode 259: reward = -200.00, steps = 200
# 13:22:54 [DEBUG] train episode 260: reward = -200.00, steps = 200
# 13:23:01 [DEBUG] train episode 261: reward = -200.00, steps = 200
# 13:23:08 [DEBUG] train episode 262: reward = -200.00, steps = 200
# 13:23:15 [DEBUG] train episode 263: reward = -200.00, steps = 200
# 13:23:22 [DEBUG] train episode 264: reward = -200.00, steps = 200
# 13:23:29 [DEBUG] train episode 265: reward = -200.00, steps = 200
# 13:23:36 [DEBUG] train episode 266: reward = -200.00, steps = 200
# 13:23:43 [DEBUG] train episode 267: reward = -200.00, steps = 200
# 13:23:50 [DEBUG] train episode 268: reward = -200.00, steps = 200
# 13:23:57 [DEBUG] train episode 269: reward = -200.00, steps = 200
# 13:24:04 [DEBUG] train episode 270: reward = -200.00, steps = 200
# 13:24:11 [DEBUG] train episode 271: reward = -200.00, steps = 200
# 13:24:18 [DEBUG] train episode 272: reward = -200.00, steps = 200
# 13:24:25 [DEBUG] train episode 273: reward = -200.00, steps = 200
# 13:24:32 [DEBUG] train episode 274: reward = -200.00, steps = 200
# 13:24:39 [DEBUG] train episode 275: reward = -200.00, steps = 200
# 13:24:46 [DEBUG] train episode 276: reward = -200.00, steps = 200
# 13:24:53 [DEBUG] train episode 277: reward = -200.00, steps = 200
# 13:25:00 [DEBUG] train episode 278: reward = -200.00, steps = 200
# 13:25:07 [DEBUG] train episode 279: reward = -200.00, steps = 200
# 13:25:14 [DEBUG] train episode 280: reward = -200.00, steps = 200
# 13:25:21 [DEBUG] train episode 281: reward = -200.00, steps = 200
# 13:25:28 [DEBUG] train episode 282: reward = -200.00, steps = 200
# 13:25:35 [DEBUG] train episode 283: reward = -200.00, steps = 200
# 13:25:42 [DEBUG] train episode 284: reward = -200.00, steps = 200
# 13:25:50 [DEBUG] train episode 285: reward = -200.00, steps = 200
# 13:25:57 [DEBUG] train episode 286: reward = -200.00, steps = 200
# 13:26:04 [DEBUG] train episode 287: reward = -200.00, steps = 200
# 13:26:11 [DEBUG] train episode 288: reward = -200.00, steps = 200
# 13:26:18 [DEBUG] train episode 289: reward = -200.00, steps = 200
# 13:26:25 [DEBUG] train episode 290: reward = -200.00, steps = 200
# 13:26:32 [DEBUG] train episode 291: reward = -200.00, steps = 200
# 13:26:39 [DEBUG] train episode 292: reward = -200.00, steps = 200
# 13:26:46 [DEBUG] train episode 293: reward = -200.00, steps = 200
# 13:26:53 [DEBUG] train episode 294: reward = -200.00, steps = 200
# 13:27:00 [DEBUG] train episode 295: reward = -200.00, steps = 200
# 13:27:07 [DEBUG] train episode 296: reward = -200.00, steps = 200
# 13:27:14 [DEBUG] train episode 297: reward = -200.00, steps = 200
# 13:27:21 [DEBUG] train episode 298: reward = -200.00, steps = 200
# 13:27:29 [DEBUG] train episode 299: reward = -200.00, steps = 200
# 13:27:36 [DEBUG] train episode 300: reward = -200.00, steps = 200
# 13:27:43 [DEBUG] train episode 301: reward = -200.00, steps = 200
# 13:27:50 [DEBUG] train episode 302: reward = -200.00, steps = 200
# 13:27:57 [DEBUG] train episode 303: reward = -200.00, steps = 200
# 13:28:04 [DEBUG] train episode 304: reward = -200.00, steps = 200
# 13:28:11 [DEBUG] train episode 305: reward = -200.00, steps = 200
# 13:28:18 [DEBUG] train episode 306: reward = -200.00, steps = 200
# 13:28:25 [DEBUG] train episode 307: reward = -200.00, steps = 200
# 13:28:32 [DEBUG] train episode 308: reward = -200.00, steps = 200
# 13:28:39 [DEBUG] train episode 309: reward = -200.00, steps = 200
# 13:28:46 [DEBUG] train episode 310: reward = -200.00, steps = 200
# 13:28:53 [DEBUG] train episode 311: reward = -200.00, steps = 200
# 13:29:00 [DEBUG] train episode 312: reward = -200.00, steps = 200
# 13:29:07 [DEBUG] train episode 313: reward = -200.00, steps = 200
# 13:29:15 [DEBUG] train episode 314: reward = -200.00, steps = 200
# 13:29:21 [DEBUG] train episode 315: reward = -200.00, steps = 200
# 13:29:29 [DEBUG] train episode 316: reward = -200.00, steps = 200
# 13:29:35 [DEBUG] train episode 317: reward = -200.00, steps = 200
# 13:29:43 [DEBUG] train episode 318: reward = -200.00, steps = 200
# 13:29:50 [DEBUG] train episode 319: reward = -200.00, steps = 200
# 13:29:57 [DEBUG] train episode 320: reward = -200.00, steps = 200
# 13:30:04 [DEBUG] train episode 321: reward = -200.00, steps = 200
# 13:30:11 [DEBUG] train episode 322: reward = -200.00, steps = 200
# 13:30:18 [DEBUG] train episode 323: reward = -200.00, steps = 200
# 13:30:25 [DEBUG] train episode 324: reward = -200.00, steps = 200
# 13:30:32 [DEBUG] train episode 325: reward = -200.00, steps = 200
# 13:30:39 [DEBUG] train episode 326: reward = -200.00, steps = 200
# 13:30:46 [DEBUG] train episode 327: reward = -200.00, steps = 200
# 13:30:53 [DEBUG] train episode 328: reward = -200.00, steps = 200
# 13:31:00 [DEBUG] train episode 329: reward = -200.00, steps = 200
# 13:31:07 [DEBUG] train episode 330: reward = -200.00, steps = 200
# 13:31:14 [DEBUG] train episode 331: reward = -200.00, steps = 200
# 13:31:21 [DEBUG] train episode 332: reward = -200.00, steps = 200
# 13:31:28 [DEBUG] train episode 333: reward = -200.00, steps = 200
# 13:31:35 [DEBUG] train episode 334: reward = -200.00, steps = 200
# 13:31:42 [DEBUG] train episode 335: reward = -200.00, steps = 200
# 13:31:50 [DEBUG] train episode 336: reward = -200.00, steps = 200
# 13:31:57 [DEBUG] train episode 337: reward = -200.00, steps = 200
# 13:32:04 [DEBUG] train episode 338: reward = -200.00, steps = 200
# 13:32:11 [DEBUG] train episode 339: reward = -200.00, steps = 200
# 13:32:18 [DEBUG] train episode 340: reward = -200.00, steps = 200
# 13:32:25 [DEBUG] train episode 341: reward = -200.00, steps = 200
# 13:32:32 [DEBUG] train episode 342: reward = -200.00, steps = 200
# 13:32:39 [DEBUG] train episode 343: reward = -200.00, steps = 200
# 13:32:46 [DEBUG] train episode 344: reward = -200.00, steps = 200
# 13:32:53 [DEBUG] train episode 345: reward = -200.00, steps = 200
# 13:33:00 [DEBUG] train episode 346: reward = -200.00, steps = 200
# 13:33:07 [DEBUG] train episode 347: reward = -200.00, steps = 200
# 13:33:14 [DEBUG] train episode 348: reward = -200.00, steps = 200
# 13:33:21 [DEBUG] train episode 349: reward = -200.00, steps = 200
# 13:33:28 [DEBUG] train episode 350: reward = -200.00, steps = 200
# 13:33:35 [DEBUG] train episode 351: reward = -200.00, steps = 200
# 13:33:42 [DEBUG] train episode 352: reward = -200.00, steps = 200
# 13:33:49 [DEBUG] train episode 353: reward = -200.00, steps = 200
# 13:33:56 [DEBUG] train episode 354: reward = -200.00, steps = 200
# 13:34:03 [DEBUG] train episode 355: reward = -200.00, steps = 200
# 13:34:10 [DEBUG] train episode 356: reward = -200.00, steps = 200
# 13:34:17 [DEBUG] train episode 357: reward = -200.00, steps = 200
# 13:34:24 [DEBUG] train episode 358: reward = -200.00, steps = 200
# 13:34:31 [DEBUG] train episode 359: reward = -200.00, steps = 200
# 13:34:38 [DEBUG] train episode 360: reward = -200.00, steps = 200
# 13:34:46 [DEBUG] train episode 361: reward = -200.00, steps = 200
# 13:34:53 [DEBUG] train episode 362: reward = -200.00, steps = 200
# 13:35:00 [DEBUG] train episode 363: reward = -198.00, steps = 198
# 13:35:07 [DEBUG] train episode 364: reward = -200.00, steps = 200
# 13:35:14 [DEBUG] train episode 365: reward = -200.00, steps = 200
# 13:35:21 [DEBUG] train episode 366: reward = -200.00, steps = 200
# 13:35:28 [DEBUG] train episode 367: reward = -200.00, steps = 200
# 13:35:35 [DEBUG] train episode 368: reward = -200.00, steps = 200
# 13:35:40 [DEBUG] train episode 369: reward = -138.00, steps = 138
# 13:35:47 [DEBUG] train episode 370: reward = -200.00, steps = 200
# 13:35:54 [DEBUG] train episode 371: reward = -200.00, steps = 200
# 13:36:01 [DEBUG] train episode 372: reward = -200.00, steps = 200
# 13:36:08 [DEBUG] train episode 373: reward = -200.00, steps = 200
# 13:36:15 [DEBUG] train episode 374: reward = -200.00, steps = 200
# 13:36:22 [DEBUG] train episode 375: reward = -200.00, steps = 200
# 13:36:30 [DEBUG] train episode 376: reward = -200.00, steps = 200
# 13:36:37 [DEBUG] train episode 377: reward = -200.00, steps = 200
# 13:36:44 [DEBUG] train episode 378: reward = -200.00, steps = 200
# 13:36:51 [DEBUG] train episode 379: reward = -200.00, steps = 200
# 13:36:58 [DEBUG] train episode 380: reward = -200.00, steps = 200
# 13:37:05 [DEBUG] train episode 381: reward = -200.00, steps = 200
# 13:37:12 [DEBUG] train episode 382: reward = -200.00, steps = 200
# 13:37:19 [DEBUG] train episode 383: reward = -200.00, steps = 200
# 13:37:26 [DEBUG] train episode 384: reward = -200.00, steps = 200
# 13:37:33 [DEBUG] train episode 385: reward = -200.00, steps = 200
# 13:37:40 [DEBUG] train episode 386: reward = -200.00, steps = 200
# 13:37:47 [DEBUG] train episode 387: reward = -200.00, steps = 200
# 13:37:54 [DEBUG] train episode 388: reward = -200.00, steps = 200
# 13:38:02 [DEBUG] train episode 389: reward = -200.00, steps = 200
# 13:38:09 [DEBUG] train episode 390: reward = -200.00, steps = 200
# 13:38:16 [DEBUG] train episode 391: reward = -200.00, steps = 200
# 13:38:23 [DEBUG] train episode 392: reward = -200.00, steps = 200
# 13:38:30 [DEBUG] train episode 393: reward = -200.00, steps = 200
# 13:38:37 [DEBUG] train episode 394: reward = -200.00, steps = 200
# 13:38:44 [DEBUG] train episode 395: reward = -200.00, steps = 200
# 13:38:51 [DEBUG] train episode 396: reward = -200.00, steps = 200
# 13:38:58 [DEBUG] train episode 397: reward = -200.00, steps = 200
# 13:39:05 [DEBUG] train episode 398: reward = -200.00, steps = 200
# 13:39:12 [DEBUG] train episode 399: reward = -200.00, steps = 200
# 13:39:19 [DEBUG] train episode 400: reward = -200.00, steps = 200
# 13:39:26 [DEBUG] train episode 401: reward = -200.00, steps = 200
# 13:39:34 [DEBUG] train episode 402: reward = -200.00, steps = 200
# 13:39:41 [DEBUG] train episode 403: reward = -200.00, steps = 200
# 13:39:48 [DEBUG] train episode 404: reward = -200.00, steps = 200
# 13:39:55 [DEBUG] train episode 405: reward = -200.00, steps = 200
# 13:40:02 [DEBUG] train episode 406: reward = -200.00, steps = 200
# 13:40:09 [DEBUG] train episode 407: reward = -200.00, steps = 200
# 13:40:16 [DEBUG] train episode 408: reward = -200.00, steps = 200
# 13:40:23 [DEBUG] train episode 409: reward = -200.00, steps = 200
# 13:40:31 [DEBUG] train episode 410: reward = -200.00, steps = 200
# 13:40:38 [DEBUG] train episode 411: reward = -200.00, steps = 200
# 13:40:45 [DEBUG] train episode 412: reward = -200.00, steps = 200
# 13:40:52 [DEBUG] train episode 413: reward = -200.00, steps = 200
# 13:40:59 [DEBUG] train episode 414: reward = -200.00, steps = 200
# 13:41:06 [DEBUG] train episode 415: reward = -200.00, steps = 200
# 13:41:13 [DEBUG] train episode 416: reward = -200.00, steps = 200
# 13:41:20 [DEBUG] train episode 417: reward = -200.00, steps = 200
# 13:41:27 [DEBUG] train episode 418: reward = -200.00, steps = 200
# 13:41:34 [DEBUG] train episode 419: reward = -200.00, steps = 200
# 13:41:41 [DEBUG] train episode 420: reward = -200.00, steps = 200
# 13:41:49 [DEBUG] train episode 421: reward = -200.00, steps = 200
# 13:41:56 [DEBUG] train episode 422: reward = -200.00, steps = 200
# 13:42:03 [DEBUG] train episode 423: reward = -200.00, steps = 200
# 13:42:10 [DEBUG] train episode 424: reward = -200.00, steps = 200
# 13:42:16 [DEBUG] train episode 425: reward = -155.00, steps = 155
# 13:42:21 [DEBUG] train episode 426: reward = -145.00, steps = 145
# 13:42:28 [DEBUG] train episode 427: reward = -200.00, steps = 200
# 13:42:35 [DEBUG] train episode 428: reward = -200.00, steps = 200
# 13:42:40 [DEBUG] train episode 429: reward = -140.00, steps = 140
# 13:42:45 [DEBUG] train episode 430: reward = -128.00, steps = 128
# 13:42:49 [DEBUG] train episode 431: reward = -120.00, steps = 120
# 13:42:54 [DEBUG] train episode 432: reward = -119.00, steps = 119
# 13:42:57 [DEBUG] train episode 433: reward = -94.00, steps = 94
# 13:43:04 [DEBUG] train episode 434: reward = -200.00, steps = 200
# 13:43:11 [DEBUG] train episode 435: reward = -200.00, steps = 200
# 13:43:18 [DEBUG] train episode 436: reward = -200.00, steps = 200
# 13:43:24 [DEBUG] train episode 437: reward = -163.00, steps = 163
# 13:43:28 [DEBUG] train episode 438: reward = -100.00, steps = 100
# 13:43:35 [DEBUG] train episode 439: reward = -200.00, steps = 200
# 13:43:40 [DEBUG] train episode 440: reward = -157.00, steps = 157
# 13:43:46 [DEBUG] train episode 441: reward = -153.00, steps = 153
# 13:43:51 [DEBUG] train episode 442: reward = -153.00, steps = 153
# 13:43:57 [DEBUG] train episode 443: reward = -150.00, steps = 150
# 13:44:02 [DEBUG] train episode 444: reward = -159.00, steps = 159
# 13:44:06 [DEBUG] train episode 445: reward = -91.00, steps = 91
# 13:44:11 [DEBUG] train episode 446: reward = -147.00, steps = 147
# 13:44:16 [DEBUG] train episode 447: reward = -146.00, steps = 146
# 13:44:19 [DEBUG] train episode 448: reward = -87.00, steps = 87
# 13:44:25 [DEBUG] train episode 449: reward = -146.00, steps = 146
# 13:44:30 [DEBUG] train episode 450: reward = -145.00, steps = 145
# 13:44:35 [DEBUG] train episode 451: reward = -148.00, steps = 148
# 13:44:39 [DEBUG] train episode 452: reward = -108.00, steps = 108
# 13:44:44 [DEBUG] train episode 453: reward = -147.00, steps = 147
# 13:44:50 [DEBUG] train episode 454: reward = -164.00, steps = 164
# 13:44:55 [DEBUG] train episode 455: reward = -148.00, steps = 148
# 13:45:01 [DEBUG] train episode 456: reward = -171.00, steps = 171
# 13:45:07 [DEBUG] train episode 457: reward = -153.00, steps = 153
# 13:45:13 [DEBUG] train episode 458: reward = -163.00, steps = 163
# 13:45:18 [DEBUG] train episode 459: reward = -143.00, steps = 143
# 13:45:21 [DEBUG] train episode 460: reward = -94.00, steps = 94
# 13:45:24 [DEBUG] train episode 461: reward = -89.00, steps = 89
# 13:45:30 [DEBUG] train episode 462: reward = -168.00, steps = 168
# 13:45:36 [DEBUG] train episode 463: reward = -143.00, steps = 143
# 13:45:41 [DEBUG] train episode 464: reward = -142.00, steps = 142
# 13:45:46 [DEBUG] train episode 465: reward = -143.00, steps = 143
# 13:45:51 [DEBUG] train episode 466: reward = -149.00, steps = 149
# 13:45:56 [DEBUG] train episode 467: reward = -145.00, steps = 145
# 13:46:02 [DEBUG] train episode 468: reward = -149.00, steps = 149
# 13:46:07 [DEBUG] train episode 469: reward = -154.00, steps = 154
# 13:46:13 [DEBUG] train episode 470: reward = -165.00, steps = 165
# 13:46:19 [DEBUG] train episode 471: reward = -177.00, steps = 177
# 13:46:25 [DEBUG] train episode 472: reward = -165.00, steps = 165
# 13:46:32 [DEBUG] train episode 473: reward = -174.00, steps = 174
# 13:46:37 [DEBUG] train episode 474: reward = -161.00, steps = 161
# 13:46:44 [DEBUG] train episode 475: reward = -168.00, steps = 168
# 13:46:51 [DEBUG] train episode 476: reward = -200.00, steps = 200
# 13:46:57 [DEBUG] train episode 477: reward = -162.00, steps = 162
# 13:47:00 [DEBUG] train episode 478: reward = -92.00, steps = 92
# 13:47:03 [DEBUG] train episode 479: reward = -87.00, steps = 87
# 13:47:07 [DEBUG] train episode 480: reward = -103.00, steps = 103
# 13:47:14 [DEBUG] train episode 481: reward = -200.00, steps = 200
# 13:47:18 [DEBUG] train episode 482: reward = -120.00, steps = 120
# 13:47:21 [DEBUG] train episode 483: reward = -85.00, steps = 85
# 13:47:26 [DEBUG] train episode 484: reward = -127.00, steps = 127
# 13:47:32 [DEBUG] train episode 485: reward = -155.00, steps = 155
# 13:47:37 [DEBUG] train episode 486: reward = -150.00, steps = 150
# 13:47:40 [DEBUG] train episode 487: reward = -89.00, steps = 89
# 13:47:43 [DEBUG] train episode 488: reward = -83.00, steps = 83
# 13:47:49 [DEBUG] train episode 489: reward = -156.00, steps = 156
# 13:47:54 [DEBUG] train episode 490: reward = -155.00, steps = 155
# 13:47:57 [DEBUG] train episode 491: reward = -83.00, steps = 83
# 13:48:00 [DEBUG] train episode 492: reward = -84.00, steps = 84
# 13:48:04 [DEBUG] train episode 493: reward = -118.00, steps = 118
# 13:48:07 [DEBUG] train episode 494: reward = -84.00, steps = 84
# 13:48:11 [DEBUG] train episode 495: reward = -88.00, steps = 88
# 13:48:11 [INFO] ==== test ====
# 13:48:11 [DEBUG] test episode 0: reward = -113.00, steps = 113
# 13:48:11 [DEBUG] test episode 1: reward = -93.00, steps = 93
# 13:48:11 [DEBUG] test episode 2: reward = -163.00, steps = 163
# 13:48:11 [DEBUG] test episode 3: reward = -117.00, steps = 117
# 13:48:11 [DEBUG] test episode 4: reward = -117.00, steps = 117
# 13:48:11 [DEBUG] test episode 5: reward = -160.00, steps = 160
# 13:48:11 [DEBUG] test episode 6: reward = -88.00, steps = 88
# 13:48:11 [DEBUG] test episode 7: reward = -154.00, steps = 154
# 13:48:11 [DEBUG] test episode 8: reward = -115.00, steps = 115
# 13:48:11 [DEBUG] test episode 9: reward = -114.00, steps = 114
# 13:48:12 [DEBUG] test episode 10: reward = -85.00, steps = 85
# 13:48:12 [DEBUG] test episode 11: reward = -113.00, steps = 113
# 13:48:12 [DEBUG] test episode 12: reward = -165.00, steps = 165
# 13:48:12 [DEBUG] test episode 13: reward = -115.00, steps = 115
# 13:48:12 [DEBUG] test episode 14: reward = -113.00, steps = 113
# 13:48:12 [DEBUG] test episode 15: reward = -113.00, steps = 113
# 13:48:12 [DEBUG] test episode 16: reward = -113.00, steps = 113
# 13:48:12 [DEBUG] test episode 17: reward = -115.00, steps = 115
# 13:48:12 [DEBUG] test episode 18: reward = -117.00, steps = 117
# 13:48:12 [DEBUG] test episode 19: reward = -156.00, steps = 156
# 13:48:12 [DEBUG] test episode 20: reward = -116.00, steps = 116
# 13:48:12 [DEBUG] test episode 21: reward = -113.00, steps = 113
# 13:48:12 [DEBUG] test episode 22: reward = -89.00, steps = 89
# 13:48:12 [DEBUG] test episode 23: reward = -162.00, steps = 162
# 13:48:12 [DEBUG] test episode 24: reward = -117.00, steps = 117
# 13:48:13 [DEBUG] test episode 25: reward = -113.00, steps = 113
# 13:48:13 [DEBUG] test episode 26: reward = -84.00, steps = 84
# 13:48:13 [DEBUG] test episode 27: reward = -172.00, steps = 172
# 13:48:13 [DEBUG] test episode 28: reward = -162.00, steps = 162
# 13:48:13 [DEBUG] test episode 29: reward = -115.00, steps = 115
# 13:48:13 [DEBUG] test episode 30: reward = -114.00, steps = 114
# 13:48:13 [DEBUG] test episode 31: reward = -114.00, steps = 114
# 13:48:13 [DEBUG] test episode 32: reward = -96.00, steps = 96
# 13:48:13 [DEBUG] test episode 33: reward = -117.00, steps = 117
# 13:48:13 [DEBUG] test episode 34: reward = -113.00, steps = 113
# 13:48:13 [DEBUG] test episode 35: reward = -114.00, steps = 114
# 13:48:13 [DEBUG] test episode 36: reward = -86.00, steps = 86
# 13:48:13 [DEBUG] test episode 37: reward = -162.00, steps = 162
# 13:48:13 [DEBUG] test episode 38: reward = -115.00, steps = 115
# 13:48:14 [DEBUG] test episode 39: reward = -117.00, steps = 117
# 13:48:14 [DEBUG] test episode 40: reward = -115.00, steps = 115
# 13:48:14 [DEBUG] test episode 41: reward = -117.00, steps = 117
# 13:48:14 [DEBUG] test episode 42: reward = -117.00, steps = 117
# 13:48:14 [DEBUG] test episode 43: reward = -88.00, steps = 88
# 13:48:14 [DEBUG] test episode 44: reward = -113.00, steps = 113
# 13:48:14 [DEBUG] test episode 45: reward = -114.00, steps = 114
# 13:48:14 [DEBUG] test episode 46: reward = -114.00, steps = 114
# 13:48:14 [DEBUG] test episode 47: reward = -113.00, steps = 113
# 13:48:14 [DEBUG] test episode 48: reward = -117.00, steps = 117
# 13:48:14 [DEBUG] test episode 49: reward = -87.00, steps = 87
# 13:48:14 [DEBUG] test episode 50: reward = -100.00, steps = 100
# 13:48:14 [DEBUG] test episode 51: reward = -91.00, steps = 91
# 13:48:14 [DEBUG] test episode 52: reward = -113.00, steps = 113
# 13:48:14 [DEBUG] test episode 53: reward = -166.00, steps = 166
# 13:48:14 [DEBUG] test episode 54: reward = -117.00, steps = 117
# 13:48:15 [DEBUG] test episode 55: reward = -156.00, steps = 156
# 13:48:15 [DEBUG] test episode 56: reward = -113.00, steps = 113
# 13:48:15 [DEBUG] test episode 57: reward = -117.00, steps = 117
# 13:48:15 [DEBUG] test episode 58: reward = -114.00, steps = 114
# 13:48:15 [DEBUG] test episode 59: reward = -85.00, steps = 85
# 13:48:15 [DEBUG] test episode 60: reward = -83.00, steps = 83
# 13:48:15 [DEBUG] test episode 61: reward = -114.00, steps = 114
# 13:48:15 [DEBUG] test episode 62: reward = -133.00, steps = 133
# 13:48:15 [DEBUG] test episode 63: reward = -156.00, steps = 156
# 13:48:15 [DEBUG] test episode 64: reward = -115.00, steps = 115
# 13:48:15 [DEBUG] test episode 65: reward = -112.00, steps = 112
# 13:48:15 [DEBUG] test episode 66: reward = -98.00, steps = 98
# 13:48:15 [DEBUG] test episode 67: reward = -113.00, steps = 113
# 13:48:15 [DEBUG] test episode 68: reward = -115.00, steps = 115
# 13:48:15 [DEBUG] test episode 69: reward = -113.00, steps = 113
# 13:48:15 [DEBUG] test episode 70: reward = -113.00, steps = 113
# 13:48:15 [DEBUG] test episode 71: reward = -115.00, steps = 115
# 13:48:16 [DEBUG] test episode 72: reward = -113.00, steps = 113
# 13:48:16 [DEBUG] test episode 73: reward = -84.00, steps = 84
# 13:48:16 [DEBUG] test episode 74: reward = -115.00, steps = 115
# 13:48:16 [DEBUG] test episode 75: reward = -88.00, steps = 88
# 13:48:16 [DEBUG] test episode 76: reward = -115.00, steps = 115
# 13:48:16 [DEBUG] test episode 77: reward = -112.00, steps = 112
# 13:48:16 [DEBUG] test episode 78: reward = -84.00, steps = 84
# 13:48:16 [DEBUG] test episode 79: reward = -155.00, steps = 155
# 13:48:16 [DEBUG] test episode 80: reward = -117.00, steps = 117
# 13:48:16 [DEBUG] test episode 81: reward = -91.00, steps = 91
# 13:48:16 [DEBUG] test episode 82: reward = -114.00, steps = 114
# 13:48:16 [DEBUG] test episode 83: reward = -83.00, steps = 83
# 13:48:16 [DEBUG] test episode 84: reward = -176.00, steps = 176
# 13:48:16 [DEBUG] test episode 85: reward = -84.00, steps = 84
# 13:48:16 [DEBUG] test episode 86: reward = -86.00, steps = 86
# 13:48:16 [DEBUG] test episode 87: reward = -83.00, steps = 83
# 13:48:17 [DEBUG] test episode 88: reward = -113.00, steps = 113
# 13:48:17 [DEBUG] test episode 89: reward = -113.00, steps = 113
# 13:48:17 [DEBUG] test episode 90: reward = -115.00, steps = 115
# 13:48:17 [DEBUG] test episode 91: reward = -154.00, steps = 154
# 13:48:17 [DEBUG] test episode 92: reward = -162.00, steps = 162
# 13:48:17 [DEBUG] test episode 93: reward = -114.00, steps = 114
# 13:48:17 [DEBUG] test episode 94: reward = -92.00, steps = 92
# 13:48:17 [DEBUG] test episode 95: reward = -83.00, steps = 83
# 13:48:17 [DEBUG] test episode 96: reward = -114.00, steps = 114
# 13:48:17 [DEBUG] test episode 97: reward = -113.00, steps = 113
# 13:48:17 [DEBUG] test episode 98: reward = -113.00, steps = 113
# 13:48:17 [DEBUG] test episode 99: reward = -165.00, steps = 165
# 13:48:17 [INFO] average episode reward = -116.28 ± 23.63

# %%
env.close()
