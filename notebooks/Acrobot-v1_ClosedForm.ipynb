# %% [markdown]
# # Use Closed-Form Policy to Play Acrobot-v1

# %%
import sys
import logging
import imp
import itertools

import numpy as np
np.random.seed(0)
import gym

imp.reload(logging)
logging.basicConfig(level=logging.DEBUG,
        format='%(asctime)s [%(levelname)s] %(message)s',
        stream=sys.stdout, datefmt='%H:%M:%S')

# %%
env = gym.make('Acrobot-v1')
env.seed(0)
for key in vars(env):
    logging.info('%s: %s', key, vars(env)[key])
for key in vars(env.spec):
    logging.info('%s: %s', key, vars(env.spec)[key])
# Out:
# 00:00:00 [INFO] env: <AcrobotEnv<Acrobot-v1>>
# 00:00:00 [INFO] action_space: Discrete(3)
# 00:00:00 [INFO] observation_space: Box(-28.274333953857422, 28.274333953857422, (6,), float32)
# 00:00:00 [INFO] reward_range: (-inf, inf)
# 00:00:00 [INFO] metadata: {'render.modes': ['human', 'rgb_array'], 'video.frames_per_second': 15}
# 00:00:00 [INFO] _max_episode_steps: 500
# 00:00:00 [INFO] _elapsed_steps: None
# 00:00:00 [INFO] id: Acrobot-v1
# 00:00:00 [INFO] entry_point: gym.envs.classic_control:AcrobotEnv
# 00:00:00 [INFO] reward_threshold: -100.0
# 00:00:00 [INFO] nondeterministic: False
# 00:00:00 [INFO] max_episode_steps: 500
# 00:00:00 [INFO] _kwargs: {}
# 00:00:00 [INFO] _env_name: Acrobot

# %%
class ClosedFormAgent:
    def __init__(self, _):
        pass

    def reset(self, mode=None):
        pass

    def step(self, observation, _reward, _done):
        x0, y0, x1, y1, v0, v1 = observation
        if v1 < -0.3:
            action = 0
        elif v1 > 0.3:
            action = 2
        else:
            y = y1 + x0 * y1 + x1 * y0
            if y > 0.:
                action = 0
            else:
                action = 2
        return action

    def close(self):
        pass


agent = ClosedFormAgent(env)

# %%
def play_episode(env, agent, max_episode_steps=None, mode=None, render=False):
    observation, reward, done = env.reset(), 0., False
    agent.reset(mode=mode)
    episode_reward, elapsed_steps = 0., 0
    while True:
        action = agent.step(observation, reward, done)
        if render:
            env.render()
        if done:
            break
        observation, reward, done, _ = env.step(action)
        episode_reward += reward
        elapsed_steps += 1
        if max_episode_steps and elapsed_steps >= max_episode_steps:
            break
    agent.close()
    return episode_reward, elapsed_steps


logging.info('==== test ====')
episode_rewards = []
for episode in range(100):
    episode_reward, elapsed_steps = play_episode(env, agent)
    episode_rewards.append(episode_reward)
    logging.debug('test episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
logging.info('average episode reward = %.2f ± %.2f',
        np.mean(episode_rewards), np.std(episode_rewards))
# Out:
# 00:00:00 [INFO] ==== test ====
# 00:00:00 [DEBUG] test episode 0: reward = -70.00, steps = 71
# 00:00:00 [DEBUG] test episode 1: reward = -194.00, steps = 195
# 00:00:00 [DEBUG] test episode 2: reward = -71.00, steps = 72
# 00:00:00 [DEBUG] test episode 3: reward = -78.00, steps = 79
# 00:00:00 [DEBUG] test episode 4: reward = -64.00, steps = 65
# 00:00:00 [DEBUG] test episode 5: reward = -157.00, steps = 158
# 00:00:00 [DEBUG] test episode 6: reward = -71.00, steps = 72
# 00:00:00 [DEBUG] test episode 7: reward = -74.00, steps = 75
# 00:00:00 [DEBUG] test episode 8: reward = -91.00, steps = 92
# 00:00:00 [DEBUG] test episode 9: reward = -138.00, steps = 139
# 00:00:00 [DEBUG] test episode 10: reward = -92.00, steps = 93
# 00:00:00 [DEBUG] test episode 11: reward = -90.00, steps = 91
# 00:00:00 [DEBUG] test episode 12: reward = -107.00, steps = 108
# 00:00:00 [DEBUG] test episode 13: reward = -85.00, steps = 86
# 00:00:00 [DEBUG] test episode 14: reward = -78.00, steps = 79
# 00:00:00 [DEBUG] test episode 15: reward = -85.00, steps = 86
# 00:00:00 [DEBUG] test episode 16: reward = -64.00, steps = 65
# 00:00:00 [DEBUG] test episode 17: reward = -72.00, steps = 73
# 00:00:00 [DEBUG] test episode 18: reward = -72.00, steps = 73
# 00:00:00 [DEBUG] test episode 19: reward = -86.00, steps = 87
# 00:00:00 [DEBUG] test episode 20: reward = -82.00, steps = 83
# 00:00:00 [DEBUG] test episode 21: reward = -177.00, steps = 178
# 00:00:00 [DEBUG] test episode 22: reward = -78.00, steps = 79
# 00:00:00 [DEBUG] test episode 23: reward = -207.00, steps = 208
# 00:00:00 [DEBUG] test episode 24: reward = -95.00, steps = 96
# 00:00:00 [DEBUG] test episode 25: reward = -80.00, steps = 81
# 00:00:00 [DEBUG] test episode 26: reward = -64.00, steps = 65
# 00:00:00 [DEBUG] test episode 27: reward = -73.00, steps = 74
# 00:00:00 [DEBUG] test episode 28: reward = -75.00, steps = 76
# 00:00:00 [DEBUG] test episode 29: reward = -143.00, steps = 144
# 00:00:00 [DEBUG] test episode 30: reward = -64.00, steps = 65
# 00:00:00 [DEBUG] test episode 31: reward = -64.00, steps = 65
# 00:00:00 [DEBUG] test episode 32: reward = -96.00, steps = 97
# 00:00:01 [DEBUG] test episode 33: reward = -80.00, steps = 81
# 00:00:01 [DEBUG] test episode 34: reward = -64.00, steps = 65
# 00:00:01 [DEBUG] test episode 35: reward = -93.00, steps = 94
# 00:00:01 [DEBUG] test episode 36: reward = -71.00, steps = 72
# 00:00:01 [DEBUG] test episode 37: reward = -71.00, steps = 72
# 00:00:01 [DEBUG] test episode 38: reward = -64.00, steps = 65
# 00:00:01 [DEBUG] test episode 39: reward = -71.00, steps = 72
# 00:00:01 [DEBUG] test episode 40: reward = -85.00, steps = 86
# 00:00:01 [DEBUG] test episode 41: reward = -71.00, steps = 72
# 00:00:01 [DEBUG] test episode 42: reward = -79.00, steps = 80
# 00:00:01 [DEBUG] test episode 43: reward = -64.00, steps = 65
# 00:00:01 [DEBUG] test episode 44: reward = -65.00, steps = 66
# 00:00:01 [DEBUG] test episode 45: reward = -96.00, steps = 97
# 00:00:01 [DEBUG] test episode 46: reward = -84.00, steps = 85
# 00:00:01 [DEBUG] test episode 47: reward = -78.00, steps = 79
# 00:00:01 [DEBUG] test episode 48: reward = -78.00, steps = 79
# 00:00:01 [DEBUG] test episode 49: reward = -91.00, steps = 92
# 00:00:01 [DEBUG] test episode 50: reward = -86.00, steps = 87
# 00:00:01 [DEBUG] test episode 51: reward = -80.00, steps = 81
# 00:00:01 [DEBUG] test episode 52: reward = -71.00, steps = 72
# 00:00:01 [DEBUG] test episode 53: reward = -87.00, steps = 88
# 00:00:01 [DEBUG] test episode 54: reward = -77.00, steps = 78
# 00:00:01 [DEBUG] test episode 55: reward = -141.00, steps = 142
# 00:00:01 [DEBUG] test episode 56: reward = -76.00, steps = 77
# 00:00:01 [DEBUG] test episode 57: reward = -77.00, steps = 78
# 00:00:01 [DEBUG] test episode 58: reward = -89.00, steps = 90
# 00:00:01 [DEBUG] test episode 59: reward = -93.00, steps = 94
# 00:00:01 [DEBUG] test episode 60: reward = -85.00, steps = 86
# 00:00:01 [DEBUG] test episode 61: reward = -93.00, steps = 94
# 00:00:01 [DEBUG] test episode 62: reward = -80.00, steps = 81
# 00:00:01 [DEBUG] test episode 63: reward = -169.00, steps = 170
# 00:00:01 [DEBUG] test episode 64: reward = -91.00, steps = 92
# 00:00:01 [DEBUG] test episode 65: reward = -65.00, steps = 66
# 00:00:01 [DEBUG] test episode 66: reward = -78.00, steps = 79
# 00:00:01 [DEBUG] test episode 67: reward = -80.00, steps = 81
# 00:00:01 [DEBUG] test episode 68: reward = -125.00, steps = 126
# 00:00:01 [DEBUG] test episode 69: reward = -85.00, steps = 86
# 00:00:01 [DEBUG] test episode 70: reward = -72.00, steps = 73
# 00:00:01 [DEBUG] test episode 71: reward = -70.00, steps = 71
# 00:00:01 [DEBUG] test episode 72: reward = -96.00, steps = 97
# 00:00:01 [DEBUG] test episode 73: reward = -100.00, steps = 101
# 00:00:01 [DEBUG] test episode 74: reward = -78.00, steps = 79
# 00:00:01 [DEBUG] test episode 75: reward = -72.00, steps = 73
# 00:00:01 [DEBUG] test episode 76: reward = -500.00, steps = 500
# 00:00:01 [DEBUG] test episode 77: reward = -177.00, steps = 178
# 00:00:01 [DEBUG] test episode 78: reward = -71.00, steps = 72
# 00:00:01 [DEBUG] test episode 79: reward = -76.00, steps = 77
# 00:00:01 [DEBUG] test episode 80: reward = -72.00, steps = 73
# 00:00:01 [DEBUG] test episode 81: reward = -85.00, steps = 86
# 00:00:01 [DEBUG] test episode 82: reward = -85.00, steps = 86
# 00:00:01 [DEBUG] test episode 83: reward = -97.00, steps = 98
# 00:00:01 [DEBUG] test episode 84: reward = -70.00, steps = 71
# 00:00:01 [DEBUG] test episode 85: reward = -94.00, steps = 95
# 00:00:01 [DEBUG] test episode 86: reward = -79.00, steps = 80
# 00:00:01 [DEBUG] test episode 87: reward = -199.00, steps = 200
# 00:00:02 [DEBUG] test episode 88: reward = -80.00, steps = 81
# 00:00:02 [DEBUG] test episode 89: reward = -71.00, steps = 72
# 00:00:02 [DEBUG] test episode 90: reward = -72.00, steps = 73
# 00:00:02 [DEBUG] test episode 91: reward = -98.00, steps = 99
# 00:00:02 [DEBUG] test episode 92: reward = -72.00, steps = 73
# 00:00:02 [DEBUG] test episode 93: reward = -84.00, steps = 85
# 00:00:02 [DEBUG] test episode 94: reward = -93.00, steps = 94
# 00:00:02 [DEBUG] test episode 95: reward = -91.00, steps = 92
# 00:00:02 [DEBUG] test episode 96: reward = -82.00, steps = 83
# 00:00:02 [DEBUG] test episode 97: reward = -90.00, steps = 91
# 00:00:02 [DEBUG] test episode 98: reward = -72.00, steps = 73
# 00:00:02 [DEBUG] test episode 99: reward = -213.00, steps = 214
# 00:00:02 [INFO] average episode reward = -94.81 ± 51.99

# %%
env.close()
